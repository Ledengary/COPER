# %% [markdown]
# # importing packages

# %%
# pip install --upgrade torch torchvision
# use this for training

# %%
# !pip install -qU sentence-transformers
# !pip install -qU wikipedia-api
# !pip install -qU clean-text[gpl]

# !mkdir resources
# !wget -q "https://github.com/sobhe/hazm/releases/download/v0.5/resources-0.5.zip" -P resources
# !unzip -qq resources/resources-0.5.zip -d resources

# !rm -rf /content/4ccae468eb73bf6c4f4de3075ddb5336
# !rm -rf /content/preproc
# !rm preprocessing.py utils.py
# !mkdir -p /content/preproc
# !git clone https://gist.github.com/4ccae468eb73bf6c4f4de3075ddb5336.git /content/preproc/
# !mv /content/preproc/* /content/
# !rm -rf /content/preproc

# !pip install faiss-cpu
# !pip install hazm
# Out:
# mkdir: cannot create directory ‘resources’: File exists
# replace resources/chunker.model? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Cloning into '/content/preproc'...
# remote: Enumerating objects: 7, done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 7
# Unpacking objects: 100% (7/7), done.
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.6/dist-packages (1.7.0)
# Requirement already satisfied: hazm in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: libwapiti>=0.2.1; platform_system != "Windows" in /usr/local/lib/python3.6/dist-packages (from hazm) (0.2.1)
# Requirement already satisfied: nltk==3.3 in /usr/local/lib/python3.6/dist-packages (from hazm) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from libwapiti>=0.2.1; platform_system != "Windows"->hazm) (1.15.0)

# %%
import numpy as np 
import pandas as pd
import re
import os
import faiss
import hazm
from hazm import stopwords_list
import pickle
import requests
from termcolor import colored

from torch.utils.data import DataLoader
from sentence_transformers import InputExample, losses
import torch
import tensorflow as tf
from sentence_transformers import models, SentenceTransformer, util


SentenceTransformer_TrainedOnFarsTail_Path = 'm3hrdadfi/bert-fa-base-uncased-farstail-mean-tokens'
SentenceTransformer_TrainedOn_wikinli_Path = 'm3hrdadfi/bert-fa-base-uncased-wikinli-mean-tokens'
SentenceTransformer_TrainedOn_wikitriplet_Path = 'm3hrdadfi/bert-fa-base-uncased-wikitriplet-mean-tokens'

# %% [markdown]
# # Helpers

# %%
# phrases that need to be removed from titles
corona_phrases = ['کرونایی', 'کروناست' ,'کرونا', 'شیوع', 'بحران', 'ویروس',
                  'ویروس جدید', 'coronavirus', 'corona', 'کووید-19 ', 
                  'کووید', 'بیماری', 'بیمارانی', 'بیماران', '-۱۹', ' وی ', '19', '۱۹',
                  ' بیمار ', 'كرونا', 'كوويد', 'ويروس', r'(\s+)',]


normalizer = hazm.Normalizer()

def clean(text):
    """Cleans the titles for the semantic models"""
    for pattern in corona_phrases:
        text = re.sub(pattern, " ", text)

    text = re.sub(' +[\w] +', " ", text)
    text = normalizer.normalize(text)

    return text


#---------------------------------- get the results for this model-----------------------#

def get_resutls(questions, top_n):
    
    results = []
    for question in questions:

        print(question)
        # print('question type', type(question))


        # we give the cleaned question to the semantic model 
        question_cleaned = clean(question)

        question_emb = sentence_bert_embedder.encode(question_cleaned,
                                    convert_to_tensor=False,
                                    show_progress_bar = False)
        
        emb_que = np.array([question_emb])
        faiss.normalize_L2(emb_que)

        top_k = index.search(emb_que, top_n)
        indices = []
        scores = []

        # saving all the reults in a dictionary
        for score, idx in zip(top_k[0][0], top_k[1][0]):
            
            indices.append(idx)
            scores.append(score)

        results.append({'question':question,
                        'index':indices,
                        'score':scores})
    return results

# %% [markdown]
# # The Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_address = '/content/drive/MyDrive/COVID-PSS.xls'
keys_address = '/content/drive/MyDrive/keywords_final_distilled_NE (1).pickle'
cleaned_titles_address = '/content/drive/MyDrive/title_cleaned_without_corona_2.pkl'
annotations_address = '/content/drive/MyDrive/all_annotations.csv'

df = pd.read_csv(data_address)
list_t = pd.read_pickle(cleaned_titles_address)

keywords = pd.read_pickle(keys_address)
keywords = [v for k,v in keywords.items()]



assert len(keywords) == len(df)
df['keywords'] = keywords
df.drop(columns=['img', 'link'], inplace=True)

# %%
corpora = []
for i in range(len(list_t)):

    keys = '[SEP]'.join(keywords[i])
    corpora.append(' '.join([list_t[i], keys]))

# %% [markdown]
# # The model

# %%
# preparing the model

def load_sentence_transformer(path):
    bert_model_s = models.Transformer(path, max_seq_length=512)
    pooling_model = models. Pooling(
        bert_model_s.get_word_embedding_dimension(),
        pooling_mode_mean_tokens = True,
        pooling_mode_cls_token = False,
        pooling_mode_max_tokens = False,
    )
    model = SentenceTransformer(modules= [bert_model_s, pooling_model])
    return model

sentence_bert_embedder = load_sentence_transformer(SentenceTransformer_TrainedOnFarsTail_Path)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=519.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=651450094.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1198122.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=222.0, style=ProgressStyle(description_…

# %% [markdown]
# # Creating Embeddings

# %%
# %%time
# creating corpus embeddings

corpus_embeddings = sentence_bert_embedder.encode(corpora,
                                                  convert_to_tensor=True,
                                                  show_progress_bar=True,
                                                  batch_size = 256)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=14.0, style=ProgressStyle(description_width…
# CPU times: user 21.7 s, sys: 18.1 s, total: 39.8 s
# Wall time: 49.1 s

# %% [markdown]
# # Sample Qustions

# %%
# creating sample question embeddings

question = str('باردار باردار باردار باردار باردار باردار ')
question_emb = sentence_bert_embedder.encode(question,
                               convert_to_tensor=False,
                               show_progress_bar = False)

# %% [markdown]
# Searching with FAISS

# %%
## Similarity Scores with FAISS

index = faiss.index_factory(768, "Flat", faiss.METRIC_INNER_PRODUCT)
# corpus
emb_cor = np.array(corpus_embeddings)
faiss.normalize_L2(emb_cor)

# query
index.add(emb_cor)
emb_que = np.array([question_emb])
faiss.normalize_L2(emb_que)

top_k = index.search(emb_que, 100)

# %%
sentence_bert_WikiNli_indices = []
sentence_bert_WikiNli_scores = []

print(question)
print('Top results!')
i=0
for score, idx in zip(top_k[0][0], top_k[1][0]):
    print(colored(f'{i}th', 'blue'),' corpus with score', colored( f'{score:.2f}:\n', 'blue'),  corpora[idx])
    i+=1
    sentence_bert_WikiNli_indices.append(idx)
    sentence_bert_WikiNli_scores.append(score)
# Out:
# باردار
# Top results!
# 0th  corpus with score 0.75:
#  تاج هم را شکست داد بیمارستان مرخص[SEP]بهبود نسبی[SEP]حال خبرها
# 1th  corpus with score 0.74:
#  مدیرعامل بانک مسکن بر اثر در گذشت اثر ابتلا[SEP]گذشت ایلنا ساعاتی[SEP]در گذشت ایلنا ساعاتی
# 2th  corpus with score 0.71:
#  در مقابل تاب می‌آوریم؟ واکنشهای احساسی بیشتری[SEP]حال همکاران بیمارم[SEP]تاب اوری شان[SEP]توان و تاباوری بیشتری[SEP]سپری شدن شرایط سخت و مصیبت زندگی خود[SEP]تاباوری یا تاباوری روانی[SEP]خود حرف زدن[SEP]کمک کننده[SEP]تاب اوری[SEP]انجام کارهای عقب[SEP]نام تاب اوری[SEP]خانواده پرجمعیتی[SEP]چند ماهی[SEP]مشکلات و سختیها[SEP]دیگر نمیکشم‌ها[SEP]خانه دایم[SEP]کارمند یک شرکت خصوصی[SEP]همان تاباوری خودشان[SEP]مدت شنیدهام[SEP]مادرت قرنطینه[SEP]همه جای دنیا[SEP]شرایط باب گفتوگو[SEP]پایین امده غمگین[SEP]دست اوردن تفکر و مهارتهای خود[SEP]گیر افتادهایم دکتر روانشناس[SEP]برخی تاباوری شان
# 3th  corpus with score 0.70:
#  چند دقیقه در کنار فرد مبتلا بمانیم می‌گیریم؟ سه هزار قطره[SEP]طور قابل توجهی[SEP]فردی مبتلا[SEP]دفتر کار[SEP]اغلب قطرهها[SEP]رهاسازی قطرات تنفسی[SEP]برخی قطرات الوده کوچک[SEP]هزار قطره[SEP]فرد مبتلا
# 4th  corpus with score 0.70:
#   بار مضاعف بر دوش کولبرها یکمیلیون تومان[SEP]یک و نیممیلیون تومان[SEP]بذار و بردار پدر و کار کردن[SEP]درامدن خرجی خانه اوایل صبحها میرفتم مدرسه[SEP]دیگر پای قانع[SEP]بگیرد نزدیک یکمیلیون و ٥٠٠ هزار تومان[SEP]دامان کوه بزرگ[SEP]لوازم خانگی درامد کولبری[SEP]گچ درامده پستی و بلندیهای کوه درد[SEP]بعدش هم نه راهی[SEP]امد دیگر[SEP]کولبری رهایی[SEP]مانع کولبری کردن قانع[SEP]نه امدن مرض همهگیر[SEP]پهنای گردها ش[SEP]سراغ کار دیگری[SEP]کار دیگری[SEP]درامد مسافرکشی اون قدری[SEP]لباسهای امروزیتر پارسال[SEP]میان پیچ و خم گردنههای گن او[SEP]مادرش و سه خواهر[SEP]راههای دیگری[SEP]درمان دیگری[SEP]انسوی مرز[SEP]گرگ و نه احتمال بورانی[SEP]میلاد کولبری[SEP]شیشه عمر پدرش[SEP]شنیدن سخن دیگری[SEP]قید درد پا و کمر و گرده[SEP]شنیدن اسم کمک دولتی[SEP]چاره دیگری[SEP]بستن گردنههای مرزی بیرمقی[SEP]یافتن کاری دیگر[SEP]سراغ کارهای دیگری[SEP]گردنهها پایش لغز[SEP]روستاهای ان سوی مرز[SEP]٣٠ کیلو مغز گردو و بادام[SEP]سرمای گردنههای[SEP]کولرگازی و سیگار و چای و جاروبرقی و تلویزیون بیاورد کول[SEP]همان روز دیگر[SEP]کشتارگاه گاوداری یا هر جای دیگری[SEP]یکمیلیون و دیگر[SEP]شاگرد تعمیراتی[SEP]کار کردن ت[SEP]کاری دیگر
# 5th  corpus with score 0.70:
#  در آغوش سرطان از ترس  سیتیاسکن[SEP]حال پذیرش دسته[SEP]نزدیکی درمانگاه دولتی داخل کوچهای خوشم[SEP]راهی پیدا میکنم مرکز‌تر و تمیز و دیوارهایش[SEP]رادیولوژی طبقه همکف[SEP]بیشتر انها[SEP]دیگر ساختمانها[SEP]گفته کنگره رادیولوژی قابلقبول[SEP]شاهد تعطیلی برخی مراکز بهدلیل خرابی دستگاهها و ناتوانی[SEP]نوبت رادیولوژی[SEP]یکبار[SEP]درباره پذیرش نکردن مبتلا[SEP]هر چند وقت یکبار[SEP]سیتیاسکن نی د[SEP]تصویربرداری و اسکن ریه[SEP]روزنامه کارش[SEP]همه مراکز[SEP]ورودی ساختمان بلندبالا[SEP]تعرفههای فعلی و انبوه تقاضا[SEP]مراکز ارایه خدمات سیتیاسکن و تصویربرداری[SEP]سر و صورت برخیشان[SEP]سیتیاسکن ریه[SEP]مراکز[SEP]تجربهای[SEP]هر چند اخباری[SEP]سیتیاسکن و تصویربرداری[SEP]دستور انجام سیتیاسکن[SEP]ساختمانهای نوساز و بالارفته[SEP]روی مرد نسبتا میانسال کت و شلوار[SEP]پرداخت هزینههای تعمیرات دستگاههای خراب[SEP]راهکار مناسبی[SEP]مراکز تصویربرداری و رادیولوژی[SEP]دستگاهها و تجهیزات وارداتی[SEP]انجام اسکن ریه[SEP]تصویربرداری و اسکن ریه نشانهای[SEP]راه میانبر[SEP]متقاضیان تصویربرداری و سیتیاسکن[SEP]تعداد مراکز سیتیاسکن دولتی و خصوصی[SEP]دوبرابر و حتی بیشتر[SEP]نخستینبار[SEP]بیشتر وقت مراکز تصویربرداری و رادیولوژی[SEP]ویزیت و انجام ازمایشهای خود[SEP]اسکن ریه[SEP]امکان تامین هزینه[SEP]سیتیاسکن و تصویربرداری کمکی[SEP]امکان افزایش تعداد مراکز[SEP]تست pcr[SEP]صفهای طولانی متقاضی روبهرو[SEP]ماشینها دوبله سوب له کنار[SEP]بسیاری[SEP]تست ریه[SEP]مراکز خاصی[SEP]درصورت تامین شدن مبلغ تحریمها مانع بزرگی[SEP]روند فعلی اصلاح نشود بهزودی[SEP]دستگاه سیتیاسکن[SEP]همان کار تست pcr[SEP]لامپ کممصرف بزرگی[SEP]موهای نسبتا کوتاه و شلوار جین ابی[SEP]دستگاه اتوماتیک سالن شمارهاش[SEP]فرسودگی شدید دستگاهها[SEP]کارکرد مراکز برای[SEP]چالشهای پیشروی رادیولوژیستها و مراکز تصویربرداری[SEP]یک کار امدهاند سیتیاسکن[SEP]هستند چالشهای مراکز رادیولوژی نگرانیها و چالشهایی[SEP]حجم بالای متقاضی انجام سیتیاسکن[SEP]سوی مراکز[SEP]یک تست ریه ارزانقیمت‌تر[SEP]نمای سنگ سیاه بیشتر[SEP]دلواپس جنبههای نگرانکننده‌اش[SEP]گرفتن تست ریه و فهمیدن[SEP]صاحب صدای سرفه[SEP]مراکز شبانهروزی تصویربرداری و سیتیاسکن[SEP]غربالگری مناسب[SEP]بیشتر افراد[SEP]هر چند بینشان کسانی[SEP]عملکرد مراکز رادیولوژی و تصویربرداری[SEP]بهنظر بیشترشان[SEP]ازمایش سروته داستان ابتلای احتمالی خود[SEP]میگوید انبوه مراجعهکنندگان[SEP]بیشتر منتظران سالن[SEP]مرکز سیتیاسکن[SEP]مراکز سیتیاسکن[SEP]داخل مرکز
# 6th  corpus with score 0.70:
#  می‌گویند من را در محله‌مان منتشر کرده‌ام پس از بازگشت به اداره نگذاشتند پشت میزم بنشینم مشکلات روحی و روانی[SEP]کارمند یک شرکت باربری[SEP]برخی بهبود[SEP]کارفرمایان و مدیران ادارات و سازمانها[SEP]محیط کاردک‌تر مسیول درباره[SEP]مراکز درمانی[SEP]گواهی سلامت درمانگاه[SEP]انجام دوباره مع ه و ازمایشهایی[SEP]کارمندان ادارات دولتی[SEP]بیمارستان راهاندازی[SEP]بهبودیافتگان خودش[SEP]عوامل مختلف ژنتیکی و محیطی افراد[SEP]سوی همسایگان[SEP]روابط کاری خانوادگی و محیط کارشان تجربه ناخوش د و عذاباور[SEP]اتاق کو وید مشکلات روحی و تنش[SEP]بهبودیافتگان استرس[SEP]محل کار[SEP]برخی موارد سیتیاسکن[SEP]رابطه دکتر درباره پیامدهای روحی و روانی ابتلا[SEP]اجازه بازگشت[SEP]سلامت روان شهروندان بهویژه مبتلایان[SEP]خانوادهام حرفها[SEP]دوران بهبودی[SEP]درمانگاه مخصوص[SEP]اپارتمان شخصیشان[SEP]فروکش کردن موج اپیدمی رخ[SEP]مانع ورود انها[SEP]بهبود یافتگان مهربان[SEP]بهطور کل محیط اطراف ازارشان[SEP]من و خانوادهام فشار روانی زیادی[SEP]خانواده و همسایگان خود[SEP]دو مقوله دردناک
# 7th  corpus with score 0.69:
#  ابتلاهای خانوادگی شلوغی دوباره بیمارستان‌ها مجددا کنترل میشود محرز[SEP]همراهی مردم[SEP]امدها و دید و بازدیدها[SEP]عین حال[SEP]حال حاضر[SEP]محرز درباره وضعیت بیمارستانهای و احتمال کاهش تاباوری مراکز درمانی[SEP]هم مبتلا میشوند محرز[SEP]تجربه کادر درمانی[SEP]چند ماه اخیر[SEP]قدرت و همراهی و دوش[SEP]نمیتوان نیروهای درمانی[SEP]طریق رعایت دستورالعملهای[SEP]ابتدای بیمارستانها[SEP]کادر درمانی[SEP]تعدادی هم بد حال
# 8th  corpus with score 0.69:
#  ۱۰۴ مشکوک به بستری در بیمارستان مسیح دانشوری بهبودی نیمی از  برای مقابله[SEP]نگران نباشند[SEP]حال بهبود
# 9th  corpus with score 0.69:
#  مطالعات جدید؛ اثر بر زنان باردار به چه صورت است؟ زنان باردار مبتلا[SEP]۱۱۴۳ ۲ زن باردار[SEP]علایم کمتری[SEP]میان زنان باردار مبتلا به[SEP]مراقبتهای ویژه و امکانات تخصصی[SEP]نوزاد داشته_باشند مادرانی[SEP]متخصصان بهداشت و درمان[SEP]مادر مبتلا[SEP]زنان باردار سه دورهی[SEP]زنان باردار[SEP]مراقبتهای ویژه[SEP]چاقی فشار خون بالا و دیابت
# 10th  corpus with score 0.69:
#  آیا بهبودیافتگان هم باید واکسن بزنند؟ حال انجام[SEP]فوقتخصص‌های عفونی و گرمسیری اقداماتی[SEP]کودکان و زنان باردار[SEP]روی کودکان و زنان باردار
# 11th  corpus with score 0.69:
#  هشدار درباره واکسن عجله نکنید احتمالی پخش[SEP]انتظارهای سیاسی[SEP]تجاری بسیاری
# 12th  corpus with score 0.68:
#  فکر نمی‌کردم بگیرم مشکلات گوارشی از بین رفتن حس بویایی و چشایی سرفه[SEP]وجود گذشت ۱۴ روز[SEP]مراحل درمان و گذراندن بسیار سخت[SEP]پروتکلهای بهداشتی[SEP]خریدها و مایحتاج خانه[SEP]ان زمان بیمارستان[SEP]رعایت پروتکلهای بهداشتی[SEP]گذشت یک روز[SEP]همینخاطر فرزندمان[SEP]بیمارستان قایم بخش حاد[SEP]بهبودی مبتلایان وخیم[SEP]مردم همانهایی[SEP]کارهای اداره‌ام[SEP]نحوه مبتلا شدنش[SEP]بیمارستان مبتلا[SEP]شدت پروتکلهای بهداشتی[SEP]تمامی پروتکلهای بهداشتی[SEP]بهبودی کامل[SEP]نکات بهداشتی[SEP]تمام پروتکلهای بهداشتی[SEP]اهدای پلاسما[SEP]اقای استاد دانشگاه و همسر ایشان[SEP]قفسه سینه و داشتم درد و خستگی ام[SEP]خانواده پنج نفری انها همگی[SEP]حتیالامکان موارد بهداشتی و فاصله اجتماعی[SEP]داروهای ساده و معمولی سرماخوردگی[SEP]نه فاصله اجتماعی[SEP]هزینه بیمارستان[SEP]مبتلا شدن[SEP]امار مبتلایان و فوتشدگان
# 13th  corpus with score 0.68:
#  ​​​​​​روزی روزگاری  فحش و بد و بیراه[SEP]درباره تفاوتهای مراقبتی[SEP]دانشگاه برایشان ظهر و شب اب و غذا[SEP]امدهای ساده[SEP]کشورشان و بگویند ما[SEP]هزار و یک مشکل اقتصادی[SEP]همین روزها[SEP]دانشجوی رشته جامعه شناسی[SEP]روزهای کاملا متفاوتی[SEP]یک مساله مهم خارجیها و دانشجوهای خارجی[SEP]برگه خروج[SEP]دیگر همکلاسی او[SEP]خوابگاه و یک تعداد[SEP]دانشجوهای خارجی[SEP]دانشجویان اتباع خارجی[SEP]دانشجوی خارجی[SEP]قدم زدن بی دغدغه[SEP]بیشتر مبتلا‌های درحال بهبودی[SEP]برگشته و نمیخواهد اسمی[SEP]روزهای وبا و های سخت[SEP]همه روزهای[SEP]روزهای کلی[SEP]روزهای خود[SEP]همهشان خاطره و لبخندی برایمان[SEP]روزهای متفاوتی
# 14th  corpus with score 0.68:
#  روند طولانی بهبودی از در برخی مبتلایان جوان جوانان مبتلا[SEP]وجود عدم ابتلا بهه‌ای زمینهای[SEP]روند بهبود میتواند طولانی[SEP]جوانان سالم
# 15th  corpus with score 0.68:
#  اثرات بر چشم عفونت چشم[SEP]ثانیه بشویید[SEP]علایم عفونت
# 16th  corpus with score 0.68:
#   آمد تو نیامدی! شبکههای اجتماعی[SEP]دایره کاربران عادی بالاتر[SEP]تحصیلکرده[SEP]جواب شوخیها[SEP]خاطر مدل شوخیها[SEP]یکی[SEP]چغندر گرمی[SEP]شوخیهایی[SEP]استفاده[SEP]یک کانال بینام و نشان خبری منتشر میکند مبنی[SEP]هیچ کس[SEP]استرس و نباید مردم[SEP]کنار رعایت توصیههای بهداشتی و مراقبت[SEP]روشهای درمان سنتی[SEP]زنی همسن و سال خودش[SEP]مراکز درمانی[SEP]ان پنهانکاری هایی[SEP]یکی دیگر[SEP]همان کمکی[SEP]نمونهاش چند تا پسر ماسک[SEP]دست گربهها[SEP]مرد یک دستکش باغبانی[SEP]کسی[SEP]نمیخواهد خود و عزیزانش[SEP]کاری[SEP]دست خوششان[SEP]شوخی و خنده و یکیشان خیلی جدی[SEP]گرمی نابود[SEP]دستمایه شوخیهای زیادی[SEP]محیطهای درمانی الودهترین اماکن[SEP]خنده و شوخی[SEP]دستکش باغبانی[SEP]کانالهای تلگرامی[SEP]روند پیشگیری و درمان مبتلایان[SEP]یک فرد ناقل[SEP]صورت مشاهده علایم[SEP]شوخی[SEP]دست خودشان[SEP]کل نادیده[SEP]ماسکهای عجیب و غریب[SEP]توصیههای بهداشتی و مراجعه[SEP]شایعات و توصیههای بیهوده[SEP]لبخندی گوشه لبها[SEP]ابتکارات جالبی[SEP]کاربران دیگر[SEP]شوخی کردن[SEP]سر شوخی[SEP]بعضی فکر[SEP]شوخیهای[SEP]پسرها یکی[SEP]شاد و سرگرم کردن همشهریهای شان[SEP]پیدا کردن ربط شانه زدن مو و دیگر[SEP]دست مغازهدار[SEP]صورت مشاهده علایم احتمالی[SEP]سلامت شوخی و ایجاد فضای چنینی[SEP]یکی ریوی[SEP]خواص بیشمار تریاک[SEP]بهترین کاری[SEP]یکی نه بابا[SEP]تا سوهان جملهها و مشابه انها[SEP]مدل شایعات شایعههای دیگری[SEP]خیلی سبزی فروشیها گوجه فرنگی[SEP]کنار بیمارستانها و درمانگاهها عبور[SEP]اضافه تریاک[SEP]دست[SEP]کی[SEP]شدن استرس[SEP]یکی دو نفر[SEP]روشهای درست کردن ماسک و استفاده[SEP]کاربر دیگر[SEP]ادمهای پا به سن گذاشته
# 17th  corpus with score 0.68:
#  آغاز آزمایش واکسن بدون سوزن  زودتر میتوانیم[SEP]کنیم زودتر[SEP]همهگیر خداحافظی
# 18th  corpus with score 0.68:
#  چه زمانی باید آزمایش بدهیم؟ ازمایشهای تشخیص[SEP]سالمندان زمینهای و خانمهای باردار[SEP]هدف اگاهی[SEP]ازمایشهای تشخیصی
# 19th  corpus with score 0.68:
#  شرایط انجام تست از مادران باردار نوزاد آنها اطفال و کودکان[SEP]خصوص مادران مبتلا[SEP]دوبار تست pcr[SEP]دو تست pcr[SEP]مادر باردار[SEP]فرد مبتلا[SEP]مادر باردار و نوزادش توضیحاتی
# 20th  corpus with score 0.68:
#  درگذشت یک نم ده براثر  خانواده ایشان[SEP]ایشان تسلیت[SEP]خبرگزاری دانشجویان
# 21th  corpus with score 0.67:
#   سیر نزولی گرفته اما هنوز پاندمی است رعایت نکات بهداشتی جدی[SEP]رعایت نکات بهداشتی[SEP]سیر نزولی[SEP]مقدم انچه[SEP]نکات بهداشتی
# 22th  corpus with score 0.67:
#  عوارض؛ موقتی یا ماندگار؟ برخی افراد[SEP]درمان و بروز تداخل دارویی[SEP]عوارض کبدی و کلیوی و سایر اندامهای بدن[SEP]چشم برخی مبتلایان[SEP]عوارض علایم امکان کشف واکسن[SEP]نتایج تحقیقات و دانش و قدرت استنتاج متخصصان‌های واگیر[SEP]سر ناشناخته بودن و البته پیچیدگی زیادش[SEP]برخی عوارض اعم[SEP]مشکل مبتلایان[SEP]روی عملکرد مغز قلب کلیهها کبد و غدد درونریز بدن[SEP]یک موسسه معتبر خبری[SEP]عوارض بسیار متفاوت[SEP]فعالیت بدنی متناسب[SEP]گذشت زمان[SEP]ابتدا و بهصورت کلی یک تنفسی تلقی[SEP]حالت عادی بررسی وضعیت پزشکی مبتلایان[SEP]ریه مبتلایان[SEP]همین مدت کوتاه گمانهزنیهای مختلفی[SEP]اغلب نظریهها[SEP]یکسوم مبتلایان[SEP]به‌های چشمی حاد و دایمی[SEP]عوارض بلندمدت[SEP]مبتلایان[SEP]بهی شدید[SEP]سردرگمی بیقراری و اختلال حافظه[SEP]بروز‌های پوستی[SEP]کاهش حس بویایی و چشایی برخی مبتلایان[SEP]احتمال بروز موجهای بعدی[SEP]احتمال بروز سکته مغزی[SEP]مویرگها و سرخرگهای بسیار کوچک[SEP]گذشت زمان اطلاعات[SEP]درباره میزان کشندگی و و تاثیر استفاده[SEP]عوارض ریوی مهمترین[SEP]حس بویایی و چشایی خود[SEP]عملکرد ریهها مبتلایان[SEP]اسیبهای بیشتری[SEP]عوارض بلندمدتی[SEP]اسیبهای عمومیتر[SEP]برخی افراد کاهش[SEP]احتمال بروز موجهای بعدی و نظریهها[SEP]سندروم اختلال کلی[SEP]بهجای یک دارو[SEP]ابتلا بهی شدید یا خفیف[SEP]عوارض[SEP]تحقیق تازه درباره عوارض چشایی و بویایی[SEP]نتایج مستقیم یا غیرمستقیم پژوهشهای محدود و کوتاهمدت[SEP]احتمال نابودی کامل ریه[SEP]ماندگاری عوارض[SEP]لختههای خونی و احتمال بروز سکته تحقیقات اولیه[SEP]بهترین حالتش[SEP]برخی[SEP]ماندگار نشدن عوارض ان[SEP]امکان بازگشت ریهها[SEP]بسیاری تصاویر[SEP]عوارض جدیدی[SEP]بالا ببرد عارضه و تشکیل لختههای خونی[SEP]اساس تجربیات پزشکی[SEP]خبرهایی[SEP]بیشترین نگرانی مبتلایان[SEP]عوارض ان[SEP]ابتلای بهی شدید[SEP]برخی محققان[SEP]دنیای‌ها سابقهدار[SEP]دبیر تاکید[SEP]عوارض و خود[SEP]خطر تشکیل لختههای خونی[SEP]برخی مبتلایان[SEP]چالش بزرگی[SEP]یک اثرات بلندمدت[SEP]عوارض یک تاثیری ماندگار[SEP]طریق ایجاد ترومبوز‌ها یا لختههای خونی کوچکی[SEP]عوارض دایمی[SEP]برخی کسانی[SEP]دلیل ناشناخته بودن و نتایج متفاوت پژوهشها مسوولان[SEP]کاهش حس بویایی و چشایی مبتلایان[SEP]در‌های واگیر اخیر ابولا[SEP]نتایج تحقیقات
# 23th  corpus with score 0.67:
#  دوست داریم بگیریم! حتی خوشی چندساعته‌ای[SEP]سبب مرگ و ابتلاء افرادی[SEP]یک خوشی چندساعته همراه[SEP]مراسم عروسی دختر خواهرم
# 24th  corpus with score 0.67:
#  توصیه‌های بهداشتی به نادر برای مقابله با  پزشک متخصص خود[SEP]مایع شستوشوی ضد عفونی بشویید - مایعات و خصوصا مایعات گرم فراوان[SEP]صورت هر گونه احتمال
# 25th  corpus with score 0.67:
#  روایت گیلانی‌ها از روزگار  پیگیری کارهای موکلش[SEP]بیمارستان دولتی و خصوصی[SEP]سه داروخانه داروهای مرتبط[SEP]دستورالعملهای جدیدی[SEP]برخی دوستان ما[SEP]بازار سیاه[SEP]نصب دستگاه سیتی اسکن و تصویربرداری[SEP]فرسوده شدن کادر درمان[SEP]بستری کردن کسی[SEP]نصب دستگاه سی تی اسکن[SEP]برندهای تصویربرداری[SEP]مدیریت مساله فکری[SEP]بههمراه چند جوان دیگر اهل شهر[SEP]چند ماه نمیپذیرم[SEP]بیمارستانهای خصوصی حمایتی[SEP]پای کار[SEP]جریان امکانات و کادر درمان[SEP]پذیرش شوم هشتم گرافی‌ها[SEP]تهیه تامی فلو[SEP]دوازده و نیم ظهر[SEP]بیمارستانهای خصوصی[SEP]بیمارستانهای دولتی[SEP]کادر درمان روزها[SEP]کادر درمان[SEP]مخالفتهای خانواده[SEP]دو سه ماه بیکار[SEP]مدت یک سری دستکش و محلول ضدعفونی[SEP]کمبود تجهیزات رو[SEP]بازار سیاه تجهیزات[SEP]گرافی ریه[SEP]مسیول تصویربرداری[SEP]بیمارستانهای دیگرهم
# 26th  corpus with score 0.67:
#  منهای  محمود شباهتی دیگر شهروندی[SEP]همه مراکز درمانی[SEP]سایر حوزههای درمان نشده_است و کادر درمانی[SEP]راهی بیمارستانها و درمانگاهها[SEP]امدن توجه و تمرکز به‌های دیگر[SEP]پرسنل بیمارستان[SEP]اورژانس سالن انتظار و صف عابر بانک همه بخشها[SEP]دلیل مراجعه مردم سایر مناطق[SEP]چکاپهای ماهانه انجام ازمایش و حتی ویزیتهای ضروری[SEP]پرستار یک مرکز درمانی[SEP]بیمارستانها و مراکز درمانی[SEP]مراکز درمانی[SEP]ان دوگانگی رفتاری و سردرگمی[SEP]انتشار خبر ابتلای یک شهروند همدانی[SEP]کلینیکهای درمانی دولتی[SEP]مسیول بخش پذیرش درمانگاه[SEP]شبانهروزی کار میکنند ایکاش مردم[SEP]بیمارستانهای ازدحام عجیبی[SEP]حدودی مراجعات[SEP]برخی محدودیتها و البته مراجعه قابل توجه مردم[SEP]شهروند املی[SEP]ارایه نشدن خدمات[SEP]پیدا کردن مرکزی[SEP]نگرانیهای بسیار زیاد مردم و اخبار مختلف و متعددی[SEP]کمبود کادر درمانی[SEP]همیشه – مراکز درمانی دولتی و عمومی[SEP]افزایش مراجعات خدمترسانی[SEP]پزشکان عمومی پزشکان متخصص[SEP]بودن مطب برخی پزشکان متخصص[SEP]روند پیگیری درمان سایر‌ها[SEP]درمانگاههای[SEP]درمانگاهها تعطیل شدن مطبها و ازمایشگاهها[SEP]مراکز درمانی عمومی بی د[SEP]تمرکز مسیولان بر و مراکز ارایه دهنده خدمات ویژه[SEP]افزایش مراجعه شهروندان[SEP]کادر درمانی[SEP]مشکلات زیادی[SEP]کنسل شدن وقت پزشکان متخصص[SEP]تعداد مراجعان خودداری[SEP]اثر سرماخوردگی و انفولانزا[SEP]درمانگاه شبانهروزی[SEP]مراجعه کنندگان شهرستانی[SEP]خدماترسانی[SEP]میگوید مرکز درمانی ما[SEP]ترس ابتلا[SEP]خدمات درمانی[SEP]سایر مراکز درمانی[SEP]ترک مرکز درمانی[SEP]مسیولان مراقبتهای ویژه[SEP]دلیل شلوغی بیمارستان کسی[SEP]مساله مشکلات زیادی[SEP]بروز مشکلات و های دیگر[SEP]هم دو و به عنوان بیمارستانهای مرجع دولتی[SEP]کوچکترین علایم سرماخوردگی خود[SEP]تشخیص پزشک درمانگاه مشکوک[SEP]پزشکان و پرستاران ما[SEP]مراکز درمانی عمومی[SEP]بیمارستانهای میگوید روزها بیمارستان[SEP]کل مرکز الوده[SEP]خدمترسانی[SEP]بیمارستانهای شلوغ و کندی خدماتدهی[SEP]شده_است احتمال‌های دیگر – جو روانی حاصل[SEP]سایر بخشهای درمانی[SEP]مراکز درمانی دولتی دیگر یا مراکز خصوصی[SEP]بودن مطلب برخی پزشکان متخصص[SEP]تمام بخشهای بیمارستانها درمانگاه و کلینیکها[SEP]مسیولان حوزه بهداشت و درمان حاضر[SEP]کمبود خدماترسانی و سردرگمی[SEP]مراجعه کنندگانی[SEP]تنها مرکز درمانی شهرک[SEP]ارایه خدمات مراکز درمانی استان[SEP]جلوی درمانگاه[SEP]چندان شرایط جسمی مناسبی[SEP]انفلوانزا و حتی سرماخوردگی[SEP]بیمارستان و مراکز درمانی[SEP]حجم مراجعات وسواس گونه مانع[SEP]ترس و وسواس دیگر و کادر درمانی بیمارستانها و درمانگاهها[SEP]موج نگرانی خانوادهها[SEP]جراحیهای داخلی و مغز و اعصاب و ارتوپد[SEP]گوشه و کنار شنیده و مخابره[SEP]برخی دوستانم[SEP]کاهش راههای انتقال و بهبود بستری
# 27th  corpus with score 0.67:
#  فوت سه نفر از دانشجویان دانشگاه تهران بر اثر  اثر جان باختند ایلنا[SEP]دانشجویان تحصیلات تکمیلی[SEP]معاون اموزشی[SEP]اثر جان
# 28th  corpus with score 0.67:
#  افزایش به دلیل ارتباط با دیگران قبل از بهبودی بهبودی نسبی[SEP]اظهارکرد کادر درمان بسیار خسته[SEP]وضعیت کادر درمان[SEP]بیمارستان درمان[SEP]حال حاضر[SEP]تمام بیمارستانهای دولتی[SEP]پرستاران و نیروهای بهداشتی ما[SEP]ادامه درمان[SEP]اقدامات پیشگیرانه[SEP]کمبود دستگاههای اکسیژن[SEP]بیمارستان و نیازمند بخشهای مراقبتهای ویژه
# 29th  corpus with score 0.67:
#  گزارش از حال هوای کافه‌ها کافه‌نشین‌ها در زمانه  شنیدن موسیقی کلاسیک نوشیدن قهوه و تماشای ادمها[SEP]یک سبک زندگی اجتماعی[SEP]یک سری کافه روها[SEP]خلوت کافهها[SEP]هدف نوشیدن جرعهای اب میوه شیرین و یا تلخ[SEP]ادمها دلتنگی[SEP]ان نبرد و وصف کافهها[SEP]کافهها و کافه روها[SEP]کافه نشینی[SEP]همه کافههای[SEP]سقف کافهها[SEP]چی و لبخندهای شکری[SEP]عصر کافهها[SEP]بیانکه نگاههای سنگین ازارم[SEP]کافه نشینها[SEP]کافه امنتر[SEP]ادمهای مختلف[SEP]کارمند یک جایی[SEP]ارتباط چشمی[SEP]انگیزه خودباوری ارامش عشق[SEP]شنیدن قیل و قال بچهها[SEP]سر دماغ د اما حال بعضیها[SEP]نوع زندگی اجتماعی روزها[SEP]روند پاسخ فیزیولوژیکی بدن[SEP]کافه ما[SEP]کافه زندگی[SEP]کافه دار میگوید‌ها[SEP]هیاهوی شهر زندگی و همه سازهای ناکوک اطراف[SEP]کافه روها[SEP]کافه وقت[SEP]یک فنجان قهوه بیو حش ت[SEP]انگیزه خودباوری ارامش عشق تایید و علم روانشناسی[SEP]مرکز پایتخت کافهها رشد[SEP]کافهای نیمهشب[SEP]دوه مک ار[SEP]کار و بار کافه[SEP]کافه رفتن[SEP]مکانهای عمومی یکدیگر[SEP]پشت قاب شیشهای کافه[SEP]قید کافه[SEP]قابهای چوبی لذیذترین
# 30th  corpus with score 0.67:
#  مشاهدات میدانی از آی سی یو بخش ویژه در بیمارستان امام حسین (ع) جا رسیدگی کامل[SEP]داروی ارامبخش[SEP]وضع تصور دشواریهای کار بخش درمان[SEP]سر و صورت خیس[SEP]پایین امدن سن ابتلا[SEP]اغلب بیمارستانهای کشور[SEP]اتاق دیگر دو مرد[SEP]تعداد مریض رسیدگی بیشتری[SEP]دکتر و پرستار و راننده و حتی مسیول اسانسور بیمارستان[SEP]بوی درد تنهایی و مرگی[SEP]بخش ویژه[SEP]برخی اوقات نگهبانی[SEP]اضطراری بخش[SEP]بخش ایسییو[SEP]خانم سرپرست ار بخش ایسییو[SEP]بخش کاری[SEP]تنهایی درد و نفس کشیدن و مرگ[SEP]کمتر بدحال مبتلا[SEP]درگیری م[SEP]رویکرد کلی بیمارستان[SEP]مرد دوباره روشنایی خورشید[SEP]همین بخش ایسییو[SEP]وضع خیلی خراب[SEP]لباسهای ایزوله و لباسهای خودم[SEP]انتظار تختی خالی[SEP]نوشت بخش ایسییو[SEP]خالی شدن تخت هستند وضع خیلی خراب[SEP]تخت خالی[SEP]درد و دلهای کادر درمان[SEP]دستگاه ونتی لاتور نفس[SEP]بخش[SEP]کارمندهای ش[SEP]قول کادر درمان تختها[SEP]تعداد شیفته ا و حجم کارمان[SEP]بخش ما[SEP]دستگاه ونتی لاتور[SEP]سن ابتلا پایین[SEP]انتهای ان لوله[SEP]خیلیها[SEP]قسمت قبلا بخش ارتوپدی[SEP]خطابش[SEP]کادر درمان[SEP]ندیدهام فشار کاری[SEP]خستگی پرسنل[SEP]بخش بیشتر همراه[SEP]بدحال مبتلا[SEP]ساعتهای طولانی[SEP]فضای نیمه تاریک بخش فکر[SEP]تخت خالی ایسییو[SEP]زن اهسته درددل میکند راستش فشاری[SEP]ضخامت خیلی زیاد[SEP]مبتلا[SEP]بخش دیگری[SEP]خانه خواهرم و میایم بیمارستان[SEP]بخش دور[SEP]پیک اول بخش ما[SEP]بخش بیرون[SEP]تنفس تنگی نفس تنهایی ونتی لاتور[SEP]رعایت کردن کار دیگری[SEP]سختیها و فشار کار دمار[SEP]موج سوم مرگ و میر روزانه پاییز و زمستان پرخطر و موج سوم مرگ و میر روزانه پاییز و زمستان پرخطر و موج سوم مرگ و میر[SEP]همین بخش[SEP]بخش خدمات[SEP]مایه دلگرمی[SEP]کارمندان بخش روابط عمومی[SEP]غذا خوردن و کمک[SEP]مسیولان روابط عمومی بیمارستان[SEP]بخشی[SEP]مسیولان بیمارستان[SEP]همان دستگاه ونتی لاتور کذایی[SEP]خیلی جاهای دنیا[SEP]مرد پنجاه و چند سالی[SEP]من روزها واقعا سخت گذشت همسر و دو بچه[SEP]راهروی بخش[SEP]همه بخشهای درمان
# 31th  corpus with score 0.67:
#  سه مخاطره در ماه‌های آینده برخی مردم با ماسک مشکل دارند پروتکلهای بهداشتی[SEP]عین حال[SEP]ثبات نسبی
# 32th  corpus with score 0.67:
#  ماجرای هنوز تمام نشده است دستمال حولهای یکبار مصرف[SEP]جای ممکن[SEP]نظر بروز علایم شدید[SEP]زمان شیردهی[SEP]برخی افراد علایم[SEP]گفت و گو بنشیند سربازی[SEP]متخصص زنان و زایمان[SEP]صورت نداشتن علایم[SEP]متخصص زنان و عضو[SEP]ویزیتهای مراقبت بارداری[SEP]حال انتشار[SEP]سالمندان افرادی[SEP]خطر زایمان زودرس[SEP]افراد بسیار اهمیت[SEP]سایر افراد[SEP]تنگی نفس[SEP]پروتکلهای بهداشتی ابتلا[SEP]بهبودی مادر مراقبت[SEP]بارداری استامینوفن[SEP]عفونت ریه کمبود اکسیژن رسانی مشکلات قلبی[SEP]راهکار شکست دادن[SEP]جدی گرفتن رعایت دستورالعملهای بهداشتی و جلوگیری[SEP]زایمان زودرس[SEP]خانمهای باردار[SEP]سایر مشکلات زمینهای[SEP]نوع شدید[SEP]بهترین راههای کاهش انتشار[SEP]زمان شیردهی مراقبت[SEP]کاهش انتشار ان[SEP]در خانم‌های باردار[SEP]تب سرفه و تنگی نفس ناشی[SEP]ماسک و رعایت پروتکلهای بهداشتی[SEP]نیز امکان زایمان طبیعی[SEP]افزایش مبتلایان به و مرگ ناشی[SEP]سالمند و جوان و کودک نمیشناسد موضوعی[SEP]زایمان یا سزارین[SEP]جهت کاهش انتشار[SEP]اکثر افرادی[SEP]مورد یادداشتها مقالهها و گزارشهای بسیاری[SEP]شرایط زایمان[SEP]ایا خانمهای باردار[SEP]سر زمینیان[SEP]عفونت ریه[SEP]عفونت ریهها[SEP]پرسش علایم شامل تب سرفه تنگی نفس[SEP]ایا ویزیتهای مراقبت بارداری
# 33th  corpus with score 0.67:
#  چگونه با ضعف عضلانی پس از مقابله کنیم؟ برای بههمراه[SEP]بهبودی عوارضی[SEP]قدرتی زیرنظر
# 34th  corpus with score 0.67:
#  سرایت در قم سه تا پنج برابر افزایش یافته است سه تا پنج برابر افزایشیافته[SEP]میزان سرایت[SEP]اخر شهریورماه[SEP]رسیده_است بابیان[SEP]جهش میزان سرایت افزایشیافته[SEP]اواخر میزان تستهای مثبت[SEP]حداکثر اشتغال تختهای بیمارستانی[SEP]مجوزهای تولید ماسک[SEP]در بیمارستانهای استان[SEP]بخشهای مراقبت ویژه[SEP]رییس بابیان
# 35th  corpus with score 0.67:
#  شمار مبتلایان در کشور از ۱۰۷ هزار نفر گذشت ۵۱ تن دیگر جان باختند استانها بویژه[SEP]روزهای اتی[SEP]۵۸۶ هزار و ۶۹۹ ازمایش تشخیص[SEP]و همچنین وضعیت بغرنجی
# 36th  corpus with score 0.67:
#  دندان‌درد در اوضاع  مطب یا درمانگاه[SEP]کشورهای دنیا[SEP]منابع مدرسه دندانپزشکی web md[SEP]تمام مراحل ضدعفونی دستگاهها[SEP]مشکلات حاد دندانی[SEP]معضل دامنگیر بسیاری[SEP]دو تا حد امکان وسایل[SEP]مطبها درمانگاههای[SEP]درمانگاههای دندانپزشکی[SEP]مشکل دندانی جدی[SEP]دستمالهای دوران داخ[SEP]درباره احتمال تنفسی[SEP]تمام سطوح بهویژه ابزارها[SEP]درمان فوری[SEP]زمان مناسبتر دیگری[SEP]زمان مناسبتری[SEP]اسپری شدن بزاق دهان یا خون میشود اتفاق[SEP]خطرناکترین مراکز درمانی[SEP]چکاپ سفید کردن دندانها جرمگیری[SEP]اطمینان همه دندانپزشکان موقع کار بهویژه[SEP]پیشفرض رعایت نکات بهداشتی[SEP]ویزیت کارهای دندانی
# 37th  corpus with score 0.67:
#  تمدید محدودیت‌های در تهران تا پایان هفته آینده فرمانده عملیات مقابله[SEP]مراکز درمانی و بهداشتی دانشگاه خدمات ویژهای[SEP]بخشهای ویژه[SEP]بیمارستانهای عدد قابل توجهی[SEP]شرایط سخت و شکننده[SEP]کاری قابل توجه و مضاعفی
# 38th  corpus with score 0.66:
#  توصیه‌های به زنان باردار سایر دوران زندگی[SEP]منصوری ازمایشهای تشخیصی[SEP]نغمه پزشک متخصص زنان و زایمان[SEP]سایر نوزادان[SEP]در اوایل تولد نوزاد[SEP]کمترین میزان خود[SEP]سایر ایام زندگی انها[SEP]طریق زنان باردار[SEP]خبرنگار حوزه بهداشت و درمان[SEP]دوران بارداری[SEP]نوزاد[SEP]زنان باردار و همسران انها[SEP]طور همزمان[SEP]عدم رعایت نکات بهداشتی[SEP]درمان مصرف داروهای حاوی کورتون[SEP]مراقبتهای وقت زایمان و موضوع شیردهی[SEP]درباره نوزادان و مادران مختلف[SEP]پزشک متخصص زنان و زایمان احتمال بروز عوارض و ابتلا به[SEP]نوزادان اسیب[SEP]بروز‌های حاد تنفسی و خارج کردن جنین[SEP]پزشک متخصص زنان و زایمان[SEP]سایر افراد[SEP]در دوران بیشتر[SEP]زمان مناسب[SEP]موارد پزشک و کادر درمان[SEP]فوت نوزاد[SEP]حفظ جان مادر پزشکان[SEP]بعد و همچنین هنگام زایمان انها[SEP]کمترین خطری دوران[SEP]پزشک معالج و کادر درمان[SEP]ابتلای زنان باردار[SEP]ضرورت صبوری و همراهی زنان باردار[SEP]امکان ابتلای زنان باردار به‌های مختلف[SEP]سطح نزدیکی نوزاد تازه[SEP]تحقق امر مستلزم خود مراقبتی و همچنین مراقبت همراهان او[SEP]نوزاد انها[SEP]پیشرفت علم پزشکی[SEP]منع کامل شیردهی[SEP]نیاز[SEP]کادر درمان[SEP]پزشکان و متخصصان حوزه زنان و زایمان[SEP]حساسیت بدنی زنان[SEP]وجود گرانبها و ارزشمند یک مادر[SEP]حد قابل قبولی کسب کردهاند منصوری[SEP]تاکید پزشکان و کادر درمان[SEP]نکات بهداشتی[SEP]شستشوی مرتب دستها استفاده[SEP]سیستم ایمنی بدن سایر زنان[SEP]پزشک متخصص زنان و زایمان حفظ ارامش و خونسردی استراحت کافی و مفید مصرف مایعات فراوان و داشتن رژیم سرشار[SEP]مشکلات تنفسی و همچنین کاهش رشد جنین[SEP]تحقیق پزشکان متخصص[SEP]عنوان بهترین مراقب و همراه افراد[SEP]نوزاد افراد[SEP]رعایت نکات بهداشتی[SEP]پزشکان[SEP]سوی زنان باردار[SEP]کادر درمان تلفات‌های واگیر[SEP]زنان باردار[SEP]ازمایشهای سلامت جنین[SEP]نوزادان نارس[SEP]خستگی پزشکان و پرستاران[SEP]نوزادان بسیاری
# 39th  corpus with score 0.66:
#  چرا برخی از افراد بهبودیافته دوباره می‌گیرند؟ تعداد مبتلایان چند روز[SEP]ازمایش شان مثبت اعلامشده[SEP]حال حاضر[SEP]افراد دوباره[SEP]تب شدید و سایر علایم مشابه انفلوانزا[SEP]حال بررسی موضوع[SEP]مورد افراد مبتلابه[SEP]تجربه از بین رفتن حس بویایی و چشایی کهیر زدن و برخی دیگر[SEP]همه علایم باهم[SEP]تعداد علایم مرتبط با و افزایشیافته[SEP]تعداد مبتلایان
# 40th  corpus with score 0.66:
#  چند برش کوتاه از تأثیر اپیدمی بر زندگی روزمره زنان افزایش تعداد مبتلایان به سفت و سخت[SEP]تاکنون روال زندگی روزمره[SEP]اعضای خانواده[SEP]امور بچهها[SEP]حقوق شرکتی[SEP]زیست روزمره زنان[SEP]بروز برخی تنشها[SEP]سوی بچهها و محل کارش[SEP]تحتتاثیر برداشتهای نادرست جنسیتی زنان[SEP]مهمترین تغییرات زندگی روزمره[SEP]دست من و همکارانم[SEP]مسیولیت مراقبت[SEP]بازه زمانی یکمیلیون و ۲۰ هزار فرصت شغلی[SEP]حوزه اموزش بچهها همسرم[SEP]همه اعضای خانواده اموزش فرزندان و اصولا وظایف و تکالیفی[SEP]نقش اجتماعی زنان[SEP]اغاز شد‌ها معمولترین[SEP]اجراکننده دستورالعملها و ابلاغهای اداری[SEP]وقت و هزینه رفتوامد[SEP]افزایش بار مسیولیتها[SEP]شرایط کنونی[SEP]میان زنان[SEP]پیامدهای کمتر دیدهشده بازتولید مسیولیتها و نقشهای[SEP]زمان بیشتری[SEP]میان زنان تحتتاثیر باورها و دیدگاههای نادرست جنسیتی حاکم[SEP]انچنان گسترده[SEP]افراد تصور چشمانداز زندگی[SEP]زمان از دست رفته تغییر سازوکار اموزشی دانشاموزان[SEP]زمان و محدودیتهای اعمال شده[SEP]شرایط و سبک زندگی[SEP]شرایط پرتنش کنونی پیامدهای اجتماعی[SEP]کلاس زبان یا باشگاه ورزشی[SEP]بهدلیل مسیولیت تازه زمان بسیار محدودی[SEP]همه مشکلات و نگرانیهای تازهای[SEP]بچهها و مادرشان[SEP]سوالات درسی بچهها و مشکلاتشان[SEP]گذشته_شود و بتوانیم یک نفس راحت[SEP]پیامدهای نگرانکنندهای[SEP]مدیرمالی شرکت راحت اب پاکی[SEP]دیگر اعضای خانواده[SEP]زنان مسیولیتهای جدیدی[SEP]تجربه درس دادن[SEP]زمینه مناسبی[SEP]اداره اجتماعی فرزندانشان[SEP]زندگی همه گروههای جامعه
# 41th  corpus with score 0.66:
#  ابتلاهای خانوادگی  مجددا کنترل میشود محرز[SEP]همراهی مردم[SEP]امدها و دید و بازدیدها[SEP]عین حال[SEP]حال حاضر[SEP]محرز درباره وضعیت بیمارستانهای و احتمال کاهش تاباوری مراکز درمانی[SEP]چند ماه اخیر[SEP]تجربه کادر درمانی[SEP]قدرت و همراهی و دوش[SEP]نمیتوان نیروهای درمانی[SEP]طریق رعایت دستورالعملهای[SEP]ابتدای بیمارستانها[SEP]کادر درمانی[SEP]تعدادی هم بد حال
# 42th  corpus with score 0.66:
#  درگذشت یک استاد دانشگاه بر اثر  برگی برای[SEP]برای ترجمه[SEP]ترجمه اشاره
# 43th  corpus with score 0.66:
#  علایم تهدید کننده سلامت روان در دوران  افسردگی اضطراب[SEP]کوچکترین حرف و یا مخالفتی[SEP]حفظ ارامش خود و اطرافیانمان افکار مزاحم[SEP]رفتارهای وسواس گونه و افکار مزاحم[SEP]خرابیهای زیادی[SEP]رعایت بهداشت فردی[SEP]مداخلات درمانی[SEP]سرعت تحمل تان[SEP]تبعات مختلف و اثرات زیادی[SEP]کوچکترین حرف و مخالفتی[SEP]یکبار استفاده[SEP]بودن استرس مضاعف‌تری[SEP]مداخلات روان درمانی و یا مشاورهها[SEP]اسپری ضدعفونی کننده[SEP]بسیاری عوارض و علایم بکاهد[SEP]ایجاد ارامش[SEP]فرد بیدار و اشکار و فرد
# 44th  corpus with score 0.66:
#  واکسن هنوز هیچ نتیجه قطعی نداده است طریق فضای مجازی[SEP]مسیر سلامت الکترونیک[SEP]پرونده سلامت الکترونیک[SEP]برخی بخشها نعوذ[SEP]سلامت الکترونیک[SEP]برخی بخشها[SEP]کار سخت[SEP]یک نفس راحت و لبخند[SEP]برخی بخشها نعوذ با[SEP]در موج دوم استانهای زیادی[SEP]مراکز درمانی[SEP]کار دادن مرخصی[SEP]انجام امور مردم[SEP]دولت الکترونیک مردم[SEP]نمودارهای استانی یک میلیمتر
# 45th  corpus with score 0.66:
#  خاموشی جدی است؟ صحت سقم برخی اخبار اطلاعات جدید[SEP]احتمال انتقالش ان[SEP]تازهترین اخبار نگرانکننده انتشاریافته[SEP]احتمال زایی بعد[SEP]موج جدید نگرانیها[SEP]صورت اسیب جدی ریه[SEP]موارد شدید درگیری ریه[SEP]موج بعدی[SEP]احتمال زایی[SEP]ابتلای مجدد[SEP]مدت عالمگیر[SEP]موارد شدید[SEP]افزایش احتمال انتقال موثر[SEP]امکان انتقال[SEP]بهصورت نما یا کدورت گراند گلاس[SEP]مورد ایمنی طولانیمدت[SEP]وجود یافته جدید مبنی[SEP]بهطور کلی افراد مختلف[SEP]حتی افرادی[SEP]بسته شدن دفتر کو وید[SEP]سیتیاسکن مجدد ریه[SEP]سرماخوردگی[SEP]چند ماه گذشته_است نمیتوان[SEP]تداوم انتشار چنین اخباری[SEP]شیشه مات[SEP]مشکل اولیه شدید قلبی ریوی[SEP]دکتر فوقتخصص عفونی اطفال عضو[SEP]خطر اسیب جدی ریوی[SEP]دلیل وجود ذرات ار ان ای[SEP]شواهدی مبنی[SEP]بهبودی اسیبهای ریوی ماندگار[SEP]مورد ابتلای مجدد[SEP]ناگوار ترسناک جدید[SEP]احتمال انتقال[SEP]جدیدترین مطالعاتی[SEP]وید[SEP]ایا بهبودی کامل[SEP]معرض اسیبهای شدید ریوی ناشی[SEP]ارایه اطلاعات دقیق مستند[SEP]موید ان[SEP]کم بودن خطر انتقال[SEP]افکار عمومی مردم[SEP]مواردی[SEP]بهبودی[SEP]افراد اختلال مختصر عملکرد ریه[SEP]علامت دار[SEP]بهطور خفیف[SEP]بهبودی رادیوگرافی[SEP]دچار عارضه مشکل ریوی درازمدت[SEP]شواهد کنونی[SEP]درصد اشباع اکسیژن او[SEP]پاسخ انتیبادی متفاوتی
# 46th  corpus with score 0.66:
#  چند نکته ضد برای دانش‌آموزان دانش اموزان[SEP]یکسری نکات و مسایل بهداشتی[SEP]سایر دانش اموزان[SEP]لباسهای مدرسه[SEP]لباس مدرسه[SEP]درب دار بیندازید - کیف و لباس مدرسه خود
# 47th  corpus with score 0.66:
#   بین جوانان ایرانی بیش از چینی‌ها درجههای مختلف[SEP]تجویز دارو[SEP]یک بیمارستان مشخص[SEP]سبب کاهش مقدار اکسیژن[SEP]ایا دستورالعمل مشخصی[SEP]مراحل درمانی مختلفی[SEP]همه توان خود[SEP]قسم پزشکی خود[SEP]بخش مراقبتهای ویژه[SEP]بهروزرسانی پروتکلهای بهداشتی[SEP]ازسوی مراکز پزشکی[SEP]بازهای دیگر داروی متفاوتی[SEP]حد مولکول و سلول داروهایی درحال بررسی و تولید[SEP]اندازه محققان و پژوهشگران درکشورهای جهان خود[SEP]جوانتر درحال دریافت خدمات درمانی[SEP]برخی دستاوردهای پزشکی مقابله[SEP]مراحل بعدی تغذیه و استفاده[SEP]سوی پزشکان[SEP]سوی کادر درمانی[SEP]درگیری کامل بدن فرد[SEP]عملکرد مناسبی[SEP]موج شدید و همچنین روشها و دستورالعملهای درمان[SEP]دلیل تفاوت[SEP]مراحل اولیه داروی هیدروکل روک ین[SEP]داروهای مختلف[SEP]اختیار محققان و مراکز پزشکی[SEP]درمان بهتری[SEP]بهدلیل ساختارهای ژنتیک درمان قطعی[SEP]ازکشورهای مختلف[SEP]مجلات معتبر جهانی[SEP]اختیار همه[SEP]کادر درمانی[SEP]پروتکلهای درمان[SEP]کادرهای پزشکی کشور[SEP]کادر پزشکی سراسر کشور[SEP]از سوی پزشکان[SEP]گروههای پزشکی کمم یا ورند و روند درمان[SEP]اختیار بودن دارو تجویز استفاده[SEP]برخی کشورها افراد[SEP]داروهای مختلفی[SEP]بیشتر افراد مسن[SEP]دکتر پزشک فوق تخصص مراقبتهای ویژه و استاد[SEP]تجویز داروها بهدلیل[SEP]همه روشهای و داروهای درمانی کماثر و بیاثر[SEP]تختهای بیمارستان ما[SEP]یک مسیول نمیبیند بیمارستان بیمارستانی[SEP]ساختار باکتریها و شناخت دقیقتر انها[SEP]بیمارستان دیگری[SEP]مراکز بیمارستانی[SEP]بیمارستان بهدلیل ابتلا[SEP]افراد پیر و جوان یا مسیولان دولتی[SEP]مهمترین مراکز بیمارستانی پایتخت[SEP]نیز براساس یافتههای جهانی دارو[SEP]ارایه خدمات درمانی[SEP]درمان اکسیژنرسانی[SEP]مقابل باکتریها[SEP]برخی محدودیتهای[SEP]برخی نتایج علمی و دانشگاهی[SEP]نظر برخی داروها
# 48th  corpus with score 0.66:
#  توصیه‌های؛ کودکان را با خودتان به مراکز خرید نبرید دست زدن[SEP]خرید دستکش خود[SEP]کیسههای پلاستیکی انها[SEP]پول نقد[SEP]رعایت نکات بهداشتی[SEP]کیسههای پلاستیکی[SEP]کارت بانکی[SEP]یک سری نکات بهداشتی[SEP]منزل کارت بانکی خود
# 49th  corpus with score 0.66:
#  در موج سنگین به سر می‌بریم نمی‌دانیم در فصل سرد چه اتفاقی می‌افتد اتفاقات غیرقابل پیشبینی[SEP]کوتاه مدت بسیار دشوار[SEP]حال حاضر[SEP]همراه و چند کشور دیگر[SEP]دستگاه تنفسی[SEP]فصل سرما[SEP]دستگاه تنفسی دستگاههای دیگر بدن[SEP]امکانات بیمارستانی و مراقبتهای ویژه[SEP]تشریح سیاست دوم سیاست سرکوب
# 50th  corpus with score 0.66:
#  آیا واکسن نیاز به بازطراحی خواهد داشت؟ موارد ابتلای مجدد بهبودیافتگان[SEP]ابتلای مجدد بهبودیافتگان[SEP]واکسن انفلوانزا واکسن[SEP]ابتلای مجدد
# 51th  corpus with score 0.66:
#  آمار دوباره اوج گرفت موج پاییزی زود از راه رسید روند رعایت پروتکلهای بهداشتی و استفاده[SEP]رها شدن پروتکلهای بهداشتی[SEP]رعایت پروتکلهای بهداشتی و استفاده[SEP]کنترل اپیدمی تجربه هفت ماه گذشته[SEP]موج پاییزی[SEP]روزهای سرد پاییز و زمستان[SEP]فکر پزشکان و پرستارانی[SEP]تجمعات غیرضروری و رفتارهای غیر بهداشتی[SEP]سوی برخی[SEP]فضاهای بسته و پرجمعیت و همچنین تماس نزدیک[SEP]رها کردن پروتکلهای بهداشت[SEP]رعایت پروتکلهای بهداشتی[SEP]پروتکلهای بهداشتی[SEP]فاجعه جدید پروتکلهای بهداشتی[SEP]میزان رعایت پروتکلهای بهداشتی
# 52th  corpus with score 0.66:
#   خطرناک‌تر شده است پیر جوان نمی‌شناسد خانه بمانیم[SEP]ترددهای غیر[SEP]غیر ضروری
# 53th  corpus with score 0.66:
#  برای آنها که اضطراب ابتلا به دارند! منابع معتبر[SEP]یک بازه زمانی خاص یا مطالعه تعداد مشخصی[SEP]قرار دادن روشهای مراقبت[SEP]نگرانیهای سلامت روانی[SEP]یک متخصص سلامت روان[SEP]دنبال کردن یک رژیم غذایی سالم[SEP]درباره سلامت و بهزیستی روانی[SEP]مشکلات سلامت روانی و روانی اجتماعی[SEP]سرعت یا تعداد افراد صحبت[SEP]احساس ترس اضطراب غم و عدم اطمینان[SEP]افراد بسیاری اقداماتی[SEP]اتخاذ اقدامات پیشگیرانه[SEP]اب جاری و صابون و محدود کردن ترددهای شهری یا مسافرتهای برون شهری[SEP]سلامت روانی شما[SEP]شناخت مواردی[SEP]افزایش اضطراب[SEP]متمرکز شدن[SEP]افزایش افسردگی و اضطراب[SEP]وجود منابع معتبر رسانهای[SEP]حفظ سلامت روانی و جسمانی[SEP]موردی ناشناخته[SEP]همه گیری یک میتواند محرکی[SEP]اخبار مضطرب کننده[SEP]خواندن خبرهای مختلف[SEP]مشکلات سازگاری افسردگی و اضطراب[SEP]انجام اقدامات مفید[SEP]مدیریت ترسها و نگرانیهای شما[SEP]مدیریت سلامت روانی[SEP]انجام اقداماتی[SEP]سخن پایانی بیشتر موارد همه گیری[SEP]مشکلات سلامت روانی[SEP]درباره سلامت روانی[SEP]افراد بسیاری افزایش نشخوار ذهنی[SEP]برخی شرایط سلامت روانی موجود[SEP]اتخاذ روشهای درمانی یا اقدامات پیشگیرانه[SEP]منابع معتبر و همچنین پرهیز[SEP]انجام اقدامات پیشگیرانه[SEP]بمباران نکردن خود[SEP]نگرانیهای سلامت روانی افزون[SEP]دورههای بروز تردید و عدم اطمینان[SEP]وخیمتر نشدن انها[SEP]اطمینان حاصل کردن[SEP]اتخاذ بهترین اقدامات[SEP]وجود افراد بسیاری توجهی[SEP]شرایط سلامت روانی فعلی افراد[SEP]مقامات بهداشت و سلامت[SEP]افسردگی و اضطراب برخی افراد[SEP]سوی منابع معتبر[SEP]صورت نیاز روشهای مدیریت استرس روشی[SEP]افراد بسیاری[SEP]کاهش خطر مد نظر
# 54th  corpus with score 0.66:
#  تفریح در ییلاق تهران اهالی اش[SEP]اعلامیه ترحیم چسباندهاند[SEP]ده به گردو و گیلاس ش[SEP]مدیریت شورا و دهیاری اطلاعرسانی[SEP]بومیهای زای گان[SEP]همین الان یادشان[SEP]اهالی روستاهای اطراف[SEP]هم رفتوامد میکنند جا خانه خاله و مادربزرگم[SEP]سنی ازم گذشته و شوهرم[SEP]همین اصلا[SEP]ماسک[SEP]طول مسیر کرکره[SEP]تمام ماسک[SEP]ماسک ش[SEP]روزهای شلوغ[SEP]برگهای طلایی زرد و نارنجی[SEP]دیگر روستاهای بخش[SEP]رستورانها نظارت نمیکند رستورانها اسمی[SEP]بیشتر اهالی ماسک[SEP]اهالی دو کیسه بزرگ گردو[SEP]بنرهای بزرگ ماسک[SEP]پاییز رنگارنگ روستاهای اطراف پایتخت[SEP]نزدیکترین بیمارستان[SEP]فاصله ۴۵ کیلومتری[SEP]ماسک شان[SEP]محدوده زای گان[SEP]یک مقداری ماسک[SEP]روزهای تعطیل[SEP]اهالی جا[SEP]طریق بنر و بروشورها[SEP]یک مغازه سبزی[SEP]اهالی روستای خودشان[SEP]خیلیها[SEP]زمانهایی ماسک رایگان پخش[SEP]شیشه رستورانش ان[SEP]اهالی روستاها[SEP]نداریم همان اوایل[SEP]اهالی ماسک[SEP]درگیرند ردیف مغازهها[SEP]طول مسیر میگویند زای گانی‌ها[SEP]اهالی[SEP]دیگر جاهای کشور[SEP]مدیریت خوب روستایشان[SEP]تعطیلیهای صوری[SEP]ماسک م[SEP]خیلیهایشان زندگی
# 55th  corpus with score 0.66:
#   در تاریکخانه برخی افراد[SEP]مراجعه حضوری داشته_باشند ایا[SEP]تشخیص پزشک معالج[SEP]مع ههای دورهای خطری[SEP]بررسیهای دورهای[SEP]تمام مراکز رادیولوژی[SEP]باردار اقداماتی[SEP]بررسی سلامت مادر جنین[SEP]بهعلاوه رعایت پروتکلهای بهداشتی[SEP]انجام سونوگرافی بارداری[SEP]تمهیدات مراقبتی جدیدی[SEP]پزشک معالج[SEP]دکتر درباره انجام مراقبتهای دوران بارداری[SEP]مع ههای دورهای رادیولوژی[SEP]رعایت نکات ایمنی بهداشتی[SEP]انجام سونوگرافی[SEP]حوزه رادیولوژی[SEP]بررسی رادیولوژی[SEP]تصویر برداری[SEP]احتمال بیشتر داشتن عوارض[SEP]بهای وخیم شدن یک عارضه قابل پیشگیری یا بهخطر افتادن جان تمام میشود روزنامه[SEP]مراقبتهای دوران بارداری[SEP]نظر پزشک معالج[SEP]درمان بررسی عود احتمالی پیشرفت بهصورت دورهای تجویز[SEP]روند درمان بازتوانی فرد اختلال[SEP]مراکز موسسات رادیولوژی[SEP]تن بررسیهای رادیولوژی[SEP]رعایت پروتکلهای ویژهای ضدعفونی[SEP]فشارخون دیابت افراد[SEP]بررسیهای دورهای چکاپ‌ها[SEP]زمانهای خلوت مراکز رادیولوژی[SEP]انجام سونوگرافی بخش مهمی[SEP]تمام موارد بررسیها[SEP]هر گونه خدمات القایی[SEP]تمام مراکز تصویربرداری فاصلهگذاری اجتماعی[SEP]مع ههای دورهای[SEP]هر گونه اقدام تصویربرداری[SEP]مراکز رادیولوژی
# 56th  corpus with score 0.66:
#  توصیه هایی برای پیشگیری از در زنان باردار خودداری زنان باردار[SEP]مدت کوتاه و محدود و به شرط رعایت نکات بهداشتی[SEP]تلفن مرکز درمانی خود اعم[SEP]حداقل میزان ممکن[SEP]ماندن زنان باردار[SEP]مراکز درمانی[SEP]مراقبتهای جنین مادران[SEP]اهمیت سلامت روان مادران باردار[SEP]مراقبتهای دوران بارداری مادران باردار[SEP]حضور غیرضروری زنان باردار[SEP]طول سفر زنان باردار[SEP]زنان باردار غیر طبیعی[SEP]پوران صاری زنان باردار[SEP]دکتر - متخصص زنان و زایمان و فوق تخصص حاملگی پرخطر[SEP]سنجش میزان افزایش وزن فشار خون و سلامت جنین[SEP]مرکز درمانی[SEP]صورت تمیز و مناسب بودن هوا[SEP]ارتباط زنان باردار[SEP]متخصص زنان باردار[SEP]امکانات بهداشتی و درمانی[SEP]سفر زنان باردار[SEP]سلامت زنان باردار و پیشگیری[SEP]توجه زنان باردار[SEP]شوند زنان باردار[SEP]دوره بارداری[SEP]وزن و فشار خون خود[SEP]هرگونه سفر و لزوم ماندن[SEP]تمام مراقبتهای بهداشتی ضروری[SEP]منزل تحرک داشته_باشند مصرف مایعات گرم[SEP]مادران باردار[SEP]اهمیت سلامت روان مادران باردار عضو هییت علمی[SEP]اب و صابون و یا اسپریهای ضدعفونی کننده[SEP]زنان باردار[SEP]حد وزن یا تورم دست و صورت[SEP]تهیه یک دستگاه فشار خون و ترازو[SEP]اطلاعات و اخبار درست[SEP]مادران باردار مراجعه
# 57th  corpus with score 0.66:
#  بستری ۱۵ کودک مبتلا به در بابل روند خدمت رسانی[SEP]حال خدمت رسانی[SEP]سالمندان و کودکان بیشتر[SEP]بیمارستان کودکان[SEP]خدمت رسانی[SEP]کادر درمانی
# 58th  corpus with score 0.66:
#  زایمان در منزل از ترس  کنار استرس زایمان[SEP]بهعنوان مثال بررسیهای دانشکده امریکایی متخصصان زنان و زایمان[SEP]احتمال برابر زنان باردار و بقیه شهروندان[SEP]احتمال مرگومیر مادر و جنین[SEP]طریق جفت و بند ناف تایید[SEP]زایمان[SEP]استرسها و دلنگرانی‌ها طبیعی[SEP]مانع فعالیت روزانهشان[SEP]تحمل اضطراب بیشتری[SEP]زنان باردار مبتلا[SEP]ماشینها و ادمها برایم[SEP]بند ناف و شیر مادر[SEP]مادران استرس و اضطراب[SEP]دوران زایمان[SEP]مراقبتهای بارداری[SEP]حفظ سلامت مادر و جنین[SEP]چه میزان[SEP]زنان باردار مشکوک به[SEP]دهای نامعلوم کودکی تازه[SEP]اطمینان خاطر به مادر و نوزاد[SEP]بهعنوان مثال مادر یا خواهری[SEP]احتمال ابتلا[SEP]دلواپسی مشترک مراجعهکنندگان باردار متخصص زنان و زایمان در[SEP]دوره نقاهت و بستریشدن کوتاهتری[SEP]شرایط زایمان[SEP]کارهای نظافت و اشپزی بپردازند[SEP]پروتکلهای بهداشتی و درمانی[SEP]٩ زن باردار[SEP]روز زایمان و احتمال مبتلا شدن[SEP]چیزی سلامت مادر و جنین[SEP]زنان باردار سالم[SEP]کل زنان باردار[SEP]بخش مادران سالم[SEP]صورت ابتلا یا ناقل بودن مادر[SEP]زنان باردار توصیه زایمان[SEP]متخصص زنان و زایمان[SEP]یکبار مصرف میبرد درمانگاه[SEP]دوران قرنطینه و دلواپسی الوده نشدن خود و فرزندشان[SEP]خدمات بیمارستانی[SEP]روابط اجتماعی[SEP]بیمارستان بارداری[SEP]طاووسی روانشناس نگرانیها و اضطرابهای دوران بارداری[SEP]عنوان نخستین سرزمین شهروندان کشور[SEP]تمام زنان باردار[SEP]زمان اندازهگیری[SEP]دلیل خطر درباره زایمان[SEP]بیشتر مراجعهکنندگان[SEP]زایمان طبیعی[SEP]احتمال الوده بودن هر کدام[SEP]مادر مبتلا[SEP]اوردن فرزندش[SEP]یک میزان[SEP]میزان سایر شهروندان[SEP]فاطمه متخصص زنان و زایمان استرسهای دوران بارداری و چالشهای بعد[SEP]بیمارستان خصوصی و دولتی[SEP]انتظار اولین فرزندش[SEP]الوده بودن بیمارستانهای دولتی[SEP]بقیه مادران[SEP]مهناز هفتماهه باردار[SEP]روی مراکز بهداشتی و اختلال[SEP]سلامت مادر و جنین تاثیر[SEP]دغدغه دیگر زنان باردار[SEP]رعایت فاصله اجتماعی و موارد بهداشتی[SEP]رقیه متخصص زنان و زایمان[SEP]شروع زندگی نوزادش[SEP]درحال برنامهریزی[SEP]موقعیت خاص میداند زنان باردار[SEP]زایمان نگرانی دیگر[SEP]جای ذوق مادرشدن[SEP]ماندن میزان مراجعه بهویژه مادران باردار یا افراد[SEP]درمانگاه و برگردیم کلی الکل[SEP]اغراق درباره شرایط و افکار منفی[SEP]غربالگری زنان باردار مبتلا یا ناقل[SEP]٤٢ ٧ زن باردار[SEP]فاصله اجتماعی و موارد بهداشتی[SEP]بیمارستان زایمان[SEP]در بیمارستان[SEP]شرایط زایمان و فکر[SEP]روز چند دقیقهای[SEP]بیشترین دغدغه و ترس زنان باردار در[SEP]دوران همهگیری خبر میدهند محمد[SEP]دوران قرنطینه است متخصص زنان و زایمان میگوید[SEP]مادران باردار[SEP]خطر بودن میلیونها مادر و نوزاد[SEP]تحمل سهماه قرنطینه دو هفته پیش[SEP]زمان تزریق واکسن سفرههای یکبار مصرف[SEP]دوران قرنطینه و روزهای فرزانه[SEP]فرزند اولش[SEP]مادران مبتلا[SEP]نگرانیهای مادرانه سهماه و نیم قرنطینه طاقت م[SEP]بیمارستان الوده[SEP]زایمان امنتر[SEP]حمایتهای حضوری نزدیکانشان[SEP]دورههای مهارتهای زندگی[SEP]چه میزان افزایش[SEP]تغییر زمان و نوع زایمان[SEP]همهگیری زنان باردار[SEP]در میان زنان باردار[SEP]دنبال راهکارهای جایگزین[SEP]نظر متخصص زنان و زایمان[SEP]اورژانس بیمارستانها خبر[SEP]استرس بالا و بیخوابی‌های مداوم او[SEP]بیمارستانها و مراکز درمانی[SEP]زمان بارداری اضطراب[SEP]دوران بارداری[SEP]میان هیاهوی همهگیری و درگیری بیمارستانها و کادر درمانی[SEP]همین زنان[SEP]روابط اجتماعیاش[SEP]قدیمیترین و بهترین روشهای زایمان[SEP]زایمان زودهنگام و سزارین[SEP]زمانی[SEP]همین نیاز[SEP]تمرکز بیمارستانها[SEP]نظر گرفتن تفاوتهای جغرافیایی جمشیدی[SEP]زمان زایمان م[SEP]واکنش فرزندم[SEP]دوران زنان[SEP]فکر زایمان[SEP]فهرست بلندبالای تحقیقات زنان باردار بهعنوان جامعه[SEP]زنان باردار[SEP]زنان باردار مراقبتهای ویژهای
# 59th  corpus with score 0.66:
#  راهکارهایی برای بازگرداندن حس بویایی بعد از درمان + فوگرافیک بویایی دچار[SEP]بهبودی نیز[SEP]عصاره‌ها نیز
# 60th  corpus with score 0.66:
#   همچنان جدی است مطالعه شاخصهای همهگیری شناسی[SEP]۶۵۸ هزار و ۶۰۴ ازمایش تشخیص[SEP]روزها و هفتههای گذشته[SEP]پزشکان و سختتر و یک مساله جدی[SEP]روزهای اخیر[SEP]ان رعایت نکات بهداشتی و فاصله گذاری فیزیکی[SEP]گستره شناسایی موارد خفیف و سرپایی[SEP]افزایش موارد بروز و بستری[SEP]گرفتن نکات بهداشتی و بیتوجهی[SEP]رعایت نکات بهداشتی[SEP]روزهای اتی[SEP]احتمال افزایش نه بهشدت مراحل اول[SEP]تفاوتهای انفلوانزا و برخی عنوان[SEP]کاهش موارد بستری و سرپایی[SEP]رعایت مسایل بهداشتی روند[SEP]ماسک و محلولهای ضدعفونیکننده و شستوشوی دستها[SEP]فاز دوم و سوم اپیدمی و جهش در و و نگرانیها
# 61th  corpus with score 0.65:
#  ماجرای خانواده‌ای ۲۰ نفره که نفر از آن‌ها گرفتند اعضای خانواده[SEP]زمان خبر ترسناکی[SEP]شروع موج دوم[SEP]دلیل تشخیص دیرهنگام نزدیک[SEP]شکل حضوری[SEP]خانواده همسرش[SEP]سه طبقه خانوادهای ۲۰ نفره و[SEP]مهمان خانه خانواده[SEP]حدود ساعت دو نیمه شب[SEP]راننده تاکسی[SEP]ازمایش مادربزرگ و دیگر عمه او[SEP]عضو ۲۸ ساله خانواده[SEP]بیمارستان مرخص[SEP]عکس ازمایش همسر و مادرم[SEP]بیمارستان دیگری[SEP]خانه خانواده[SEP]خانواده ۲۰ نفره[SEP]شنیدن صدای سرفه و ویزیت پزشک[SEP]پیشنهاد یکی[SEP]برگزاری امتحانات[SEP]راه خانواده و روزهای خانواده[SEP]همراه خانوادهاش[SEP]یک بیمارستان خصوصی[SEP]مراکز خرید و مغازهها[SEP]سراغ همان پزشک[SEP]انتیبیوتیک تجویز میکند گونه روزهای پنهان
# 62th  corpus with score 0.65:
#  خرید کنید اما را به خانه نبرید! مراکز خرید[SEP]رعایت نکات بهداشتی[SEP]اعلام نکات بهداشتی[SEP]مراکز خرید جدا[SEP]نکات بهداشتی
# 63th  corpus with score 0.65:
#  توصیه‌های پیشگیری از برای زنان باردار انها و یا انتقال الودگی به تازه مادر[SEP]شفقنا دکتر متخصص زنان[SEP]تغذیه زنان باردار[SEP]یکباره بیست ملاقات کننده[SEP]درباره زنان باردار[SEP]زنان باردار[SEP]دکتر یک متخصص زنان زمان ملاقات[SEP]متخصص زنان[SEP]سیستم ایمنی بدن زنان باردار
# 64th  corpus with score 0.65:
#  چگونه در محیط کار از در امان بمانیم؟ خود مشتریان و مراجعین[SEP]صورت داشتن علایم شبه سرماخوردگی[SEP]تب سنج الکترونیک[SEP]مانع انتشار شوند اطلاع رسانی و یاداوری کارمندان[SEP]کارکنان اموزش د ھ ید[SEP]ھ یه یک چارچوب و برنامه[SEP]ارباب رجوع ھم ا[SEP]محیط کار و در امان ماندن[SEP]چه کار ھای[SEP]محیط کار و مراقبت[SEP]دسترس ھم ه کارکنان و مراجعین[SEP]دسترس ارباب رجوع[SEP]تب سنجی الکترونیک[SEP]تذکر شفا ھ ی ھم[SEP]ورود مراجعین تب دار[SEP]ماموریت ھا و سفر ھای کاری[SEP]وسایل بھ داشتی وجود صابون و مواد ضدعفونی کننده کافی[SEP]درصورت رد و بدل کردن مدارک پوشه خودکار یا ھ ر[SEP]اضافه شدن مشتریان و کم شدن فاصله[SEP]دستگاه کارتخوان[SEP]رعایت برخی نکات[SEP]فاصله فیزیکی[SEP]استام پ یا دستگاه الکترونیک ثبت اثر انگشت محلول ضد عفونی[SEP]میزان ساعت ھای کار[SEP]خودمراقبتی شرایط فعلی[SEP]محیط کار[SEP]فروشگاه ھای بزرگ و زنجیرهای مع ه مشتریان[SEP]محافظت خود و مشتریان یا مراجعین[SEP]یاداوری شفا ھ ی نکات[SEP]تجمع ارباب رجوع[SEP]محصولات کارتخوان و وسایل بهداشتی[SEP]محل کار نی د و توصیه جدی[SEP]سلامت مراجعین[SEP]اموزش شستشوی دست رعایت فاصله عدم تماس دست ھا[SEP]صورت امکان محلول ضدعفونی[SEP]مانند بخش مغازه ھا و سوپرمارکت ھا اصول ضروری[SEP]شناسایی و جداسازی موارد مشکوک[SEP]یاداوری موضوع درمحل کسب[SEP]رعایت فاصله[SEP]دستگاه کارتخوان تلفن ھا موبایل ھا و سایر اشیا ھم منشا الودگی ھ[SEP]انجام کار غذا[SEP]کارمندان و بین کارمندان و مشتریان[SEP]یاداوری شستشوی صحیح دست ھا رعایت فاصله[SEP]رعایت فاصله کارمندان[SEP]رعایت برخی موارد[SEP]ارباب رجوع[SEP]پله برقی اسانسور ھا عابربانک ھا و کلیه سطوح قابل تماس[SEP]افراد برحسب نوبت و یکی[SEP]کار ھای ضروری[SEP]کارتخوان تلفن و موبایل خودکار و سایر وسایلی[SEP]ضدعفونی میز تلفن ھا موبایل ھا صفحه کلید موس و پد موس و سایر اج زای کامپیوتر ھا[SEP]یچ کد ام نابغه کارنی[SEP]سایر مراجعین و کارکنان
# 65th  corpus with score 0.65:
#  قبل از دادن تست با پزشک متخصص مشورت کنید دو تفاوتهای عملکردی و تشخیصی ویژهای[SEP]دو بررسی متفاوت[SEP]رد تنگی نفس سردرد یا عوارض گوارشی[SEP]یک متخصص عفونی باتجربه[SEP]تست ارزانتر و اسانتری[SEP]مسیر بپرهیزیم دو تست همانطور[SEP]مسیر خودت ش[SEP]موید قطعی وضع سلامت یک فرد[SEP]شرایط سخت اقتصادی کنونی نهتنها[SEP]هر یک نمیتواند جایگزین دیگری[SEP]تستها و تجویزهای متنوع و دوا و درمانهای خانگی[SEP]مسیر جستوجو[SEP]مراکز درمانی[SEP]دو نوع تست سرو لوژی ( خون ) و تست پیسی ار[SEP]میان دو تست سرو لوژی و پیسی ار معمولا تست سرو[SEP]دستورالعملهای و همچنین گفتوگو[SEP]میرسد اما سوال جاست ایا تست سرو لوژی اطمینانبخشی کافی[SEP]دست فرد مشکوک
# 66th  corpus with score 0.65:
#  چگونه از چشم‌ها در برابر محافظت کنیم؟ لمس کنید[SEP]عینک حالتی[SEP]حالتی محافظتکننده
# 67th  corpus with score 0.65:
#  به مردم بگویید قبل از خروج از ووهان تست داده‌ایم در سلامت کامل هستیم بیمارستانها[SEP]دریای شیر غرق شده_باشی[SEP]شبکههای اجتماعی[SEP]اتفاقات یک شهر ارام و ساکت[SEP]اب شیر اشامیدنی[SEP]خانههای بچهها رساندم[SEP]تعداد فوت شدهها[SEP]مردم شهر[SEP]یک شهر دانشجویی[SEP]تقریبا مشابه[SEP]کشورهای و هم رسیده_است سینا دانشجوی بیزینس[SEP]قول خودشان روزها[SEP]همه شهر[SEP]سلامت غذاهای انبار مطلع شدید و چه مواد غذایی[SEP]بیشترین ترس ما[SEP]در کشور همدلی و اطلاعرسانی[SEP]یک انبار[SEP]چنین شرایط غیر قابل پیش بینی[SEP]یک بیمارستان بزرگ[SEP]کشورها[SEP]استرس برگشتن به و نوع واکنش مردم[SEP]دو دانشجوی ایرانی شهر[SEP]یک منطقه شهر[SEP]همین شهر[SEP]بیمارستان[SEP]یک انبار در[SEP]رستوران و بگویی سوپ خفاش[SEP]وضعیت بدتری[SEP]همه جای شهر[SEP]رسانههایشان[SEP]روزبهروز وضعیت[SEP]او و دیگر دانشجوها[SEP]و۱ ۱ میلیون جمعیت[SEP]شبکههای خبری مختلف و شبکههای اجتماعی[SEP]تعداد انگشت شماری سوپرمارکت[SEP]اولین بار[SEP]دربارهاش[SEP]پیدا کردن غذا سراغ انبارها[SEP]شهر مسلمانان زیادی[SEP]قرنطینه ۱۱ میلیون جمعیت محبوس خیابانهای خالی دود مغازههای[SEP]بچههای سفارت[SEP]خوردن غذاهای عجیب و غریب[SEP]شهر[SEP]تنها راه پیشگیری[SEP]دانشجویان ایرانی بستههای غذایی[SEP]یک بازار محلی فروش غذاهای دریایی[SEP]سوپ خفاش و چیزهای مشابه[SEP]بویژه انهایی[SEP]ریشه کن شدن[SEP]قرنطینه استرس ش[SEP]همه محدوده شهری[SEP]اواره کوچه و خیابان[SEP]قرنطینه شهر[SEP]سمت هانک و زندگی[SEP]پریشانی شهر[SEP]نم ده دانشجویان ایرانی[SEP]گیر افتادهاند انها[SEP]پیش برد کارها[SEP]شهر حکومت نظامی[SEP]رستوران و هتل بیرون[SEP]سوپ خفاش[SEP]همه بیمارستانها[SEP]موبایل و شبکههای اجتماعی[SEP]مراحل اداری پیچیده‌اش[SEP]راننده اتومبیل[SEP]عادت مردم شهر[SEP]موتور بی د سمت ما[SEP]دانشجوهای ایرانی[SEP]هشدار[SEP]سطح شهره یچ[SEP]شهری[SEP]مغازهای دور و برشان[SEP]بیمارستان تون جی و بیمارستانهای دیگر
# 68th  corpus with score 0.65:
#  هر عارضه‌ای رابه ربط ندهید عفونتهای ادراری تنفسی غیر گوارشی پوستی و یا مفاصل[SEP]مراکز درمانی و بهداشتی تمهیدات لازم[SEP]نشانههای ابتلا[SEP]نیاز مند بررسی و مراجعه متعدد[SEP]دلهره و نگرانی وضعیت سلامت فرد[SEP]بیمارستان خود[SEP]علایم تنفسی[SEP]قطعا و همچنان علایم اصلی و تنفسی[SEP]درمانهای مناسبی[SEP]سله‌ای کبدی و یا هپاتیتهای عفونی[SEP]درصورت عدم مراجعه اثرات جدی و جبران ناپذیری[SEP]مراکز درمانی[SEP]بیمارستانها و مراکز درمانی[SEP]عضو هییت علمی دانشگاه مراجعه[SEP]دنیا تغییری[SEP]تنگی نفس علایمی[SEP]علایم طولانی
# 69th  corpus with score 0.65:
#  عوارض کدام واکسن کمتر است؟ عوارض جانبی طولانیمدت[SEP]تزریق واکسن[SEP]استیون استاد فاراک وپی[SEP]هر دو واکسن بیخطر[SEP]مورد عوارض جانبی ان[SEP]رویداد ههای ایمنی و کارایی بهطور طبیعی[SEP]دو واکنشهای جانبی داشتهاند[SEP]سنجش فواید و خطرات ارزیابی[SEP]ماهیت خاص واکنشها و سابقه پزشکی[SEP]مقامات بهداشت جهانی کنترل[SEP]تزریق واکسن فایز ر[SEP]سابقه واکنش الرژیک شدید[SEP]درد عضلانی و برخی بهطور موقت تورم غدد لنفاوی[SEP]اتفاقات نادر عوا رض جانبی شدید[SEP]عارضه جانبی جدی[SEP]دریافت واکسن[SEP]فرضیه عوارض جانبی جدی[SEP]عوارض جانبی خفیفی[SEP]میزان بهطورمعمول[SEP]سابقه واکنش الرژیک قابلتوجهی[SEP]دو عارضه جانبی جدی دیگر[SEP]دانشمندان بهطور قطعی
# 70th  corpus with score 0.65:
# ...
# 85th  corpus with score 0.65:
#  افزایش گدایان پشت ماسک  مرحله انتقال متکدیان و معتادان متجاهر[SEP]قول اهالی خودش[SEP]خودش[SEP]متکدیان افراد دیگری[SEP]برخی اهالی داستانهای دیگری[SEP]رونق انداخته جا[SEP]وظیفه ساماندهی متکدیان و کودکان کار و خیابان[SEP]توانمندسازی خانوادههای ضعیف و شناسایی منابع تولید فقر[SEP]ماجرای متکدیان جدید تازه[SEP]سطح کلانشهرها[SEP]عداد متکدیان[SEP]ظرفیت حدودا ۴۰۰ نفر متکدیان[SEP]صدایشان ان قدر[SEP]مرحله امارگیری[SEP]علت رها شدن طرح ساماندهی متکدیان و دوم[SEP]عابران پولها[SEP]چهارراه شلوغ خودروها[SEP]نقص جسمیاش مادرزادی[SEP]رد دوربرگردان خیابان پشت[SEP]خیال فریب عابری خودش[SEP]تعداد متکدیان[SEP]پول نقد[SEP]لحظهای[SEP]شکم خانوادهشان[SEP]خاطر پول نقد[SEP]متکدیان[SEP]حالی[SEP]خودشان[SEP]اختلال حواس[SEP]نظر قرنطینه دو هفتگی و تستها و ازمایشها[SEP]پول[SEP]داخل سبد[SEP]کاسبان محل میگویند تازهواردها
# 86th  corpus with score 0.65:
#  ۲۴ تجربه کاربردی از زبان پزشکی که به مبتلا شد دورهی نقاهت خود[SEP]داروهای تجویزی[SEP]کل خانه هوا[SEP]دمای خانه و اتاق ۲۸ و حتی گرمتر[SEP]مستعد اسیب[SEP]نمونه و چگونگی کنترل حداکثری[SEP]۱۲ - مسواک شما و اهل خانه[SEP]دمای بالای ۲۷ درجه[SEP]۳ - دمای اتاق قرنطینه و خانه همانطور[SEP]خوراکیهای فریز[SEP]مایعات زیاد[SEP]نحوه بروز و ظهور علایم و مراجعه[SEP]مدت ۱۰ تا ۱۵ دقیقه[SEP]عصرایران مدیر[SEP]اندکی[SEP]دمای بالا و زمان[SEP]دود خوش د و خاطره انگیزش[SEP]همه اهل خانه[SEP]مصرف قطره یا قرص پلا زیل یا همان متوکل وپر[SEP]قسمتهای داغ[SEP]اسپند بسیار مختصر[SEP]مقدمهی مطلب[SEP]روز دو وعده صبح و عصر نشاط[SEP]خوردن مکملها[SEP]مبارکی ایمنی بدنتان انقدر[SEP]یک نفر دیگر[SEP]میزان تهوع شما[SEP]روزهای بهتر[SEP]زینک ویتامینها[SEP]نقاهت حاصل[SEP]دستمال کاغذی[SEP]غذا و مایعات[SEP]فریزر و یخچال[SEP]کار بسیاری امده[SEP]روز[SEP]فشارخون دیابت و قلبی عروقی[SEP]۱۰ سیسی ویژه بزرگسالان[SEP]دمای کم[SEP]بیشتر چند علامت اولیه[SEP]۳۸ ۳ ) - بدن درد - خارش و ناراحتی گلو[SEP]روز پنجم و ششم[SEP]میریزد اب ساده[SEP]علایم جدیدی[SEP]دقیقه یا تب ماندگار بالای ۳۸ ۵ داشتید[SEP]هربار مسواک زدن[SEP]اب نمک ۳۰ تا ۴۰ درجه[SEP]روحیه زیادی[SEP]خوردن قرص استامینوفن ۵۰۰[SEP]زینک ویتامینها اهن و دوستان[SEP]دمای ۳۰ تا ۴۰ و ۱۵ دقیقه[SEP]ترشحات - کمی تهوع و دلپیچه - لرز مختصر - ابریزش بینی - عطسه - اسهال علایم[SEP]توانایی خوردن میوهها و سبزیجات تازه[SEP]دمای خانه و اتاق قرنطینه[SEP]بیقراری شما خواهد_۸ - بی اشتهایی و تهوع[SEP]ومای د[SEP]لرز یک واکنش طبیعی[SEP]شدن علایم[SEP]اهالی خانه[SEP]۲۴ - تا روز ۱۴ قرنط ینگی[SEP]خانه[SEP]۵ - بیقراری سیستم فرماندهی بدن[SEP]مختاری د[SEP]هوای افتابی بخشکان ید ۱۴[SEP]مدیریت شما و اهل خانه[SEP]بدترین چیزهایی[SEP]اب میوههای صنعتی و کنسانتره[SEP]دمای یخچال[SEP]شربت دیفن هیدر امین[SEP]شکر خدای مهربان[SEP]دمای حمام[SEP]روزها[SEP]زمره درصدی قرارگیری د[SEP]کنده‌اید ۱۰[SEP]بهترین دارو[SEP]زبان ساده و نه علمی[SEP]بدنش ویه همراه
# 87th  corpus with score 0.65:
#  حریرچی منم شدم داشتم تست[SEP]امیدوارم ظرف[SEP]تست اولیها
# 88th  corpus with score 0.65:
#  اهمیت سلامت روان روان درمانی در دوران  افراد توانایی تنظیم و تعدیل هیجانهای منفی[SEP]انجام کارها و درسهای تان[SEP]یک برنامه فعالیتی[SEP]حال تجربه کردن[SEP]استرس یک واکنش طبیعی[SEP]یک فردی تلفنی[SEP]روان درمانی[SEP]خانه یا برنامهای بهزیستی[SEP]بهبود دهنده سلامت روان[SEP]اضطراب افسردگی وسواس و عدم تمرکز و ز[SEP]یک برنامه[SEP]برنامهای[SEP]زمان مطالعه – یا کار خود[SEP]خانواده کلاسهای انل[SEP]دوران و ضرورت انجام انها[SEP]زمینههای مختلف فیلمها و سریالهای[SEP]شرایط تطبیق[SEP]ادامه نکاتی[SEP]تماس تلفنی تماس تصویری[SEP]معرض اطلاعات و اخبارهای بد و استرس امیز[SEP]مسایل و مشکلات و احساسات خودشان[SEP]برنامه ریزی[SEP]انواع روان درمانی انل و روانکاوی و مشاوره روانشناسی انل و مجازی[SEP]احتمالا سلامت روان[SEP]بسیاری[SEP]بازدهی بهتری[SEP]اطلاعات پیامها و اخبار‌ها[SEP]نوعی رفتارها و سبک زندگی مان[SEP]تماس تلفنی تماس تصویری و )[SEP]فراز و نشیب هایی[SEP]تهیه یک برنامه بهزیستی[SEP]کار یا مدرسه و دانشگاه[SEP]حفظ و بهبود سلامت روان تان[SEP]بهبودی سلامت روان[SEP]برنامهی روزانهی خود[SEP]برخی موارد[SEP]انجام کارها بازیابی د[SEP]احتمالا احساسات مختلف و متفاوتی[SEP]خدمات روانشناسی[SEP]اضطراب افسردگی وسواس و عدم تمرکز و باشید[SEP]اهداف بسیار بلند پروازانه[SEP]انواع روان درمانی افسردگی[SEP]وجود همه استرسها و اسیب هایی[SEP]یک روان درمانگر خوب
# 89th  corpus with score 0.65:
#  چگونه مبتلایان خفیف را در خانه درمان کنیم؟ سردرد و تنگی نفس است علایم[SEP]سایر افراد خانواده[SEP]عین حال
# 90th  corpus with score 0.65:
#  برچسب وسواس در روزگار  بیشتر شدن رفتارهای وسواسی[SEP]سیستم عصبی اثرات خود[SEP]برچسب وسواس[SEP]نظر اختلالات دیگر روان[SEP]اختلال[SEP]اختلال وسواس فکری - عملی مبتلا[SEP]مسایل جنسی احساس گناه و حساسیتهای مذهبی[SEP]بیان دیگر وسواس فکری منجر[SEP]مصرف دارو[SEP]تفاسیر افراد مبتلا[SEP]رفتارها و افکار وسواسی[SEP]واقعیت سنجی[SEP]شستوشوی بیشتر یا توجه بیشتر[SEP]بروز نوع اختلالات فکری و رفتاری[SEP]قالب ترس از شدن بهدلیل خطر وجود الودگی ناشی[SEP]رفتار وسواسی[SEP]رفتارهای وسواسی[SEP]افراد[SEP]اطرافیان چنین افرادی[SEP]دکتر متخصص علوم اعصاب شناختی و عضو پزوه شکده علوم شناختی[SEP]تایید بیمارگونه بودن رفتارش[SEP]دستورالعملهای بهداشتی[SEP]رعایت بهداشت وسایل و سطوح[SEP]اختلال وسواس[SEP]بهبود رفتار شخص وسواسی[SEP]وسواس فکری و عملی[SEP]رفتارهای دیگرشان[SEP]وسواس فکری[SEP]اختلال وسواسی[SEP]طریق رفتاردرمانی[SEP]سیستم هشداردهنده مغزتان بهطور صحیح کار[SEP]دیده میشود وسواس[SEP]افراد تمرکز بیشتری[SEP]افراد مبتلا[SEP]خانواده افراد[SEP]بهعلاوه افراد خودشان[SEP]جلوی هجوم افکار و رفتارهای وابسته[SEP]تمیزی خلاصه[SEP]افرادی[SEP]وسواس بیمارگونه[SEP]نشانههای وسواس بیمارگونه[SEP]درمان وسواس[SEP]سطح فکر و رفتار تغییر[SEP]درمان نوع وسواس[SEP]وسواس بهصورت حملههای شدیدتر[SEP]شکلهای مختلف[SEP]اختلالات شدید روانپزشکی[SEP]سمت هذیان یا اسکیزوفرنی[SEP]شاخصهای رفتاری و فکری شخص[SEP]وسواس بیشتری[SEP]دوران نشانه وسواس[SEP]شاخصهای رفتاری و فکری بهصورتی[SEP]وسواس[SEP]یکسری خودمراقبتی[SEP]تاثیر افراد[SEP]خیر بهاسانی نمیتوان[SEP]تسلیم دروغگویی مغزتان
# 91th  corpus with score 0.65:
#  نمونه جدید واکسن چینی ابداع شد بلندمدت بررسی میکنند کین پژوهشهای بسیاری[SEP]عوارض جانبی منفی[SEP]موشها و پستانداران غیر انسان[SEP]ارانای پیامرسان[SEP]هیچ عوارض جانبی منفی
# 92th  corpus with score 0.65:
#  غرغره به جای نمونه‌برداری برای یافتن در حلق سیستم اموزش و پرورش یا پروژههای تحقیقاتی[SEP]حفره دهان و حلق[SEP]نظر انها دریافت یک بسته حاوی وسایل لازم[SEP]موارد بسیاری جایگزین[SEP]روشهای پیشین نمونهبرداری[SEP]روش غرغره نتایج قابل مقایسهای[SEP]صورت جداگانه تجزیه و تحلیل میشوند مایکل میکروبیولوژی[SEP]ذرات حفره دهان و حلق[SEP]حفره دهان غرغره[SEP]مقامات بهداشتی کشور
# 93th  corpus with score 0.65:
#  بهبودیافتگان در چه صورتی می‌توانند روزه بگیرند؟ فاصله گذاری اجتماعی[SEP]شرایط روزه گرفتن بهبودیافتگان[SEP]فاصله گذاری[SEP]افراد بهبود یافتهای[SEP]افراد بهبودیافته[SEP]صورت رعایت نکردن نکات بهداشتی و فاصله گذاری اجتماعی افراد بیشتر
# 94th  corpus with score 0.65:
#  سناریوی خوزستان در هر شهری قابل تکرار است کشف واکسن یک ۱۸ ماه زمان[SEP]مصون میشود بررسی علل قرمز شدن وضعیت[SEP]ضرورت تداوم ایزولاسیون گروههای پرخطر زال[SEP]اخبار نویدبخش[SEP]چه میزان زمان[SEP]عدم رعایت نکات بهداشتی[SEP]ایا ساخته بشر[SEP]ساخته دست بشر[SEP]پروتکل بسیار خاصی[SEP]زمان دیگری[SEP]معرض خطر بیشتری[SEP]هیچ گزارش قطعی مبنی[SEP]مثال بعضی وقتها[SEP]مورد زمان کشف واکسن[SEP]حال گزارشهای خوبی[SEP]تب سرفه و درد عضلانی[SEP]بعضی وقتها[SEP]میزبان دیگر[SEP]میزان کافی[SEP]رفتار و رعایت نکات بهداشتی[SEP]زمان بازگشایی رستورانها[SEP]شرکتهای دانشبنیان[SEP]نکات بهداشتی[SEP]ایزولاسیون گروههای پرخطر[SEP]مورد کشف واکسن[SEP]رعایت نکات بهداشتی[SEP]میزبان اصلی ان خفاشها[SEP]شرایط‌های زمینه[SEP]مورد شرایط و قرمز شدن ان[SEP]پاسخ به سوالی مبنی
# 95th  corpus with score 0.65:
#  چه کنیم تا خاموش شود؟ کنترل و مهار[SEP]گروههای پرخطر[SEP]شرایط و همچنین رعایت کامل اقدامات محافظتی و امادگی بیمارستانها و مراکز بهداشتی درمانی[SEP]مکانهای شلوغ و پرتردد[SEP]خصوص گروههای پرخطر
# 96th  corpus with score 0.65:
#  روایت‌های واقعی از سوگ خانواده قربانیان  سلامت خانواده[SEP]درمان مساله درمان رفتاری و دارویی[SEP]حتی خانواده همسرش[SEP]استفاده[SEP]امر دو احتمال اختلال استرس حاد یا تروما و اختلالات هذیانی[SEP]روال سرعت مرگ[SEP]سیستم درمان[SEP]مرگ عزیز یا اسیب جدی یا خشونت فیزیکی یا‌های[SEP]دلیل اختلال استرس حاد[SEP]دست دادن شبها و روزها[SEP]ارواح دوست اشنا و فامیل[SEP]رفتار جایگزین مناسب[SEP]روزهای سوگ[SEP]دست دادن ان فرد[SEP]صحبت صدای دخترم[SEP]چشمانداز درستی[SEP]دست دادن[SEP]باور فعلی[SEP]افسردگی احساس وحشت زدگی و کنارهگیری[SEP]بردن هزینه ما[SEP]برخی موارد[SEP]صورت شفاف و اطلاعات بسیار خوب[SEP]که اجتماعی و اهل رفت و امد[SEP]بازپرداخت بیمهها[SEP]میان صحبت مادر[SEP]طریق بیمهها و بیمههای اجتماعی کار[SEP]سوگواری[SEP]رفتوامد عزیزان و اطرافیان همسرش[SEP]دست دادن عزیز[SEP]غربت اما دیگر مصایب خانواده قربانیان[SEP]شرط و شروط بسیار بالا[SEP]سوگ[SEP]دریافت خدمات بهداشت[SEP]روابط اجتماعی[SEP]مرادی افکار برخی[SEP]تپش قلب شدید افت فشار ضعف عضلانی و افسردگی شدید تجربههای دیگر[SEP]شبکههای حمایتی و ارتباطی اقوام[SEP]دستشان[SEP]عنوان تروما برایش[SEP]تجربههای احساسی[SEP]دختر سرخورده و منزوی[SEP]فر د سوگ ناشی[SEP]ان خدمات و دفترچههای شان[SEP]تامین اجتماعی و بازنشستگی و حمایتهای مالی[SEP]اختلال جسمانی کردن یا احتمال گاری[SEP]برنامهریزی حقوقی مناسب[SEP]امضای روانشناس بالینی امضای روانپزشک و یک پزشک متخصص[SEP]ترس مسایل ارتباطش[SEP]دکتر روانشناس بالینی[SEP]یک زمان خیلی کوتاه[SEP]زمان سوگواری باورن اپذیری و غیرمترقبه بودن و ترس[SEP]دست داده_است خانواده[SEP]طریق رفتاردرمانی و معنا درمانی و بازسازی شبکه حمایتی و دادن اطلاعات حقوقی اجتماعی و خانوادگی و برنامهریزی فردی فرد[SEP]ایجاد یک صندوق مناسب و مکلف کردن بیمهها[SEP]برنامهریزی[SEP]سوگواری ما[SEP]تسلیت گفتنها و کمک خانوادهها[SEP]اپذیری مرگ[SEP]کسب برنامهریزی جدید و نقش پذیری[SEP]سفتی عضلات حساسیت شدید[SEP]میان خانواده قربانیان[SEP]شوک ناباوری و کرختی ناشی[SEP]مورد سوگ[SEP]طریق شبکههای مجازی یا جایگزینهای مناسب[SEP]جواب دادن تلفن اطرافیان[SEP]ناراحتی قلبی[SEP]دیگر دستورعمل‌ها[SEP]دوره سخت[SEP]خدمات روانشناسی و مشاورهای[SEP]دست پسرعمویش[SEP]پرداخت انل و ایجاد یک دستورالعمل مناسب[SEP]باور کردنی[SEP]گفته دو سال دیگر[SEP]فردای ان روز همسرش[SEP]باورپذیری ان[SEP]دست[SEP]یک سوگ متعارض[SEP]دست دادن یک عزیز[SEP]درماندگی و اشفتگیهای ناشی[SEP]مورد احساس عدم امنیت و کمبود اطلاعات[SEP]سوگ پدرت[SEP]حالت برانگیختگی[SEP]میزان ناراحتیهای روحی و روانی خانواده قربانیان[SEP]بیمههای درمانی ما[SEP]فر د سوگواری[SEP]افزایش فوتیهای اسیبی جدی سلامت روانی جامعه[SEP]عواطف دردناک و ازاردهنده اتفاق[SEP]ان قربانیان[SEP]اختلال استرس حاد[SEP]شباهت بسیار زیادی[SEP]ستاره فرد[SEP]خواستههای خودت[SEP]سحرگاه یک روز ماه رمضان[SEP]بیمههای قدرتمندی[SEP]سر خودم یا دیگران[SEP]خانواده قربانیان[SEP]تشخیص یک دقیقا نوع مداخله و نوع کاری[SEP]مدت سوگواری نداشته_باشیم بحث بعدی ترس[SEP]براساس دستورالعملهایی[SEP]غمگینی خشم اضطراب تنهایی و احساس خستگی[SEP]یک زمان پدربزرگش یا یک فامیل دیگر[SEP]یک سوگ تاخیری[SEP]عنوان اختلاس استرس حاد[SEP]خاطرات فرد افکار احساسات و مکانهای حادثه و موضوع خود حادثه
# 97th  corpus with score 0.65:
#   همیشه می‌ماند بدن افراد خفیفتر فرد[SEP]صورت ابتلای دوباره بهبودیافتگان[SEP]هیچ انتی بادی خاصی[SEP]بدن برخی بهبودیافتگان[SEP]ابتلای دوباره[SEP]تست انتی بادی[SEP]میزان انتی بادیها[SEP]میل دانشمندان برتر دنیا[SEP]ایجاد ایمنی گلهای[SEP]مصداق ایمنی گلهای[SEP]ابتلای دوباره بهبودیافتگان
# 98th  corpus with score 0.65:
#  ۱۱ هزار ۲۷۰ بهبود یافته پلاسما اهدا کردند یاری هموطنان بشتابند حاجی[SEP]اهدای پلاسما کنندو[SEP]دریافت پلاسمای بهبود یافتگان[SEP]انتقال خون سراسر کشور[SEP]سویی دریافت پلاسما بهبودیافته‌ها[SEP]امار اهدا کنندگان پلاسما بهبودیافتگان[SEP]شرایط اهدای پلاسما[SEP]بهبودی بهترین زمان ممکن[SEP]بیشترین میزان مراجعه بهبود یافتگان[SEP]سابقه بارداری[SEP]پلاسمای بهبود یافتگان[SEP]شرایط اهدا[SEP]بهبودیافتگان پلاسما[SEP]۶ استان شامل و مرکز دریافت پلاسمای بهبودیافتگان[SEP]دریافت پلاسمای بهبودیافته‌ها[SEP]بهبود یافتگان[SEP]مراکز انتقال خون[SEP]اهدای پلاسما[SEP]دریافت پلاسما[SEP]درخواست پلاسما بهبودیافتگان[SEP]مراکز انتقال خون پلاسمای بهبودیافتگان
# 99th  corpus with score 0.65:
#  با شک تردید چه کنیم؟ وعدههای غذایی سالم و متعادل و انجام منظم ورزش و خواب مناسب[SEP]دنبال ازمایش و درمان بروم پرهیز[SEP]باور پیشگیری و درمان[SEP]بسیاری دیگر[SEP]پزشکان و سایر ارایهدهندگان مراقبتهای بهداشتی یا امدادگران[SEP]ورزش و تغذیه سیستم ایمنی خود[SEP]دیگر اقدامات کاربردی[SEP]هزینههای مادی و معنوی بسیاری[SEP]مرور تجربههای موفق استاد[SEP]تجربههای موفق بهبود ای گذشته[SEP]برخی خانوادهها تجربهها و اتفاقهای تلخ[SEP]مراکز بهداشتی[SEP]رسانههای ارتباط جمعی[SEP]رعایت پروتکلهای بهداشتی[SEP]شنیدن مکرر[SEP]طور بیست و چهار ساعته درباره[SEP]ماسک و رعایت بهداشت[SEP]بیشتر موارد[SEP]رسانههای اجتماعی[SEP]مانند‌های دیگر اصول پیشگیری و درمان[SEP]ارزوهای خوب و تجربه دلنشین زندگی خود[SEP]شک و تردید میکند نبود خودشناسی و نداشتن خودباوری[SEP]مدیریت فکری داشتیم بدونشک[SEP]اقدامات و ازمایشگاهها و بررسیها[SEP]انتقال بیمورد تجربههای مربوط[SEP]مدیریت افکار منفی[SEP]میان افراد مسن و افراد مبتلا به‌های مزمن[SEP]نگاه نخست رهایی[SEP]افکار منفی[SEP]حواسپرتی شیوه استفاده[SEP]تقویت کردهام و ترسی[SEP]باورهای درست[SEP]دیگر ریشههای باور نادرست[SEP]شیوه ترساندن و ایجاد رعب و وحشت[SEP]هجوم افکار منفی و اضطراب زا[SEP]کشش یا حرکتهای مدیتیشن جسمی[SEP]ورزش و تغذیه متا سب و رعایت فاصله و استفاده[SEP]مثبت کاذب و منفی کاذب و موارد مشابه[SEP]دریافت نتیجه[SEP]یک رمز مثلا فشار دادن انگشت یا پلک زدن[SEP]موضوع یا تجربه کردن روزهای سخت[SEP]اجتماعات و فعالیتهای مختلف و شیوه زندگیم[SEP]سمت خاطرههای دلنشین

# %%
question

# %% [markdown]
# # Sampling in Batches

# %%
questions = pd.read_pickle('/content/drive/MyDrive/CoPer paper-Models/Sample Queries/Titles_with_Corona.pkl')

# %% [markdown]
# Don't put faiss itself in the function it'll give wrong results and indices

# %%
# create the basic faiss for corpus embeddings
index = faiss.index_factory(768, "Flat", faiss.METRIC_INNER_PRODUCT)
emb_cor = np.array([i.numpy() for i in corpus_embeddings])
faiss.normalize_L2(emb_cor)
index.add(emb_cor)

# %%
results = get_resutls(questions, top_n = 50)
# Out:
# آیا زنان باردار بیشتر در معرض خطر ابتلا به بیماری کروناهستند
# من باردار هستم چگونه می‌توانم از خودم در مقابل بیماری کرونامحافظت کنم
# آیا زنان باردار باید برای کروناآزمایش شوند
# آیا کرونامی تواند از مادر باردار به نوزاد متولد نشده جنین یا نوزاد تازه متولد شده منتقل شود
# در دوران بارداری حین زایمان چه مراقبت‌هایی باید انجام شود
# آیا زنان باردار مبتلا به کرونایا مشکوک به این بیماری نیاز به سزارین دارند
# آیا مادر مبتلا به کرونامی تواند به نوزاد خود شیر بدهد
# آیا در صورت مبتلا شدن به کووید۱۹ می‌توانم کودک خود را در آغوش بگیرم
# من به کرونامبتلا هستم حال عمومی مساعدی ندارم که بتوانم به کودک خود مستقیما شیر بدهم چه باید بکنم
# آیا خشک­ کن­های دست در نابودی ویروس جدید کرونا موثر هستند
# آیا گندزداییضدعفونی با لامپ ماورای بنفش ویروس جدید کرونا را از بین می­برد
# آیا سنجش حرارت بدن اندازه گیری تب در شنسایی افراد مبتلا به عفونت ویروس جدید کرونا موثر است
# آیا اسپری کردن الکل یا محلول‌های حاوی کلر روی تمام بدن می­تواند ویروس جدید کرونا را نابود کند
# آیا واکسنهای ذات­الریه در برابر ویروس جدید کرونا موثر هستند
# آیا شستشوی منظم بینی با محلول­های نمکی کمک به پیشگیری از ابتلا به عفونت کرونا ویروس جدید می­کند
# آیا خوردن سیر به پیشگیری از ابتلا به ویروس جدید کرونا کمک میکند
# چگونه ماسک بزنیم استفاده کنیم در بیاوریم دور بیندازیم
# علائم کروناچیست
# کروناچگونه منتقل می‌شود
# آیا ویروسی که عامل ابتلا به کرونااست از طریق هوا منتقل می‌شود
# آیا کرونااز فرد فاقد علائم بیماری به دیگران منتقل می‌شود
# آیا ممکن است از طریق مدفوع فرد بیمار به کرونامبتلا بشویم
# برای حفاظت خودم جلوگیری از انتشار بیماری چه کار کنم
# چقدر احتمال دارد به کرونامبتلا شوم
# آیا کرونانگران‌کننده است
# چه کسانی احتمال دارد به نوع شدید بیماری کرونامبتلا شوند
# آیا مصرف آنتی‌بیوتیک در جلوگیری از ابتلا به کرونایا درمان آن مؤثر است
# برای پیشگیری درمان کرونادارو یا درمان خاصی وجود دارد
# آیا کروناواکسن دارو یا درمان خاصی دارد
# آیا کروناهمان بیماری سارس است
# آیا باید برای حفاظت از خودم ماسک بزنم
# دوره ‌نهفتگی کمون بیماری کروناچقدر است
# ممکن است از طریق حیوان خانگی‌ام به کرونامبتلا شوم
# این ویروس تا چه مدت روی سطوح زنده می‌ماند
# دریافت بسته پستی از مناطقی که کرونادر آن‌ها گزارش شده بی‌خطر است
# آیا سازمان جهانی بهداشت توصیه می‌کند که تمام گردهمایی‌های بزرگ بین‌المللی در دوران طغیان ویروس جدید کرونا لغو شود
# اقلیم سرد برف نمی‌تواند ویروس را بکشد
# ویروس جدید کرونا نمی‌تواند از طریق نیش پشه منتقل شود
# آیا کرونا از راه استفاده کردن از سرویس بهداشتی انتقال پیدا می‌کند
# آیا کرونا از طریق پوست انتقال پیدا می‌کند
# ویروس کرونا از راه گوش منتقل می‌شود
# آیا ویروس کرونا دچار جهش شده است
# آیا هر نوع سرفه‌ای نشان از ابتلا به کروناست
# آیا افراد مبتلا به آسم آلرژی در خط ابتلا به کرونا هستند
# چگونه سیستم تنفسی ریه خود را تقویت کنیم تا به بیماری کرونا مبتلا نشویم
# آیا کودکان به کرونا مبتلا می‌شوند
# آیا بین گروه خونی احتمال ابتلا به ویروس کرونا ارتباطی هست
# آیا یکبار ابتلا به کرونا به این معناست که دیگر آن را نمی‌گیریم
# آیا ماسک پارچه‌ای برای جلوگیری از ابتلا به کرونا مناسب است
# چگونه باید لوازم شخصی بیماران مبتلا به کرونارا تمیز کرد

# %% [markdown]
# # Saving all in a pickle

# %%
with open('/content/drive/MyDrive/CoPer paper-Models/Results/sbert-farsTail.pkl', 'wb') as f:
    pickle.dump(results, f)
