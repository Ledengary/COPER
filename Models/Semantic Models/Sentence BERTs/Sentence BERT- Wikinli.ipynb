# %% [markdown]
# # importing packages

# %%
# pip install --upgrade torch torchvision
# use this for training

# %%
# !pip install -qU sentence-transformers
# !pip install -qU wikipedia-api
# !pip install -qU clean-text[gpl]

# !mkdir resources
# !wget -q "https://github.com/sobhe/hazm/releases/download/v0.5/resources-0.5.zip" -P resources
# !unzip -qq resources/resources-0.5.zip -d resources

# !rm -rf /content/4ccae468eb73bf6c4f4de3075ddb5336
# !rm -rf /content/preproc
# !rm preprocessing.py utils.py
# !mkdir -p /content/preproc
# !git clone https://gist.github.com/4ccae468eb73bf6c4f4de3075ddb5336.git /content/preproc/
# !mv /content/preproc/* /content/
# !rm -rf /content/preproc

# !pip install faiss-cpu
# !pip install hazm
# Out:
#      |████████████████████████████████| 71kB 8.6MB/s
#      |████████████████████████████████| 1.8MB 33.4MB/s
#      |████████████████████████████████| 1.2MB 59.5MB/s
#      |████████████████████████████████| 890kB 55.7MB/s
#      |████████████████████████████████| 3.2MB 49.9MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
#   Building wheel for wikipedia-api (setup.py) ... done
#      |████████████████████████████████| 71kB 10.0MB/s
#      |████████████████████████████████| 133kB 15.9MB/s
#      |████████████████████████████████| 245kB 41.8MB/s
#   Building wheel for ftfy (setup.py) ... done
# rm: cannot remove 'preprocessing.py': No such file or directory
# rm: cannot remove 'utils.py': No such file or directory
# Cloning into '/content/preproc'...
# remote: Enumerating objects: 7, done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 7
# Unpacking objects: 100% (7/7), done.
# Collecting faiss-cpu
#   Downloading https://files.pythonhosted.org/packages/1e/a8/ed1601e6e94702ad691465bd1bead221dd2984f741bf384011b4dc59130e/faiss_cpu-1.7.0-cp36-cp36m-manylinux2014_x86_64.whl (8.1MB)
#      |████████████████████████████████| 8.2MB 18.0MB/s
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.0
# Collecting hazm
#   Downloading https://files.pythonhosted.org/packages/22/13/5a7074bc11d20dbbb46239349ac3f85f7edc148b4cf68e9b8c2f8263830c/hazm-0.7.0-py3-none-any.whl (316kB)
#      |████████████████████████████████| 317kB 15.3MB/s
# Collecting libwapiti>=0.2.1; platform_system != "Windows"
#   Downloading https://files.pythonhosted.org/packages/bc/0f/1c9b49bb49821b5856a64ea6fac8d96a619b9f291d1f06999ea98a32c89c/libwapiti-0.2.1.tar.gz (233kB)
#      |████████████████████████████████| 235kB 39.8MB/s
# Collecting nltk==3.3
#   Downloading https://files.pythonhosted.org/packages/50/09/3b1755d528ad9156ee7243d52aa5cd2b809ef053a0f31b53d92853dd653a/nltk-3.3.0.zip (1.4MB)
#      |████████████████████████████████| 1.4MB 50.2MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from libwapiti>=0.2.1; platform_system != "Windows"->hazm) (1.15.0)
# Building wheels for collected packages: libwapiti, nltk
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp36-cp36m-linux_x86_64.whl size=155108 sha256=725725fa00719f07dcb7b54fe6b3b249ff1d1177c4dedd05fac46dc5022856b8
#   Stored in directory: /root/.cache/pip/wheels/66/15/54/4510dce8bb958b1cdd2c47425cbd1e1eecc0480ac9bb1fb9ab
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-cp36-none-any.whl size=1394470 sha256=6b4c1f53e1a870d3a6a621ac5d912c0e983517e7366a858e8cd83c39aaddd5f5
#   Stored in directory: /root/.cache/pip/wheels/d1/ab/40/3bceea46922767e42986aef7606a600538ca80de6062dc266c
# Successfully built libwapiti nltk
# Installing collected packages: libwapiti, nltk, hazm
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
import numpy as np 
import pandas as pd
import re
import os
import faiss
import hazm
from hazm import stopwords_list
import pickle
import requests
from termcolor import colored

from torch.utils.data import DataLoader
from sentence_transformers import InputExample, losses
import torch
import tensorflow as tf
from sentence_transformers import models, SentenceTransformer, util


SentenceTransformer_TrainedOnFarsTail_Path = 'm3hrdadfi/bert-fa-base-uncased-farstail-mean-tokens'
SentenceTransformer_TrainedOn_wikinli_Path = 'm3hrdadfi/bert-fa-base-uncased-wikinli-mean-tokens'
SentenceTransformer_TrainedOn_wikitriplet_Path = 'm3hrdadfi/bert-fa-base-uncased-wikitriplet-mean-tokens'

# %% [markdown]
# # Helpers

# %%
# phrases that need to be removed from titles
corona_phrases = ['کرونایی', 'کروناست' ,'کرونا', 'شیوع', 'بحران', 'ویروس',
                  'ویروس جدید', 'coronavirus', 'corona', 'کووید-19 ', 
                  'کووید', 'بیماری', 'بیمارانی', 'بیماران', '-۱۹', ' وی ', '19', '۱۹',
                  ' بیمار ', 'كرونا', 'كوويد', 'ويروس', r'(\s+)',]


normalizer = hazm.Normalizer()

def clean(text):
    """Cleans the titles for the semantic models"""
    for pattern in corona_phrases:
        text = re.sub(pattern, " ", text)

    text = re.sub(' +[\w] +', " ", text)
    text = normalizer.normalize(text)

    return text


#---------------------------------- get the results for this model-----------------------#

def get_resutls(questions, top_n):
    
    results = []
    
    for question in questions:

        print(question)
        # print('question type', type(question))


        # we give the cleaned question to the semantic model 
        question_cleaned = clean(question)

        question_emb = sentence_bert_embedder.encode(question_cleaned,
                                    convert_to_tensor=False,
                                    show_progress_bar = False)
        
        emb_que = np.array([question_emb])
        faiss.normalize_L2(emb_que)

        top_k = index.search(emb_que, top_n)
        indices = []
        scores = []

        # saving all the reults in a dictionary
        for score, idx in zip(top_k[0][0], top_k[1][0]):
            
            indices.append(idx)
            scores.append(score)

        results.append({'question':question,
                        'index':indices})
        
        
    return results

# %% [markdown]
# # The Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_address = '/content/drive/MyDrive/COVID-PSS.xls'
keys_address = '/content/drive/MyDrive/keywords_final_distilled_NE (1).pickle'
cleaned_titles_address = '/content/drive/MyDrive/title_cleaned_without_corona_2.pkl'
annotations_address = '/content/drive/MyDrive/all_annotations.csv'

df = pd.read_csv(data_address)
list_t = pd.read_pickle(cleaned_titles_address)

keywords = pd.read_pickle(keys_address)
keywords = [v for k,v in keywords.items()]



assert len(keywords) == len(df)
df['keywords'] = keywords
df.drop(columns=['img', 'link'], inplace=True)

# %%
corpora = []
for i in range(len(list_t)):

    keys = '[SEP]'.join(keywords[i])
    corpora.append(' '.join([list_t[i], keys]))

# %% [markdown]
# # The model

# %%
# preparing the model

def load_sentence_transformer(path):
    bert_model_s = models.Transformer(path, max_seq_length=512)
    pooling_model = models. Pooling(
        bert_model_s.get_word_embedding_dimension(),
        pooling_mode_mean_tokens = True,
        pooling_mode_cls_token = False,
        pooling_mode_max_tokens = False,
    )
    model = SentenceTransformer(modules= [bert_model_s, pooling_model])
    return model

sentence_bert_embedder = load_sentence_transformer(SentenceTransformer_TrainedOn_wikinli_Path)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=519.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=651449935.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1198122.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=348.0, style=ProgressStyle(description_…

# %% [markdown]
# # Creating Embeddings

# %%
# %%time
# creating corpus embeddings

corpus_embeddings = sentence_bert_embedder.encode(corpora,
                                                  convert_to_tensor=True,
                                                  show_progress_bar=True,
                                                  batch_size = 256)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=14.0, style=ProgressStyle(description_width…
# CPU times: user 22.6 s, sys: 19.4 s, total: 42 s
# Wall time: 51.4 s

# %% [markdown]
# # Sample Qustions

# %%
# creating sample question embeddings

question = str(questions[1:2])
question_emb = sentence_bert_embedder.encode(question,
                               convert_to_tensor=False,
                               show_progress_bar = False)

# %% [markdown]
# Searching with FAISS

# %%
## Similarity Scores with FAISS

index = faiss.index_factory(768, "Flat", faiss.METRIC_INNER_PRODUCT)
# corpus
emb_cor = np.array(corpus_embeddings)
faiss.normalize_L2(emb_cor)

# query
index.add(emb_cor)
emb_que = np.array([question_emb])
faiss.normalize_L2(emb_que)

top_k = index.search(emb_que, 100)

# %%
sentence_bert_WikiNli_indices = []
sentence_bert_WikiNli_scores = []

print(question)
print('Top results!')
for score, idx in zip(top_k[0][0], top_k[1][0]):
    print(colored(f'{idx}th', 'blue'),' corpus with score', colored( f'{score:.2f}:\n', 'blue'),  corpora[idx])
    
    sentence_bert_WikiNli_indices.append(idx)
    sentence_bert_WikiNli_scores.append(score)
# Out:
# ['من باردار هستم چگونه می\u200cتوانم از خودم در مقابل بیماری کرونامحافظت کنم']
# Top results!
# 3406th  corpus with score 0.76:
#  چگونه با خانواده‌ای که عزیزشان بر اثر فوت کرده رفتار کنیم؟ جاری زندگی[SEP]امور جاری[SEP]خرید کردن
# 1152th  corpus with score 0.75:
#  زندگی با را باور کنیم چهره خشن در ICU نمایان می‌شود چهره خشن[SEP]پاند می‌اگر نخواهیم_پروتکلهای بهداشتی[SEP]خصوص نوع کورتون انها[SEP]پیوند عضو
# 658th  corpus with score 0.75:
#   جدید از مادر به جنین منتقل نمی‌شود زنان باردار مبتلا[SEP]زنان باردار و جنین انان[SEP]حتی زنان بارداری[SEP]زنان باردار و نوزادان[SEP]زنان بارداری
# 3057th  corpus with score 0.75:
#   زنان باردار درمقابل چه کارهایی باید انجام دهند؟ زنان غیرب اردار[SEP]زنان غیرب اردار است فوق تخصص زنان[SEP]که مقاومت بدن زنان باردار[SEP]زنان باردار
# 597th  corpus with score 0.75:
#  آیا به جنین آسیب می‌زند؟ زودرس پاره[SEP]زودرس کیسه[SEP]زایمان زودرس
# 3416th  corpus with score 0.75:
#  طلوع زندگی پس از  تجربههای متفاوتی[SEP]سومین هفته طاعون خبر[SEP]بزرگترین غم زندگیاش[SEP]پروتکلهای بهداشتی[SEP]مادر بهتری[SEP]یک تفاوت باریک و درعین حال عمده[SEP]احساسات مشترک جدایی ترس[SEP]جای بهتری[SEP]دیگران و درنتیجه به خانواده و فامیل[SEP]بیشترین سرعت و کمترین امکان خطر جریان[SEP]مراقبتهای لازم[SEP]اشتیاق اغوش پدربزرگ و مادربزرگ بیتاب[SEP]ادم بهتری[SEP]مرحله بعدی[SEP]فکر سلامتی خودتان[SEP]جایگزین فرد محوری و منفعت طلبی[SEP]شناخت بهتری[SEP]فرزندان بهتری[SEP]پیامدهای منفی‌های روان[SEP]سویههای امیدبخش فراوانی[SEP]مرگ سیصد و دو نفر[SEP]کجا معلوم انچه امروز مایه تلخکامی و بیم ماست[SEP]افرادی با‌های زمینهای بیشتر[SEP]امکان رشد و توسعه فردی[SEP]خود و نوع روابطشان
# 2414th  corpus with score 0.73:
#  شرایط انجام تست از مادران باردار نوزاد آنها اطفال و کودکان[SEP]خصوص مادران مبتلا[SEP]دوبار تست pcr[SEP]دو تست pcr[SEP]مادر باردار[SEP]فرد مبتلا[SEP]مادر باردار و نوزادش توضیحاتی
# 648th  corpus with score 0.73:
#  چگونه با فرزندان درباره صحبت کنیم؟ دلایل شرایط سنی خود[SEP]مقابل و سایر‌ها شستن مرتب دستها[SEP]طریق دیدن زبان بدن تن صدا و نحوه تنفس کودک[SEP]کودک جستوجو و دنبال کردن حامیان و فعالان سلامتی پرداختن و توجه[SEP]افزایش قدرت درک و تحلیل موضوع تقویت توان سازگاری و پذیرش واقعیت موجود[SEP]حفظ ایمنی و سلامتی خود[SEP]حفظ امنیت و سلامتی کودکان[SEP]شرایط تقویت عوامل محافظتکننده و درنهایت[SEP]نظارت والدین کمک[SEP]ایجاد یک گفتوگوی باز[SEP]سلامتی خود و گفتوگوی نزدیک[SEP]پرسیدن یک سوال باز[SEP]حفظ امنیت و سلامتی کودک[SEP]حال تماشای تصاویر دلخراش و ترسناک[SEP]ایمن نگهداشتن خانواده بهکار[SEP]طریق بازیها و تکنیکهای ارامسازی انجام فعالیتهای روزمره بهصورت منظم[SEP]خانه یا بیمارستان بمانند والدین[SEP]جعفری سد هی اگاهی و مهارت والدین[SEP]مهمترین اصول انجام یک گفتوگوی سازنده[SEP]انجام دادن کارهایی[SEP]کودک جامعهشناس[SEP]ایمنی همه افراد کمک میکند کارشناس بهزیستی[SEP]انجام گفتوگوی حمایتی و پذیرنده[SEP]کوچکسازی دغدغههای ذهنی کودک و بیتوجهی[SEP]ان داشتن جدول زمانی روزانه[SEP]فرزندان والدین[SEP]درک منطقی و اصولی نیازها و چالشهای ذهنی کودکان[SEP]اضطراب استرس یا غم و اندوه[SEP]اطمینان دهی[SEP]سطح اضطراب و نگرانی کودک مهم[SEP]کودک جامعهشناس و کارشناس بهزیستی[SEP]محیط زندگی انها مکانی[SEP]کودکان ارزیابی دقیق[SEP]والدین و فرزندان برشمرد کارشناس بهزیستی[SEP]توقف و ایجاد جامعه سالم
# 1633th  corpus with score 0.71:
#   طی چند روز از بدن فرد مبتلا پاک می‌شود؟ افراد سالمند و مبتلایان[SEP]تایید کننده منفی بودن ازمایش[SEP]مدت زمان پاک شدن بدن
# 3474th  corpus with score 0.71:
#   چطور ما را مضطرب افسرده کرد؟ برخی افراد[SEP]اضطراب استرس و افسردگی اختلالات خلقی شایع[SEP]مهمانی دانشگاه مدرسه و جمع همکاران[SEP]مطالعه حمام ورزش و کارهای عادی[SEP]روابط خانوادگی[SEP]نقطه اصلی ان رعایت بهداشت[SEP]مسایل بهداشتی[SEP]دوران شاهد افزایش ناگهانی سطح مصرف ترنت[SEP]تحمل ابهام[SEP]سومین نکته روابط خانوادگی[SEP]بدن مادر و فرزند هورمون ارامش بخش اکسی[SEP]طریق لوازم ارتباطی[SEP]مسیله دیگر دخالت خانواده[SEP]جنبه فردی ما[SEP]یک مشاور خانواده روانشناس و استاد دانشگاه[SEP]حوزه روانشناسی اجتماعی[SEP]اختلالات خلقی و روانی[SEP]مشاهدات بالینی شما یا مراجعات مردم[SEP]موضوع لوازم ارتباطی[SEP]روز پیامهای شخصی و گروهی رد و بدل میشد ایا[SEP]انواع افسردگیها[SEP]کنار همدیگر[SEP]منابع خبری بهداشتی[SEP]شناخت حد و مرز علمی مراقبت[SEP]حوزه روانشناسی[SEP]حوزه روانشناسی بالینی تکلیف جدید پراسترس[SEP]روابط درون خانواده و حتی روابط اجتماعی[SEP]برخی افراد اختلالات خلقی[SEP]حوزه روانشناسی بالینی و اجتماعی و خانواده[SEP]تحمل فضای سنگین عبور[SEP]قرنطینه خانگی
# 2199th  corpus with score 0.71:
#  زایمان موفق مادر باردار مبتلا به در بندرعباس ۳ مادر باردار مبتلا[SEP]مادر بارداری[SEP]اورد حال عمومی مادر و کودک[SEP]هر کدام[SEP]معاون درمان دانشگاه[SEP]مادر باردار[SEP]مادران باردار مادر[SEP]معاون درمان[SEP]خبر داد عصرایران دکتر ( ) سه مادر باردار[SEP]اعلام نتیجه و مثبت[SEP]علایم تب سرفه و گلودرد[SEP]۳ مادر باردار[SEP]کادر درمانی
# 627th  corpus with score 0.71:
#  سئوالات کودکان را پاسخ دهید انجام کاری خلاقانه میتو اد عارضه[SEP]مورد هرگونه هیجان شدید[SEP]رضا منش[SEP]ذهن اگاهی مدیتیشن تکنیکهای ارام سازی یوگا دعا و شیوههای مشابه[SEP]کودکان باز زبانی ساده و قابل فهم اطلاعات[SEP]رضا منش کودک[SEP]میان طیف گستردهای[SEP]رضا منش روانپزشک پنجشنبه[SEP]مصرف الکل دخانیات و مصرف مواد اهمیت ویژهای[SEP]قرنطینه هم برنامه[SEP]درصورت وجود روانی زمینهای مصرف دارو
# 601th  corpus with score 0.71:
#  چگونگی روابط زوجین با وجود  مسیول سلامت خانواده[SEP]سلامت خانواده[SEP]درد و سرفههای خشک و تنگی نفس[SEP]دوره نهفتگی[SEP]کارشناس سلامت خانواده[SEP]رابطه زناشویی[SEP]است مسیول سلامت خانواده[SEP]زندگی مشترک همسران سازگاری و برقراری رابطه صمیمانه[SEP]معرض خطر ابتلا به دارای علامت و یا کسانی[SEP]ارتباطات خانوادگی و عاطفی[SEP]مسیول بهداشت خانواده
# 3458th  corpus with score 0.71:
#  توصیه‌هایی به مادرانی که در صاحب فرزند شده‌اند برخی افراد[SEP]عوامل بنیادی ایجاد افسردگی احساس تنهایی[SEP]متخصص مشاوره و روانشناسی توضیحاتی[SEP]نگرانیهای بی مورد و افراطی[SEP]نزدیکترین بستگان ازجمله همسر و یا اعضای خانواده خود[SEP]غم بی حوصلگی کاهش انگیزه کاهش انرژی خستگی عدم لذت بردن[SEP]صاحب فرزند[SEP]اشتراک گذاری تجربیات شخصی افراد[SEP]جلب توجه دیگران[SEP]بین نزدیکان خود[SEP]ترس عوامل دیگر پدیدار شدن اختلال[SEP]متخصص مشاوره و روانشناسی[SEP]مدت زمان بسیار کوتاه[SEP]برخی افراد بهخصوص زنانی[SEP]یکدیگر و ماهها قرنطینه[SEP]ابتلای احتمالی خود و یا فرزندانشان[SEP]بیانگر افسردگی[SEP]عنوان یک نیاز بنیادی[SEP]درحالت پیشرفته اختلال[SEP]یک عامل تنش زای ضعیفتری دورههای افسردگی بعدی[SEP]علایم افسردگی[SEP]زودرنجی و عصبانیت[SEP]بیان علایم خود و سیر تشخیص درمان و نحوه مبارزه[SEP]تجربه اسیبهای احساسی حوادث تلخ کودکی یا اختلال شخصیت و یا زمینه خانوادگی[SEP]نیاز بنیادی خود[SEP]دنبال کسب درامد و یا شهرت ترنت[SEP]سابقه اختلالات افسردگی
# 176th  corpus with score 0.71:
#  در مقابل تاب می‌آوریم؟ واکنشهای احساسی بیشتری[SEP]حال همکاران بیمارم[SEP]تاب اوری شان[SEP]توان و تاباوری بیشتری[SEP]سپری شدن شرایط سخت و مصیبت زندگی خود[SEP]تاباوری یا تاباوری روانی[SEP]خود حرف زدن[SEP]کمک کننده[SEP]تاب اوری[SEP]انجام کارهای عقب[SEP]نام تاب اوری[SEP]خانواده پرجمعیتی[SEP]چند ماهی[SEP]مشکلات و سختیها[SEP]دیگر نمیکشم‌ها[SEP]خانه دایم[SEP]کارمند یک شرکت خصوصی[SEP]همان تاباوری خودشان[SEP]مدت شنیدهام[SEP]مادرت قرنطینه[SEP]همه جای دنیا[SEP]شرایط باب گفتوگو[SEP]پایین امده غمگین[SEP]دست اوردن تفکر و مهارتهای خود[SEP]گیر افتادهایم دکتر روانشناس[SEP]برخی تاباوری شان
# 651th  corpus with score 0.70:
#  چگونگی رفتار با کودکان در روزهای  خطرات واکنشهای دفاعی[SEP]اصرار شدید کودکان[SEP]استرس مبتلا شدن به[SEP]مسیر رشدشان مارا الگو خود[SEP]درس خواندن[SEP]طریق ذهن ارامی یا ارامش درمانی اضطراب[SEP]ادامه واکنش طبیعی[SEP]زمینه رعایت بهداشت فردی[SEP]اضطراب یک واکنش طبیعی[SEP]داشتن مشکلات قلبی تا گوارشی[SEP]نگرانی هایمان[SEP]ایام انها[SEP]تمام هیجانهای منفی[SEP]منشاء بهداشت روانی
# 611th  corpus with score 0.70:
#  کدام روش مناسب زایمان در دوران است؟ اضطراب جنینی[SEP]شواهد موجود روش زایمان مشخصی[SEP]بررسی مستندات شواهد و پاسخهای علمی[SEP]طریق زایمان طبیعی[SEP]شرایط مادر یا جنین[SEP]نظر گرفتن ابتلا یا عدم ابتلا[SEP]عوارض مادری و جنینی[SEP]انتخاب نوع زایمان[SEP]نظر گرفتن ابتلا یا عدم ابتلا به
# 3463th  corpus with score 0.70:
#  در دوران که با اضطراب روبرو هستیم چطور خودمان را آرام کنیم؟ فکرهای عجیب و زیادی[SEP]مسایل مفید[SEP]ارام شدن مفید[SEP]ضمیمه خانواده همهگیر شدن قرنطینه خانگی چندماهه ازدسترفتن[SEP]مشاغل و کاهش درامد افزایش بیرویه قیمت اجناس و مهمتر[SEP]سلامت جسمی و روحی و حتی اجتماعیمان[SEP]افکار منفی[SEP]افکار بیهوده[SEP]شر افکار منفی و اضطراباور خلاص[SEP]انجام کار مفید[SEP]بیدرمان شفا[SEP]همین ترفند ساده[SEP]چنین مواقعی[SEP]افکار بیمنطق ناشی[SEP]متوقف کردن هجوم فکرهای مسموم[SEP]فکرهای بیهوده
# 621th  corpus with score 0.70:
#  چگونه با کودکان درباره صحبت کنیم؟ فوق تخصص روانپزشکی کودک و نوجوان[SEP]بیشک کودکان و نوجوانان[SEP]دست ندادن روبوسی و بغل کردن و همچنین بهبود[SEP]کودک و نوجوان براساس سن خود[SEP]باره اخبار و اطلاعات امیدوارکننده[SEP]اصول مراقبتی و پیشگیرانه[SEP]کودک و نوجوان[SEP]اساس میزان فهم و اگاهی و صحت اطلاعات کودک و نوجوان دریافت و مطابق[SEP]باره چگونگی اگاهیبخشی[SEP]مرگ و میر[SEP]متخصص اعصاب و روان[SEP]اموزش کودکان و نوجوانان[SEP]گفته فوق تخصص روانپزشکی کودک و نوجوان والدین[SEP]سرماخوردگی انفلوانزا و یاد[SEP]طریق کمک پزشکان و پرستاران[SEP]درصد مرگ و میر[SEP]سرماخوردگی انفلوانزا و متخصص اعصاب و روان[SEP]خصوص مرگ ومیر ناشی
# 653th  corpus with score 0.70:
#  با تنش‌های زناشویی روز‌های چه کنیم؟ ماشین تعمیرات وسایل منزل ترجمه کردن نوشتن ورزش کردن تمرین خطاطی خیاطی و میباشند روان شناس بالینی[SEP]پژوهشگر روان شناسی بالینی اساسا فعالیت هابه دوبخش تقسیم[SEP]نمونه شناخت تیپهای شخصیتی برون گرایی درون گرایی احساسی منطقی کنشگری کنش پذیری کلی نگری جزیی نگری و رفتارها و گرایشات ناشی[SEP]گوش دادن فعال همدلی کردن پذیرش بی قید و شرط انعکاس احساسات گفتگوی سازنده[SEP]یکدیگر و کاهش تنشها و تعارضات یا سوءت عیب[SEP]ارتباط مثبت و مطلوب همسران[SEP]ماشین تعمیرات وسایل منزل ترجمه کردن نوشتن ورزش کردن تمرین خطاطی خیاطی و فعالیتهای تسلط بخش شامل نظافت خانه[SEP]ایجاد تفاهم و تعدیل اختلافات[SEP]نوع اول فعالیتهای لذت بخش درمنزل[SEP]درجه دوم فراگیری مهارتهای ارتباطی[SEP]نزدیکی و شدت روابط خانوادگی همراه[SEP]زوجین نیازمند داشتن نگرشهای منطقی و سازگارانه مهارتهای ارتباطی مهارتهای زندگی و مهارت حل[SEP]ازطریق مطالعه کتابهای علمی[SEP]مطالعه کردن کتابهای گوناگون تماشای تلویزیون گوش دادن[SEP]طریق مذاکره و گفتگوی سازنده[SEP]صحیح تفاوتهای فردی و انجام وظایف و تکالیف خاص[SEP]نوع برداشتها و تفکرات ( عدم شناخت صحیح ) زوجین[SEP]فعالیتهای هدفمند انه[SEP]فراگیری مهارتهای ارتباط موثر[SEP]مهارتهای ارتباطی کمتری[SEP]اعضای خانواده درسطح دانش تمایلات تفاوتهای فردی ارزشها[SEP]گوش دادن فعال همدلی کردن پذیرش بی قید و شرط انعکاس احساسات گفتگوی سازنده و فراگیری مهارتهای ارتباط موثر[SEP]فعالیتهای تسلط بخش لزوما منجربه[SEP]رسیدگی کردن
# 3520th  corpus with score 0.70:
#  رنجی که از اضطراب می‌کشیم مدیریت ذهن و عواطف[SEP]توان مدیریت و کنترل بدن ذهن و عواطف خود[SEP]کنترل اضطراب عضو توصیههایی[SEP]سالمندان کودکان جوانان و حتی زنان باردار[SEP]جوانی ۲۵ ساله و به ظاهر پرانرژی[SEP]رنج بسیار شدید[SEP]کنش مسوولانه مردم خودمراقبتی و همکاری[SEP]واسطه استرس و نگرانی مختل[SEP]شرایط غیرقابل پیشبینی و غیرقابل کنترلی[SEP]ان سواد گفتمانی[SEP]جمله دیگر علایم نشاندهنده حضور میهمان ناخوانده[SEP]انجام کارهای روزمره سردرد ترس[SEP]کنترل اضطراب[SEP]عوض میتوانیم ذهن و عواطف خود[SEP]رفتارهای مسوولانه[SEP]شکستن زنجیره تکثیر و کاهش تبعات اقتصادی اجتماعی سیاسی و فرهنگی ناشی[SEP]اندازه اقدامات مسوولان[SEP]تمرکز انزوای اجتماعی[SEP]پازل درست کردن اسم و فامیل خمیر بازی نقاشی کاردستی و موارد مشابه[SEP]تماشای فیلم و سریال بنشینیم کتاب
# 604th  corpus with score 0.70:
#  شرایط سخت برای کودکان چنین خبرهایی[SEP]اغوش پدربزرگ و مادربزرگ اغوش دایی و خاله و عمه و عمو[SEP]بهعنوان واسطه اموزشی[SEP]طبیعتگردی و اشنایی بچهها[SEP]حتی اسباب بازی[SEP]تایید تنگناهای مالی و سخت شدن معیشت[SEP]خانه و پای کلاسهای انل افتاب و هوای تازه[SEP]درباره چیزها[SEP]کنار فضای سالم گفتوگو[SEP]کلاسهای انل و خانه نشینی روابط بچهها[SEP]رعایت حال همسایهها[SEP]رعایت فاصله اجتماعی انها[SEP]اسباب بازی بچهها شوند‌ها[SEP]مدت سه چهار تا کار مختلف[SEP]انجام کارهای خانه[SEP]نتوانستهام خانوادهام[SEP]راههای خلاقیت مهرورزی گفتوگو و رفتارهای سالم و عاری[SEP]نسلهای ده بیاموزد[SEP]مسیولیت خانه[SEP]جریان مشکلات ریز و درشت من[SEP]سه برابر شدن امار مشاجرات خانوادگی[SEP]صدای پدربزرگ و مادربزرگ یا هرکدام[SEP]کودکان و نوجوانان شادی افرین و ارامبخش[SEP]فضای سالم خانواده[SEP]همه‌ها هجوم اخبار ناگوار و گفتوگوهای ناگوار‌تر خانوادگی[SEP]سوی پدربزرگ و مادربزرگ یا خاله و دایی و عمه و عمو[SEP]ان وقت کینه و حرفهای ناسالم[SEP]روزنامه نشستن[SEP]بزرگان فامیل و شنیدن صدای محبتامیز انها[SEP]امار کشتهشدگان یا حتی خبرهای ناگواری[SEP]بچه اسباب بازی گرانقیمتی[SEP]یک شرکت کوچک تزیینات منزل[SEP]دکتر عضو و دکترای تخصصی روانشناسی[SEP]مانع پرخاشگری شوند اشتباه
# 3238th  corpus with score 0.70:
#  مردم به سبک زندگی اهمیت بدهند اعضای خانواده[SEP]خانواده وقت[SEP]نحو مفید
# 631th  corpus with score 0.70:
#  دنیای کودکان را با تلخ نکنیم هیجانات و احساسات والدین تعیین کننده نوع واکنش کودک[SEP]الوده بودن دستان خود و دیگران یا مواد غذایی یا حتی وسایل اشپزخانه[SEP]عنوان والدین[SEP]یک فضای حمایتی[SEP]والدین ترسها و اضطرابهای خود[SEP]ترس خودمان[SEP]مراقبتی هشدارهای مکرر و ترساندن زیاد کودک[SEP]والدین ترسها و اضطراب هایشان[SEP]روال عادی زندگی روزمره[SEP]بترسیم واکنشی[SEP]تمام دغدغه والدین ترس[SEP]یک رسانه معتبر رسمی[SEP]تلخ نکنیم ایرنا ا[SEP]جای کنترل کودک[SEP]مبتلا شدن خودمان و عزیزانمان[SEP]اسکلت روان شناختی مستحکمی
# 590th  corpus with score 0.70:
#  چکار کنیم جسم روح سالمندان مقابل آسیب نبیند؟ سعی کردن فعالیت[SEP]پیشگیری و مراقبت سالمندان[SEP]سالمند[SEP]۳ ۵ لیتر مایعات و پایین اوردن درجه حرارت بدن[SEP]نان جو غلات سبوسدار و انواع سبزی و میوه تازه[SEP]دیابت‌های قلبی – عروقی تنفسی و نقص ایمنی[SEP]صورت داشتن علایم سرفه عطسه و تب[SEP]تغذیه سالمندان مبتلا[SEP]حالت ایدهال مراقبت[SEP]متخصص سلامت سالمندان[SEP]بین سالمندان[SEP]قرنطینه ماندن تجربه منحصر[SEP]مورد سالمندان[SEP]۱۴ مراقب علایم سرفه عطسه و تب[SEP]شرایط استراحت و خواب افراد سالمند[SEP]صورت داشتن تب و سرفه و عطسه[SEP]فرد سالمند[SEP]قند شکر و روغنهای جامد کره و چربیهای حیوانی موجود[SEP]بغل کردن لمس و بوسیدن پدر بزرگ و مادر بزرگ خود[SEP]امد عضو سالمند[SEP]در سالمندان اطراف یان[SEP]خروج فرد سالمند[SEP]دورهمی واقعی[SEP]دلیل اسیب پذیر بودن انها[SEP]سالمندان[SEP]خصوص سالمندان یک احساس ناخوش دی[SEP]ابتلا فرد سالمند به‌های زمینهای[SEP]روی ترحم[SEP]در سالمندان[SEP]خصوص سالمندان[SEP]ارتباط سالمندان[SEP]سالمندان
امه قرنطینه مزیتها[SEP]لایو‌های ورزش و تناسب اندام فعالیت[SEP]چه تحسین و بازخوردی[SEP]یک گفتوگوی صادقانه و صمیمی[SEP]یک نمایش خانوادگی[SEP]تهیه یک دفتر یادداشتهای روزانه[SEP]رستورانهای خودرو گذر[SEP]داشتن یک رژیم غذایی سالم و متعادل[SEP]احساسات مثبتتر علایم افسردگی[SEP]نیازهای شخص دیگر[SEP]دنبال چیزهای مثبت[SEP]یک اهنگ خانوادگی[SEP]یک یا دو ترفند سالم[SEP]فعالیتهای جریانی[SEP]انجام بازیهای ویدیویی یا استفاده
# 29th  corpus with score 0.69:
#  روایت آنهایی که یک بار از جسته‌اند نوید بهار[SEP]احتمال بازگشت بسیار زیاد[SEP]انتی بادی[SEP]جهت انتیبادی[SEP]انتیبادی همیشگی[SEP]ورود انهایی[SEP]دو احساس هرکدام بهصورت افراطی[SEP]جستهاند دیگر[SEP]جمله اخر[SEP]ماسک نزدن و میهمانی گرفتن[SEP]بدنم انتی بادی[SEP]خانوادهشان اکثرا[SEP]اصلا بدنت انتی بادی[SEP]زیر زدن ماسک[SEP]تمام خانواده همسرم اعم[SEP]همین خاطر دکتر[SEP]دختر جوان[SEP]میهمانی انتیبادی[SEP]سیستم ایمنی بدنت[SEP]سلامت خودشان و جامعه[SEP]مرد میانسالی[SEP]پاند می‌در[SEP]خصوصا انها[SEP]اتمام دوران قرنطینه[SEP]همان دختر جوان[SEP]چندان رعایت[SEP]انتی بادی شان[SEP]رعایت کردن افراطی[SEP]یک جمع انتی بادی[SEP]چه دارا و چه ندار[SEP]قید رعایت کردن
# 2273th  corpus with score 0.69:
#  فوت اولین مادرباردار مبتلا به در ایرانشهر بدن مادر[SEP]فوت یک مادر باردار[SEP]اقدامات پیشگیرانه[SEP]بین خانواده مادر باردار[SEP]امینی مادر باردار ساکن[SEP]اولین مادر باردار مبتلا
# 2528th  corpus with score 0.69:
#  بهبودیافتگان در چه صورتی می‌توانند روزه بگیرند؟ فاصله گذاری اجتماعی[SEP]شرایط روزه گرفتن بهبودیافتگان[SEP]فاصله گذاری[SEP]افراد بهبود یافتهای[SEP]افراد بهبودیافته[SEP]صورت رعایت نکردن نکات بهداشتی و فاصله گذاری اجتماعی افراد بیشتر
# 1226th  corpus with score 0.69:
#  چه افرادی باید تست بدهند؟ رعایت کنید[SEP]بین رفتن[SEP]چشایی یکی
# 3431th  corpus with score 0.69:
#  روایت‌های واقعی از سوگ خانواده قربانیان  سلامت خانواده[SEP]درمان مساله درمان رفتاری و دارویی[SEP]حتی خانواده همسرش[SEP]استفاده[SEP]امر دو احتمال اختلال استرس حاد یا تروما و اختلالات هذیانی[SEP]روال سرعت مرگ[SEP]سیستم درمان[SEP]مرگ عزیز یا اسیب جدی یا خشونت فیزیکی یا‌های[SEP]دلیل اختلال استرس حاد[SEP]دست دادن شبها و روزها[SEP]ارواح دوست اشنا و فامیل[SEP]رفتار جایگزین مناسب[SEP]روزهای سوگ[SEP]دست دادن ان فرد[SEP]صحبت صدای دخ
ودت[SEP]سحرگاه یک روز ماه رمضان[SEP]بیمههای قدرتمندی[SEP]سر خودم یا دیگران[SEP]خانواده قربانیان[SEP]تشخیص یک دقیقا نوع مداخله و نوع کاری[SEP]مدت سوگواری نداشته_باشیم بحث بعدی ترس[SEP]براساس دستورالعملهایی[SEP]غمگینی خشم اضطراب تنهایی و احساس خستگی[SEP]یک زمان پدربزرگش یا یک فامیل دیگر[SEP]یک سوگ تاخیری[SEP]عنوان اختلاس استرس حاد[SEP]خاطرات فرد افکار احساسات و مکانهای حادثه و موضوع خود حادثه
# 2958th  corpus with score 0.69:
#  موج هفته‌‎های آینده اوج می‌گیرد در خانه بمانید یک متخصص‌های عفونی[SEP]متخصص‌های عفونی افراد[SEP]متخصص‌های عفونی
# 619th  corpus with score 0.69:
#  تاثیر بر زنان باردار جنین مدیریت زایمان براساس مواردی[SEP]زنان باردار و جنین انها[SEP]اماکن شلوغ سیستم حمل و نقل عمومی و ارتباطات اجتماعی[SEP]پزشک متخصص[SEP]احتمال سقط جنین[SEP]سوالات مرتبط با و حاملگی زنان[SEP]زنان بارداری[SEP]شرایط عمومی زن وضعیت جنین و دوره حاملگی[SEP]خوردن ماههای حاملگی ( طولانیتر شدن یا کوتاهتر شدن دوره حاملگی[SEP]زنان باردار[SEP]دوره حاملگی[SEP]مشکلات مزمن تنفسی‌های کبد و کلیه اسم‌های قلبی فشار خون دیابت و سرطان[SEP]صورت ابتلای زنان[SEP]یک زن باردار[SEP]زنان باردار نمیتوانند انتی بادیهای
# 668th  corpus with score 0.69:
#  توصیه‌های پیشگیری از برای زنان باردار انها و یا انتقال الودگی به تازه مادر[SEP]شفقنا دکتر متخصص زنان[SEP]تغذیه زنان باردار[SEP]یکباره بیست ملاقات کننده[SEP]درباره زنان باردار[SEP]زنان باردار[SEP]دکتر یک متخصص زنان زمان ملاقات[SEP]متخصص زنان[SEP]سیستم ایمنی بدن زنان باردار
# 645th  corpus with score 0.69:
#   باعث سقط جنین نمی‌شود مادران باردار مبتلا[SEP]نه درباره ناهنجاری و نه سقط بیشتر[SEP]معمول موردی[SEP]احتمال سقط جنین[SEP]احتمال ابتلای زنان باردار[SEP]مورد دیده یا ثابت[SEP]شادابی بیشتر مادر و جنین[SEP]درباره مساله[SEP]احتمال ابتلای مادران باردار[SEP]فوت مادر باردار[SEP]اثر هم گزارش نشده_است نگرانیها و استرسهای دوران بارداری[SEP]خانه و رعایت نکات بهداشتی[SEP]واپسین ماههای بارداری[SEP]ناهنجاری و نه سقط بیشتر[SEP]دیر زمان مادر و خانواده[SEP]مورد مادران باردار مبتلا[SEP]مادران باردار روزها[SEP]مادر باردار خوردن فلان غذا یا میوه یا پوشیدن فلان رنگ[SEP]گریبان مادر[SEP]یک فرد معمولی[SEP]نگرانی مادران باردار[SEP]سقط جنین[SEP]مادران باردار[SEP]مورد هیچ مشکلی[SEP]مادران مبتلا[SEP]سوی مادران باردار
# 3230th  corpus with score 0.69:
#  سلامت جنسی در قرنطینه  داشتن رابطه زناشویی[SEP]دنبال انجام روابط زناشویی[SEP]خطر خشونت جنسی و خانگی[SEP]به‌های ریوی‌های قلبی دیابت‌های خودایمنی سرطان یا ضعف سیستم ایمنی بدن[SEP]تحکیم روابط عاطفی خانواده و کاهش اضطراب[SEP]ترشحات دستگاه تناسلی اقایان و خانمها[SEP]روابط زناشویی دستها[SEP]امکان انتقال[SEP]طریق روابط زناشویی[SEP]کاندوم و یا دیگر وسایل محافظتی[SEP]ارتباطات اجتماعی و حفاظتی و کاهش دسترسی[SEP]برخی روشهای پیشگیری[SEP]روابط زناشویی[SEP]علایمی شامل تب سرفه گلودرد یا تنگی نفس[SEP]رابطه زناشویی[SEP]یک همسایه دوست یا فامیل[SEP]طریق تنفس و هوای بازدم[SEP]افزایش خطر خشونت خانگی و جنسی[SEP]احتمال خطر خشونت خانگی[SEP]خانواده و دوستان میتوانند بهصورت رایگان و شبانهروزی[SEP]طبع روابط زناشویی[SEP]روشهای پیشگیری[SEP]انتقال عفونتهای مقاربتی[SEP]خدمات بهداشتی و درمانی
# 3408th  corpus with score 0.69:
#  چند نکته در باره تاثیر روانی؛ چه باید کرد؟ کتاب خواندن فیلم دیدن و بازیهای فکری[SEP]بهکارگیری روشهای خودمراقبتی[SEP]تغذیه ورزش و خواب مناسب سرگرمی و پرکردن و غنی سازی اوقات فراغت[SEP]احساس و افکار منفی[SEP]صورت داشتن نشانههای ازاردهنده[SEP]افکار منفی[SEP]دیگران شستن صحیح دستها حذف و محدود کردن مسافرتها و دوری[SEP]رفتارهای خودمراقبتی رعایت بهداشت فردی مدیریت هیجانات نحوه ارتباط و تماس
# 640th  corpus with score 0.69:
#  مادران به نوزادان‌شان شیر بدهند؟ مادران بستری شیردهی[SEP]داخل شیر مادر[SEP]بخش مراقبتهای ویژه[SEP]اهمیت شیر مادر[SEP]بانک شیر بیمارستانی[SEP]شرطی[SEP]دوشی ده شود بنابر ارجح[SEP]رعایت مسایل بهداشتی و ایمنی[SEP]شرط رعایت مسایل ایمنی[SEP]شیر مادر مبتلا[SEP]شیر مادر[SEP]بخش قرنطینه[SEP]شد همه شرایط[SEP]طریق شیر[SEP]سمت شیر مصنوعی و یا شیر خشک[SEP]برخی بیمارستانها و دانشگاههای علوم پزشکی کشور بانک شیر مادر[SEP]کشور و دنیا[SEP]شرایط[SEP]شیرخوار[SEP]دستورالعملهای بهداشتی[SEP]شیرخواران[SEP]رعایت مسایل ایمنی[SEP]طریق ترشحات تنفسی[SEP]طریق جفت و یا شیر مادر[SEP]حال عمومی مادر[SEP]مسایل ایمنی بهداشتی[SEP]حال بهبود و درمان[SEP]شرایط کاملا[SEP]حداقل دو متری[SEP]صورت امکان بین مادر و نوزاد پرده[SEP]شیر دوشی[SEP]بانک شیر[SEP]شیر[SEP]شیر شان[SEP]شرایط مادر[SEP]شرایط نادر که‌ها[SEP]راه ترشحات تنفسی[SEP]الودگیهای شیر[SEP]امکان شیردهی[SEP]امکان شیر دوشی[SEP]شیر انسانی[SEP]کودکان بزرگتر و شیرخواران چند ماهه[SEP]ترشحات تنفسی[SEP]امکان دوشیدن شیر انها[SEP]شیر خشک یا مصنوعی
# 3451th  corpus with score 0.69:
#  با شک تردید چه کنیم؟ وعدههای غذایی سالم و متعادل و انجام منظم ورزش و خواب مناسب[SEP]دنبال ازمایش و درمان بروم پرهیز[SEP]باور پیشگیری و درمان[SEP]بسیاری دیگر[SEP]پزشکان و سایر ارایهدهندگان مراقبتهای بهداشتی یا امدادگران[SEP]ورزش و تغذیه سیستم ایمنی خود[SEP]دیگر اقدامات کاربردی[SEP]هزینههای مادی و معنوی بسیاری[SEP]مرور تجربههای موفق استاد[SEP]تجربههای موفق بهبود ای گذشته[SEP]برخی خانوادهها تجربهها و اتفاقهای تلخ[SEP]مراکز بهداشتی[SEP]رسانههای ارتباط جمعی[SEP]رعایت پروتکلهای بهداشتی[SEP]شنیدن مکرر[SEP]طور بیست و چهار ساعته درباره[SEP]ماسک و رعایت بهداشت[SEP]بیشتر موارد[SEP]رسانههای اجتماعی[SEP]مانند‌های دیگر اصول پیشگیری و درمان[SEP]ارزوهای خوب و تجربه دلنشین زندگی خود[SEP]شک و تردید میکند نبود خودشناسی و نداشتن خودباوری[SEP]مدیریت فکری داشتیم بدونشک[SEP]اقدامات و ازمایشگاهها و بررسیها[SEP]انتقال بیمورد تجربههای مربوط[SEP]مدیریت افکار منفی[SEP]میان افراد مسن و افراد مبتلا به‌های مزمن[SEP]نگاه نخست رهایی[SEP]افکار منفی[SEP]حواسپرتی شیوه استفاده[SEP]تقویت کردهام و ترسی[SEP]باورهای درست[SEP]دیگر ریشههای باور نادرست[SEP]شیوه ترساندن و ایجاد رعب و وحشت[SEP]هجوم افکار منفی و اضطراب زا[SEP]کشش یا حرکتهای مدیتیشن جسمی[SEP]ورزش و تغذیه متا سب و رعایت فاصله و استفاده[SEP]مثبت کاذب و منفی کاذب و موارد مشابه[SEP]دریافت نتیجه[SEP]یک رمز مثلا فشار دادن انگشت یا پلک زدن[SEP]موضوع یا تجربه کردن روزهای سخت[SEP]اجتماعات و فعالیتهای مختلف و شیوه زندگیم[SEP]سمت خاطرههای دلنشین
# 3528th  corpus with score 0.69:
#  چگونه بر استرس ناشی از غلبه کنیم؟ عبادت و دعا و کمک[SEP]سلامت روانی خودمان[SEP]دوستان و اشنایان[SEP]مدت زمان خواندن و شنیدن و دیدن اخبار مربوط به[SEP]برقرای ارتباط و گوش دادن[SEP]دل درد یا اسهال سردرد و درد نقاط دیگر بدن کاهش اشتها یا خوردن بیش[SEP]شنیدن و دیدن اخبار نگران کننده و اسیبرسان فضای مجازی[SEP]کمک انها احساسات و هیجانات خودمان[SEP]همهگیری‌های عفونی یک اتفاق طبیعی[SEP]معرض خطر و نزدیکان انها[SEP]یا دانشگاههای علوم پزشکی[SEP]حرف افراد یا منابع خبری[SEP]شنیدن اخبار[SEP]کاهش سطح انرژی و فعالیت افزایش مصرف سیگار یا موارد[SEP]کارکنان یا مشاوران گروه[SEP]عصا بی شدن و جر و بحث کردن زیادی[SEP]نشانههای استرس مجموعهای[SEP]اخبار یک عفونی همچون[SEP]کشیدن سیگار و قلیان و مصرف مواد مخدر و داروهای محرک و مشروبات الکلی[SEP]جسم و روح و روان خودمان[SEP]استراحت کردن گریه کردن زیاد اضطراب بیش[SEP]نبودن دوم نشانههای جسمی[SEP]رفع نیازهای احتمالی جسمی و روحی برنامه[SEP]برنامههای سرگرم کننده مجازی[SEP]یاد اوردن چیزها و کارها احساس گیجی[SEP]نشانههای استرس اول نشانههای رفتاری شامل افزایش[SEP]حد چهارم نشانههای شناختی[SEP]پاسخهای رفتاری فیزیکی هیجانی و شناختی[SEP]کمک انها[SEP]روح و روان خودمان
# 3442th  corpus with score 0.68:
#  چگونه استرس را کنترل کنیم موارد اشتغال ذهنی انقدر شدید[SEP]مورد ده به خصوص نگرانی[SEP]مطالعه و تماشای فیلم زمان خود[SEP]عملکرد بهتری[SEP]کنار خانواده و عزیزان بودن کمک زیادی[SEP]نوشتن اشتغالات ذهنی و هر چیزی[SEP]افکار منفی ما[SEP]عضو هییت علمی[SEP]کارهای ناتمام زیادی[SEP]اشتغال ذهنی[SEP]پزشک دریافت و درمان[SEP]برنامه ریزی[SEP]شکل افکار وسواس گونه بروز میکند و افکار مزاحم یا همان افکار وسواس گونه[SEP]راههای تشدید اضطراب اطلاعات نادرست درباره و روند درمان[SEP]حضور ذهن[SEP]حضور ذهن و تمرینهای دیگری[SEP]افکار منفی[SEP]مرتب کردن وسایل خانه مطالعه ورزش و کارهای دیگری[SEP]پایان تمرینهای مدیتیشن[SEP]یاداوری ویژگیهای مثبت انها[SEP]حضور ذهن تمرینهای راه رفتن[SEP]الوده بودن محیط اطراف بررسی مداوم خود مبنی بر[SEP]صورت هجوم افکار منفی[SEP]اشتغال ذهنی و فکر کردن[SEP]کاهش افکار منفی و استرس و دغدغههای ذهنی[SEP]دغدغههای ذهنی و استرس خود
# 1808th  corpus with score 0.68:
#   فوگرافی سؤال رایج مهم درباره  ناشناخته بودن سوالات زیادی[SEP]بهدلیل ناشناخته بودن سوالات زیادی[SEP]مورد پرسیده میشود انا بهدلیل
# 3503th  corpus with score 0.68:
#  آیا وسواس به سراغ شما هم آمده است؟ شروع صدای پای[SEP]داشتن زندگی عادی و جلوگیری[SEP]اختلال وسواس اجباری فر فدایی متخصص اعصاب و روان[SEP]بیمارستانها و مراکز درمانی[SEP]فروشگاه موادغذایی مواد پروتیینی یا لبنی[SEP]خدای نکرده به گرفتار نشویم روزها[SEP]مواد ضدعفونیکننده‌ها[SEP]جان خود[SEP]شرایط کنونی وجود استرس[SEP]مراجع بهداشتی[SEP]رعایت اصول بهداشتی[SEP]ماندن شعار همه[SEP]تاثیر منفی[SEP]روح خودشان[SEP]موضوع تاثیر منفی[SEP]شرایط عادی[SEP]شرایط کنونی[SEP]ماده ضدعفونیکننده[SEP]نیاز خودشان[SEP]اضطراب میزان شست وشو و همچنین استفاده[SEP]ضدعفونی کردن وسایل و چندین نکته بهداشتی[SEP]رعایت نکات بهداشتی مهمترین اصل[SEP]زندگی عادی[SEP]نام اختلال وسواسی[SEP]ارزوهای همه مردم جهان[SEP]عادت نادرست مسیر زندگی انها[SEP]یاری خداوند[SEP]رعایت اصول بهداشتی همه[SEP]خاطر وسواس انها شدت
# 1473th  corpus with score 0.68:
#  نیمی از اشتباه را انجام دادند اعتماد پیشفرض[SEP]مرد یا زن غریبه اقا یا خانم[SEP]عمو یا خاله‌ی خود[SEP]اپلیکیشنهای نشاندهندهی ازدحام جمعیت و مبتلا[SEP]ماسک رعایت فاصلهی اجتماعی و شستن مرتب دستها کمکهای موثری[SEP]طبق ظرفیت شرکتهای دارویی[SEP]سیستم ایمنی بدن ضعیفی
# 607th  corpus with score 0.68:
#  راهکارهایی برای مدیریت ترس اضطراب کودکان در دوران  بازی و نشاط و بازیهای مناسب خانگی کنترل اضطراب انها[SEP]گروه سلامت نوزادان کودکان و شیرمادر[SEP]صورت امکان خواب و وعدههای غذایی معمولی کودک[SEP]ممنوعیت فعالیتهای خارج[SEP]ایجاد روابط عاطفی[SEP]گرامیداشت هفته ملی کودک[SEP]همه کودکان بدرفتاریها و کج خلقی[SEP]برگزاری هفته ملی کودک[SEP]دوران فعالیت فیزیکی و پیشگیری[SEP]هنگام خستگی گرسنگی ترسیدن یا یادگیری مهارتهای مستقل[SEP]یک جریان روزمره منعطف ولی ثابت[SEP]کودکان بسیار دشوار[SEP]رابطه کاهش ترس و نگرانی کودکان[SEP]مفهوم و ضرورت تعطیلی و قرنطینه[SEP]چاقی و اضافه وزن سلامت و ایمنی تغذیه مناسب شیرخواران و کودکان[SEP]مدیریت ترس نگرانی ناراحتی و ایجاد اسایش[SEP]رویکرد بازی نشاط و تحرک فیزیکی[SEP]فاصله گذاری اجتماعی[SEP]اساس نیاز کودک[SEP]خانه تعطیلی مدارس و مهدهای کودک دوری[SEP]منظور میتوان یک شعر ۲۰ ثانیهای ساخت و چند حرکت[SEP]مدیریت ترس و نگرانی کودکان[SEP]وضعیت زندگی رشد و بالندگی کودکان روشنترین نشانه توسعه و توان هر جامعهای[SEP]ویژگیها نیازها و خواستههای کودکان[SEP]فعالیتهای مختلفی[SEP]هفته ملی کودک[SEP]مدیریت ترس و نگرانی
# 642th  corpus with score 0.68:
#  استرس‌های در کودکان مراقب روح روان بچه‌ها باشیم توصیههای بهداشتی مبنی[SEP]حدودیت ارتباط و تماس فیزیکی کودکان و حتی بزرگسالان[SEP]عضو هییت علمی[SEP]ارتباط نزدیک و مناسبی[SEP]فوق تخصص روانپزشکی کودکان و نوجوانان[SEP]فوق تخصص روانپزشکی کودکان و نوجوان[SEP]بزرگ ترها[SEP]دومین توصیه عضو هییت علمی[SEP]مهمترین عاملی[SEP]گل خواندن مطالب کتاب و یا انیمیشن هایی[SEP]خودکشی و یا اسیب رساندن[SEP]موجبات استرس کودکان[SEP]مهمترین عللی[SEP]سوگواری کودکان درها[SEP]بزرگسالان راههای مختلفی[SEP]دست دادن معلم دوست و یا همکلاسی
# 416th  corpus with score 0.68:
#  می‌گویند من را در محله‌مان منتشر کرده‌ام پس از بازگشت به اداره نگذاشتند پشت میزم بنشینم مشکلات روحی و روانی[SEP]کارمند یک شرکت باربری[SEP]برخی بهبود[SEP]کارفرمایان و مدیران ادارات و سازمانها[SEP]محیط کاردک‌تر مسیول درباره[SEP]مراکز درمانی[SEP]گواهی سلامت درمانگاه[SEP]انجام دوباره مع ه و ازمایشهایی[SEP]کارمندان ادارات دولتی[SEP]بیمارستان راهاندازی[SEP]بهبودیافتگان خودش[SEP]عوامل مختلف ژنتیکی و محیطی افراد[SEP]سوی همسایگان[SEP]روابط کاری خانوادگی و محیط کارشان تجربه ناخوش د و عذاباور[SEP]اتاق کو وید مشکلات روحی و تنش[SEP]بهبودیافتگان استرس[SEP]محل کار[SEP]برخی موارد سیتیاسکن[SEP]رابطه دکتر درباره پیامدهای روحی و روانی ابتلا[SEP]اجازه بازگشت[SEP]سلامت روان شهروندان بهویژه مبتلایان[SEP]خانوادهام حرفها[SEP]دوران بهبودی[SEP]درمانگاه مخصوص[SEP]اپارتمان شخصیشان[SEP]فروکش کردن موج اپیدمی رخ[SEP]مانع ورود انها[SEP]بهبود یافتگان مهربان[SEP]بهطور کل محیط اطراف ازارشان[SEP]من و خانوادهام فشار روانی زیادی[SEP]خانواده و همسایگان خود[SEP]دو مقوله دردناک
# 3054th  corpus with score 0.68:
#   تا چند ساعت زنده می‌ماند؟ بچههای مدرسهای کوچکترین[SEP]رعایت مسایل بهداشتی[SEP]دکتر - فوق تخصص‌های عفونی[SEP]متخصص‌های عفونی شست و شوی مرتب دستها[SEP]جدید دست ندادن عطسه و سرفه نکردن[SEP]یک برنامه رادیویی[SEP]دکتر متخصص‌های عفونی و استاد
# 1238th  corpus with score 0.68:
#  اگر گرفتیم با نوزاد در خانه چه کنیم؟ تمام پروتکلهای بهداشتی[SEP]کم شدن و یا رفع علایم[SEP]صورت نداشتن علایم[SEP]۱۲ سال و کودکان ۱۲ تا ۱۷ سال[SEP]اعضای خانواده[SEP]امار مرکز کنترل و پیشگیری از‌ها[SEP]کودکان و نوزادان و جدی[SEP]باید وضعیت نوزاد و کودک[SEP]علایم خفیف کودک[SEP]صورت بروز شدید علایم او[SEP]فرد مبتلا و مخصوصا مادر[SEP]پروتکلهای بهداشتی افراد مبتلا[SEP]فرد یا افراد مبتلا[SEP]شیردهی و یا تماس ضروری فرد مبتلا[SEP]مصرف داروهای معمول سرماخوردگی[SEP]خانوادهای فرد مبتلا[SEP]افراد مبتلا[SEP]فرد مبتلا[SEP]روشهای خانگی و داروهای معمول[SEP]پروتکلهای بهداشتی
# 3501th  corpus with score 0.68:
#  مثبت اندیشی راهکار خروج از استرس  حال رشد و مدرن امروزی[SEP]موقع ه صرف صبحانه و یا توانایی نه گفتن[SEP]علایم خستگی و فرسودگی انان[SEP]مقابل هر گونه رفتار و یا حتی گفتار[SEP]همراه خانواده[SEP]نوسانات و فراز و نشیبهای عاطفی شدید[SEP]روان ادمی[SEP]روان مفید[SEP]جمعیت میلیاردی جهان[SEP]حقیقت ظرفیت مقاومت و خودکنترلی فرد[SE
#  چند راهکار اساسی برای حفظ دوستان در شرایط  جان دوست خود[SEP]دوست[SEP]دوست شما[SEP]گوشی همراه نداریم یا امکانات پیشرفته[SEP]دوست یابی[SEP]زمان دوری و دوستی[SEP]همان دوستی[SEP]ثابت کردن دوستی[SEP]چنین امکان[SEP]حفظ دوستان[SEP]خصوص دوست یابی[SEP]یک معنایی[SEP]دوستان[SEP]هم گل و نامه بفر وستی د[SEP]دستکش و ماسک او[SEP]صندوق پست[SEP]دوستی[SEP]دوستی خود[SEP]رنجیده خاطر و شدن دوستمان[SEP]همان دوست خود[SEP]طریق تلفن و شبکههای مجازی[SEP]مسایل دوست یابی[SEP]همین دوستی[SEP]دوست خود[SEP]دوستان خود[SEP]واژه دوست[SEP]دوستیها[SEP]دستاورد نتیجهای[SEP]دل دوستمان[SEP]دوست ما[SEP]جواب نامههای یکدیگر[SEP]دوستمان[SEP]طریق دادن جزوات یا نتایج درس هایی[SEP]دست او
# 66th  corpus with score 0.68:
# ...
# 3486th  corpus with score 0.67:
#   استرس راه‌های مقابله مسایل تندرستی[SEP]ان افکار و احساسات مقابلهای و مفید[SEP]ایجاد فعالیتهای پرنشاط و سرگرم کننده[SEP]دفع استرس و عدم امنیت[SEP]استرس و نگرانی گستردهای[SEP]تبیین راههای مقابله[SEP]کنار اعضای خانواده[SEP]دقت و بصیرت انسانها[SEP]خودمان و اعضای خانواده[SEP]نرخ ابتلا و میزان و جهانی بودن[SEP]کنار بهداشت جسمی[SEP]تقویت سیستم ایمنی[SEP]قدرت لایزال الهی[SEP]لذت کنار عزیزان بودن و شکرگزاری نعمت بزرگ[SEP]جای عکسالعملهای انفجاری[SEP]صورت پاسخ جنگ یا گریز[SEP]بین اعضای خانواده[SEP]شادی و ارامش خود و اعضای خانواده[SEP]صورت فهرست وار نکاتی[SEP]حالتی مبهم و ناخوش د ازهر اس و نگرانی[SEP]میان گروههای اسیب پذیری[SEP]انسان موجودی هوشمند و توانمند[SEP]عملکرد سیستم ایمنی[SEP]مراقبتی رعایت بهداشت فردی و کنترل و مدیریت هیجانی و تماس و ارتباط[SEP]حالت تهدید سلامت جسمی یا روانی[SEP]موقع ورزش و حرکات بدنی[SEP]تغذیه مناسب و صحیح خواب و استراحت[SEP]همین راستا[SEP]یگانه خالق هستی کند عاملی[SEP]همدلی و مراقبت و ملاطفت بپردازیم سالمندان[SEP]سلامتی تهدیدهای اجتماعی و اقتصادی گستردهای[SEP]میتواند جوی سالم[SEP]سلامت روانی و ارامش انسانها[SEP]حفظ ارامش و شکیبایی تنشهای حاصله[SEP]افزایش انرژی ما و مقابله[SEP]جنبههای خوب زندگی و تمرکز[SEP]مسایل و کنترل شرایط سخت[SEP]سیستم ایمنی[SEP]تمرکز بیش از حد و وسواس گونهای[SEP]استرس روانی[SEP]مقابله و دفع ان بپردازیم[SEP]احساس خطر جدی و ناتوانی[SEP]مدیریت و برنامهریزی کارهای همیشگی[SEP]سرعت انتشار و عدم توانایی[SEP]اثر کاسته شدن برخی هورمونها[SEP]توانایی سیستم ایمنی[SEP]همدلی و مراقبت و ملاطفت[SEP]دوستان و حمایتها و همدلیها[SEP]معرض اسیبها و تنشهای[SEP]ضعف سیستم ایمنی
# 3525th  corpus with score 0.67:
#  ۴ گانه سلامت برای غلبه بر استرس  وضعیت دعا مناجات و انرژیهای مثبت ناشی[SEP]حقیقت ارامش[SEP]دانایی ( سلامت روحانی[SEP]رعایت اصول دعا و مناجات[SEP]ارتقا سیستم ایمنی بدن[SEP]زیبایی ( سلامت روحانی[SEP]چهار رویکرد شامل توانایی ( سلامت جسمانی ) دانایی ( سلامت روحانی[SEP]توانمندیهای اقتصادی علمی و اجرایی[SEP]اصطلاح ادبی[SEP]برابر دشواریها و گاه ملایمت‌ها[SEP]طریق رعایت نصایح متخصصان علوم پزشکی[SEP]قران باران[SEP]یک جامعهشناس و استاد دانشگاه[SEP]باهر رعایت اصول بهداشتی - پزشکی و مباحث روانشناختی[SEP]طریق رعایت اصول بهداشتی
# 3459th  corpus with score 0.67:
#  اهمیت سلامت روان روان درمانی در دوران  افراد توانایی تنظیم و تعدیل هیجانهای منفی[SEP]انجام کارها و درسهای تان[SEP]یک برنامه فعالیتی[SEP]حال تجربه کردن[SEP]استرس یک واکنش طبیعی[SEP]یک فردی تلفنی[SEP]روان درمانی[SEP]خانه یا برنامهای بهزیستی[SEP]بهبود دهنده سلامت روان[SEP]اضطراب افسردگی وسواس و عدم تمرکز و ز[SEP]یک برنامه[SEP]برنامهای[SEP]زمان مطالعه – یا کار خود[SEP]خانواده کلاسهای انل[SEP]دوران و ضرورت انجام انها[SEP]زمینههای مختلف فیلمها و سریالهای[SEP]شرایط تطبیق[SEP]ادامه نکاتی[SEP]تماس تلفنی تماس تصویری[SEP]معرض اطلاعات و اخبارهای بد و استرس امیز[SEP]مسایل و مشکلات و احساسات خودشان[SEP]برنامه ریزی[SEP]انواع روان درمانی انل و روانکاوی و مشاوره روانشناسی انل و مجازی[SEP]احتمالا سلامت روان[SEP]بسیاری[SEP]بازدهی بهتری[SEP]اطلاعات پیامها و اخبار‌ها[SEP]نوعی رفتارها و سبک زندگی مان[SEP]تماس تلفنی تماس تصویری و )[SEP]فراز و نشیب هایی[SEP]تهیه یک برنامه بهزیستی[SEP]کار یا مدرسه و دانشگاه[SEP]حفظ و بهبود سلامت روان تان[SEP]بهبودی سلامت روان[SEP]برنامهی روزانهی خود[SEP]برخی موارد[SEP]انجام کارها بازیابی د[SEP]احتمالا احساسات مختلف و متفاوتی[SEP]خدمات روانشناسی[SEP]اضطراب افسردگی وسواس و عدم تمرکز و باشید[SEP]اهداف بسیار بلند پروازانه[SEP]انواع روان درمانی افسردگی[SEP]وجود همه استرسها و اسیب هایی[SEP]یک روان درمانگر خوب
# 666th  corpus with score 0.67:
#  چگونه توصیه‌های بهداشتی درباره را به کودکان آموزش دهیم؟ همین شادیهای مقطعی کوچک[SEP]عنوان تنش اجتماعی[SEP]سیستم ایمنی[SEP]شرایط کنونی[SEP]یک روانشناس اجتماعی[SEP]انسانها براساس عوامل مختلفی[SEP]توصیههای پیشگیرانه[SEP]روانشناسی اصلی مبنی[SEP]گسستن یا شکستن مسایل بزرگ[SEP]طور قطع ضعیف بودن سیستم ایمنی بدن[SEP]میتواند روان انسانها[SEP]پی ان سیستم ایمنی بدن[SEP]شرایط کنونی جامعه[SEP]جای افزایش اضطراب تنشهای اجتماعی[SEP]ترس میشوند‌های سایکوسوماتیک[SEP]غیر صورت روان جامعه
# 1597th  corpus with score 0.67:
#  آنفلوانزا سخت‌تر از  فوق تخصص عفونی اطفال ما[SEP]۵ سال مادران باردار کادر پزشکی و افراد دارای مزمن و نقص ایمنی برسد فوق تخصص عفونی اطفال ما[SEP]ایا رعایت فاصله اجتماعی و شستن دست و ماسک زدن[SEP]یک فوق تخصص عفونی اطفال[SEP]عفونت همزمان انفلوانزا با[SEP]عفونت همزمان دو
# 93th  corpus with score 0.67:
#  نمکی طولانی شدن جامعه کودکان نوجوانان را گونه خواهد کرد پاند می‌جدیدی[SEP]رفت و امدهای خانوادگی[SEP]الگوی زندگی[SEP]وزیر بهداشت[SEP]تشکیل و برنامههای مشترک[SEP]یک نامهربانی[SEP]چگونه زندگی کردن[SEP]طولانی شدن پاند می‌جامعه[SEP]برای‌های ده کشور[SEP]همکاری بلند مدت و اجرای برنامههای مشترک غیر[SEP]بهداشت روان[SEP]الگو پذیری قوی خانوادهها[SEP]بستن کمربندی ایمنی سرعت مجاز و رفتارهای نابهنجار[SEP]انجام طرح مشترک اموزش شیوه تغذیه و ورزش منظم[SEP]معنی زندگی کردن[SEP]اغوش پدربزرگ یا مادربزرگ[SEP]پرفشاری خون سکتههای قلبی و مغزی و سرطانها[SEP]همدلی وفاق ملی و تجربه همگرایی و همدلی[SEP]تاثیر اموزههای پدران و مادران خودمان[SEP]مهرورزی و بازی کودکانه[SEP]ظرفیت بی بدیل دانشاموزان و معلمان[SEP]شیوه درست زندگی کردن[SEP]قالب برنامههای مشترکی[SEP]بهم ریخته دانشاموز[SEP]تغییر الگوی زندگی[SEP]اقدامات پیشگیرانه و حل مشکلات پوسیدگی و مشکلات دهان و دندان[SEP]حریم دیگران و رعایت قوانین رانندگی[SEP]ابعاد دیگر خانواده[SEP]بهداشت مدارس واکسیناسیون بهداشت دهان و دندان[SEP]نظر فضای فیزیکی خانه یا وضعیت اقتصادی شرایط مناسبی[SEP]سایر ابعاد جامعه[SEP]گفت بحث بهداشت روان[SEP]کمیتهای مشترک[SEP]پیشگیری از‌ها و تغییر الگوی زندگی تهیه و تدوین
# 54th  corpus with score 0.67:
#  از تو ممنونم  زندگی ما[SEP]کیفیت یا خرید بیش از حد کفش و کیف و لباس[SEP]زندگی و خودمان[SEP]ایا زندگی عادی[SEP]روزهای اول افسرده و غمگین[SEP]درس خواندن بهصورت مجازی[SEP]دوره بسیار اموختهاند انها[SEP]سلامتی و سبک زندگیمان[SEP]جهت توسعه فردی[SEP]و مجازی شدن کلاسها[SEP]افزایش کیفیت زندگیام[SEP]میهمانی و معاشرتهای خانوادگی و دوستانه[SEP]شروع کردهام موسیقی و اواز و زبان[SEP]کارهای متفاوت عدهای دیگر[SEP]روزگار متعارفی[SEP]حرف میزدم بیست کیلویی وزن[SEP]شتاب زندگی روزمره و روابط بیفایده[SEP]جریان زندگی[SEP]که خیلی کار میکنی یا سفر[SEP]زندگی عادی[SEP]زندگی سابقم[SEP]حوزه توسعه فردی[SEP]درس خواندن[SEP]شتاب زندگی روزمره[SEP]اموزش انل[SEP]چندین سال بهخاطر[SEP]تسلیم سرعت بیوقفه و بیمورد زندگی[SEP]خیلیها ترسناک[SEP]ترکش کردهام فیلمهایی[SEP]یادگیری زبان[SEP]رشد و توسعه فردی سحر[SEP]کل زندگیام عوض شده‌ها[SEP]یک دوره یک ساله اموزش انل[SEP]تغییرات زندگیام
# 1734th  corpus with score 0.67:
#  بهبودیافتگان چه مدت در برابر ابتلای مجدد مصون هستند؟ دستورالعمل بهبودیافتگان[SEP]زمانیکه علایم مجدد[SEP]سخنگوی براساس جدیدترین یافتههای علمی[SEP]برابر ابتلای مجدد[SEP]در برابر ابتلای مجدد[SEP]انجام مجدد تست تشخیصی
# 629th  corpus with score 0.67:
#  حفظ سلامتی زنان باردار در دوران  زنان باردار مشابه کسانی[SEP]بارداری و زایمان زنان باردار شامل افزایش زایمان زودرس و افزایش میزان سزارین[SEP]نتایج ازمایشگاهی کاهش یک نوع[SEP]اماکن سربسته یا محدود[SEP]اب و صابون تمیز و ضدعفونی کردن سطوحی[SEP]دکتر دکترای سلامت باروری[SEP]صورت مبتلا شدن خودشان[SEP]رعایت صحیح بهداشت فردی و خود مراقبتی ابتلا[SEP]اهمیت موضوع[SEP]پزشک زنان و یا سایر خدمات[SEP]ازجمله زدن ماسک درصورت[SEP]عضو هییت علمی و معاون پژوهشی[SEP]محل زایمان براساس[SEP]مراکز درمانی[SEP]مراقبتهای انجام شده[SEP]محکم کردن روابط خانوادگی[SEP]حفظ فاصله اجتماعی[SEP]زمان مناسبترین[SEP]مسیله زایمان[SEP]انتخاب بهترین و امنترین محل زایمان[SEP]محققان زنان باردار[SEP]عضو هییت علمی[SEP]امکان سرویس بهداشتی جداگانهای[SEP]مع ات پزشکی منظم[SEP]پزشک زنان یا مامای خود[SEP]اطرافیان زنان باردار[SEP]خانمهای باردار[SEP]دکترای سلامت باروری[SEP]مورد بدن خود و نوزادشان[SEP]بیمارستان و الوده نشدن احتمالی مادر و جنین[SEP]کدام بیمارستان[SEP]درد زایمان[SEP]بند ناف یا شیرمادر[SEP]خانه و رعایت فاصلهگیری اجتماعی خود[SEP]نگرانیهای زنان باردار ابتلای جنین[SEP]افراد نزدیک خانواده[SEP]محل زایمان[SEP]نام لنفوسیت و افزایش cr p[SEP]بهترین کار رعایت کلیه اقدامات احتیاط امیز و ضروری[SEP]مادران باردار[SEP]کمک پزشکی گرفته_شود مادرانی[SEP]افزایش سریع تعداد موارد ابتلا[SEP]ابتلا به است دکتر زنان[SEP]داشتن یک برنامه[SEP]دلیل هرج و مرج عجیب ناشی[SEP]زنان باردار[SEP]بدن و سیستم ایمنی زنان باردار[SEP]نوزاد و تمیز یا ضدعفونی کردن سطوح[SEP]مراقبین سلامت خود[SEP]رعایت تمام نکات بهداشتی و احتیاطی
# 2551th  corpus with score 0.67:
#  ۳ سناریو از رفتار احتمالی در آینده روزه گرفتن و بهبودیافتگان[SEP]مرکز تحقیقات سل بالینی و اپیدمیولوژی[SEP]روزه گرفتن بهبود یافتگان[SEP]فاز همهگیری[SEP]حال تاکید میشود افراد و یا حتی بهبودیافتگان[SEP]روزه گرفتن[SEP]مدیر بخش عفونی[SEP]متخصص عفونی[SEP]طرح فاصله گذاری اجتماعی[SEP]تجمعات کنفرانسها گردهماییها و سایر تجمعات[SEP]ادامه طرح فاصله گذاری اجتماعی
# 3464th  corpus with score 0.67:
#   امید راه نجات از  متخصص اعصاب و روان فرد امیدوار[SEP]شکست نمی‌هراس د و راههای متفاوتی[SEP]محمدرضا روانشناس بالینی[SEP]راهکارهای درمانهای روان و جسم[SEP]کمک متخصصین روانشناس و روانپزشک شناسایی[SEP]فرد یا افراد امیدوار[SEP]نوع صحیح روابط امیدبخش و تمرینات خاص معنوی[SEP]رعایت دستورالعملهای بهداشتی استفاده[SEP]افراد موفق یا کسانی[SEP]زندگی شخصی و کاری خود[SEP]اضطراب افسردگی و ناامیدی[SEP]دیگر لیاقت عشق ورزی[SEP]بین اقشار اسیب پذیر و محروم جامعه[SEP]افراد امیدوار[SEP]بهترین ابزار رسیدن[SEP]فکر درمان انان شتافت وابستگی یا نیاز غلبه و بقا[SEP]مسیر رسیدن[SEP]تمامی افراد جامعه[SEP]عدم کارکرد سیستمهای انگیزشی[SEP]بین افراد جامعه[SEP]سه شرط امیدوار بودن
# 1584th  corpus with score 0.67:
#  از بدون علامت تا خستگی مرگ احتمالی نفع جامعه[SEP]متخصص فرهنگ اصالت فرد[SEP]بهعنوان مسیر ورود‌ها[SEP]پنجمین متغیر وضعیت ایمنی بدن افراد[SEP]انگ برچسب زنی و مخفی کردن بهصورت و جمعی[SEP]فعالیت فیزیکی تغذیه مناسب و عدم مصرف سیگار و الکل[SEP]فرهنگ اصالت جمع[SEP]سالمندان افراد چاق دیابتیها[SEP]برنامه زندگی خود[SEP]رعایت فاصله گذاری اجتماعی زدن ماسک و شستشوی دست[SEP]حاصل تعامل درجات متفاوت ژنتیک رفتار و اجتماع[SEP]صورت شدید بودن ابتلا یک عضو خانواده هشداری[SEP]برابر غیر قابل پیشبینی استام[SEP]بافت میزبان یا ایمنی بدن[SEP]متخصص پزشکی اجتماعی افراد[SEP]سیستم ایمنی[SEP]متخصص پزشکی اجتماعی[SEP]هر نوع نقص ایمنی مادرزادی یا اکتسابی امیری طبقهبندی[SEP]داشته_باشیم متخصص فرهنگ اصالت فرد[SEP]سازوکار پاسخ سریع سیستم ایمنی[SEP]دلیل متفاوت بودن پاسخهای دفاعی[SEP]دلایل مختلف سیستم ایمنی[SEP]سیستم ایمنی شما واردشده و درنتیجه احتمالا جدیتری[SEP]نتیجه خطر شدت گرفتن[SEP]خطر شدت
# 2898th  corpus with score 0.67:
#  روش‌های مراقبت از پس از ترخیص از بیمارستان سایر اعضای خانواده[SEP]تعداد کسانیکه[SEP]اساس شرایط جسمی و وضعیت شما[SEP]عفونی کردن سطوحی[SEP]ظروف سایر اعضای خانواده
# 2733th  corpus with score 0.67:
#  وضعیت به خانواده او اطلاع‌رسانی می‌شود روسای دانشگاههای علوم پزشکی سراسر کشور[SEP]روسای دانشگاههای علوم پزشکی[SEP]تعامل برقراری ارتباط ارامش بخش
# 2952th  corpus with score 0.67:
#  نحوه نگهداری مبتلا به در منزل هفته طول[SEP]علایم خفیف[SEP]تشدید علایمی
# 2518th  corpus with score 0.67:
#   از مادر باردار به جنین منتقل می‌شود؟ جنین مادران مبتلا[SEP]مطالعات گسترده و جامع درباره عوارض[SEP]مادر و جنین[SEP]دوران بارداری[SEP]همان سن و شرایط جسمی نخواهد_بود مختار[SEP]ابتلا به و زایمان زودرس[SEP]در دوران بارداری[SEP]سه ماهه نخست بارداری[SEP]دکتر جراح و متخصص زنان و زایمان فلوشیپ ناباروری و عضو تیم تخصصی[SEP]بارداری خطر ابتلا به[SEP]عوارض ابتلا[SEP]معاشرتهای غیرضروری[SEP]عضو تیم تخصصی[SEP]پرسشهای متداول خانمهای باردار[SEP]خانمهای باردار[SEP]دوران بارداری و گفت شستشوی مرتب دستها[SEP]عوارض مستقیم[SEP]باردار بودن خطر ابتلا به[SEP]ابتلا به و خطر بروز ناهنجاریهای جنینی همانطور[SEP]سلامت مادر و جنین[SEP]مراکز بهداشتی و درمانی[SEP]موازین پیشگیرانه و محافظتی[SEP]امارها نشاندهنده خطر کم ابتلای جنین[SEP]دغدغههای اصلی خانمهای باردار
# 616th  corpus with score 0.67:
#  مطالعات جدید؛ اثر بر زنان باردار به چه صورت است؟ زنان باردار مبتلا[SEP]۱۱۴۳ ۲ زن باردار[SEP]علایم کمتری[SEP]میان زنان باردار مبتلا به[SEP]مراقبتهای ویژه و امکانات تخصصی[SEP]نوزاد داشته_باشند مادرانی[SEP]متخصصان بهداشت و درمان[SEP]مادر مبتلا[SEP]زنان باردار سه دورهی[SEP]زنان باردار[SEP]مراقبتهای ویژه[SEP]چاقی فشار خون بالا و دیابت
# 2404th  corpus with score 0.67:
#  آیا کودکان منتشرکنندگان پنهان هستند؟ بازگشایی مجدد مدارس و مهد کودکها[SEP]نیر اپیدمیولوژیک[SEP]کودکان الوده[SEP]ابتلا کودکان مدرسهای[SEP]چنین شرایطی محدود و بسیار پایینتر[SEP]اکثر کودکان الوده علایم خفیف و یا حتی هیچگونه علایمی[SEP]مبتلایان کودک[SEP]اندام انها شود تجزیه و تحلیل اولیه او[SEP]همان ابتدای انتشار جدید[SEP]کودکان مبتلا به cov id[SEP]عدم پیشرفت تحصیلی و عدم دریافت پشتیبانیهای اجتماعی[SEP]صراحت مخالف بازگشت سریع کودکان[SEP]کریستین تن شناس و نویسنده[SEP]نشانگر میزان الودگی فرد[SEP]رشته یک کودک نه ساله[SEP]میان کارشناسان و خانوادهها[SEP]نگرانیهای زیادی[SEP]درمانهای بالقوه[SEP]بازگشایی مدارس[SEP]زیرا‌های تنفسی[SEP]دانش اموزان برخی مناطق[SEP]السد پژوهشگر‌های عفونی کودکان[SEP]نویسندگان مطالعه[SEP]محقق طب تنفسی کودکان[SEP]زمان بازگشایی انها[SEP]سطح ایمنی بدن کودکان[SEP]سیتوکین بالاتری[SEP]اکثر کودکان[SEP]۹ دانش اموز و ۹ کارمند مبتلا[SEP]استانه بازگشایی مدارس[SEP]همان اندازه بزرگسالان[SEP]بافت کودکان[SEP]میزان سیتوکین‌های[SEP]هنگام انفلوانزای مرغی h۵n۱[SEP]کودکان بخش کمی[SEP]علایم cov id[SEP]ریههای کودکان حاوی گیرندههای ace[SEP]سطح سیتوکین بالاتری[SEP]برخی‌های نادر کودکان ف[SEP]سیستم ایمنی بدن[SEP]مدارس ابتدایی و دبیرستانهای تماس[SEP]شرایط عادی و البته بازگشایی مدارس ابهامات و تضادها[SEP]نقش کودکان[SEP]تجزیه و تحلیل[SEP]کودکان مدرسهای مبتلا[SEP]روشی مشابه بزرگسالان پخش[SEP]کودکان مبتلا[SEP]استانه امادگی برخی[SEP]بررسی میزان انتی بادیها[SEP]کودکان[SEP]تلاشند تا رابطه میان جدید و کودکان[SEP]ده میزان ابتلا[SEP]کودکان مدرسهای[SEP]خانوادهها کودکان[SEP]کلاسها و بسته کردن زمینهای بازی[SEP]روی واکنش سیستم ایمنی بدن کودکان[SEP]ابتلای کودکان
# 3479th  corpus with score 0.67:
#  کارهای کوچک برای بهتر شدن سلامت روان در زمان  بردن استرس یا حداقل مدیریت کردن استرس افسردگی یا اضطراب[SEP]مردم و ایجاد روابط مثبت راهبردهای یادگیری[SEP]سلامت روانی یا پشتیبانی روانی - اجتماعی[SEP]داشتن سلامت روانی ضعیف[SEP]بینانه روشهای یادگیری[SEP]سلامت روانی و بهزیستی خود[SEP]معرض خطر ابتلا[SEP]سلامت روانی بهینه[SEP]معرض خطر پریشانی و اض ظر[SEP]زندگی روزمره کاری تحصیلی یا روابط شخصی[SEP]سلامت روان افراد بسیار نگران کننده[SEP]افراد دیگر یافتن یک ورزش منظم یا فعالیت بدنی
# 3461th  corpus with score 0.67:
#  خلق تنگ در دوران را با افسردگی اشتباه نگیرید متخصص روانشناسی بالینی[SEP]ماهیت کنترل احتیاط و رعایت بهداشت[SEP]راه حل مناسبی[SEP]بیشترین نکتهای[SEP]تجربه دو هفتهای تنگی خلق و غمگینی[SEP]دوران متخصص روانشناسی بالینی[SEP]ابتلا به و یا اضطراب[SEP]راستای اگاهیبخشی و افزایش سطح سواد سلامت جامعه[SEP]سوی مسیولان بهداشتی و درمانی[SEP]روانشناس بالینی دانشگاه[SEP]راههای کاهش بار مشکلات خلقی[SEP]فضای مجازی[SEP]روانشناسان و روانپزشکان[SEP]میزان قابل توجهی ترس[SEP]بستر فضای مجازی[SEP]مستعد بودن روان برخی[SEP]رعایت پروتکلهای بهداشتی و توصیهها وسواس و یا اختلال روانی
# 2773th  corpus with score 0.66:
#   فقط برای سالمندان نیست همه در خطرند زنجیره انتقال شکسته_شود دکتر رعایت نکاتی[SEP]استفاده نم د و فاصله اجتماعی[SEP]متخصص‌های عفونی[SEP]پس شستن مکرر دستها رعایت فاصله اجتماعی و مراقبت[SEP]یک متخصص‌های عفونی
# 623th  corpus with score 0.66:
#  آیا با شیردهی به کودک منتقل می‌شود؟ شیر مادر سیستم ایمنی کودک[SEP]شیر انسانی اهدایی[SEP]مشاور تغذیه یا متخصص بهداشت[SEP]صورت مواجهه کودک[SEP]زمان شیردهی[SEP]طریق شیر مادر یا تغذیه[SEP]همراه شیر مادر[SEP]طریق شیر مادر و تغذیه[SEP]اهمیت تغذیه نوزادان و کودکان[SEP]ادامه تغذیه[SEP]شیر مادر اهدایی[SEP]مصرف بشویید وسایل دوشیدن شیر[SEP]شیر مادر[SEP]تداوم تولید شیر[SEP]شش ماهه یا کوچکتر[SEP]امکان دوشیدن شیر یا استفاده[SEP]طریق شیر[SEP]تامین کودک[SEP]شروع زودهنگام شیردهی[SEP]تماس نزدیک[SEP]پادتنهای شما[SEP]ازمایش شیر مادر[SEP]وسایل دوشیدن شیر[SEP]شیر مادر پادتنهای[SEP]کودکتان تماس بدنی[SEP]شیردهی[SEP]طریق یک قاشق یا فنجان تمیز[SEP]دستورالعملهای شستشوی دستها[SEP]ذخیره شیر[SEP]کودک و نظافت و ضدعفونی مداوم سطوحی[SEP]دوشیدن شیر[SEP]یک تقویت کننده سالم[SEP]شیر مادر اگاهی[SEP]شیردهی کودک[SEP]دوران اهمیت فراوانی[SEP]توانایی شیردهی[SEP]شیر[SEP]دایه یا شیر خشک نوزاد[SEP]روشهایی[SEP]ماسک شستشوی دستها[SEP]تماس بدنی و تغذیه زودهنگام و انحصاری[SEP]زمانبندی بسیار مهم

# %%
question
# Out:
# "['کاهش ۵۳ درصدی مبتلایان مرگ\\u200cومیر ناشی از به یک\\u200cسوم کاهش یافت']"

# %% [markdown]
# # Sampling in Batches

# %%
questions = pd.read_pickle('/content/drive/MyDrive/CoPer paper-Models/Sample Queries/Titles_with_Corona.pkl')

# %% [markdown]
# Don't put faiss itself in the function it'll give wrong results and indices

# %%
# create the basic faiss for corpus embeddings
index = faiss.index_factory(768, "Flat", faiss.METRIC_INNER_PRODUCT)
emb_cor = np.array([i.numpy() for i in corpus_embeddings])
faiss.normalize_L2(emb_cor)
index.add(emb_cor)

# %%
results = get_resutls(questions, top_n = 50)
# Out:
# آیا زنان باردار بیشتر در معرض خطر ابتلا به بیماری کروناهستند
# من باردار هستم چگونه می‌توانم از خودم در مقابل بیماری کرونامحافظت کنم
# آیا زنان باردار باید برای کروناآزمایش شوند
# آیا کرونامی تواند از مادر باردار به نوزاد متولد نشده جنین یا نوزاد تازه متولد شده منتقل شود
# در دوران بارداری حین زایمان چه مراقبت‌هایی باید انجام شود
# آیا زنان باردار مبتلا به کرونایا مشکوک به این بیماری نیاز به سزارین دارند
# آیا مادر مبتلا به کرونامی تواند به نوزاد خود شیر بدهد
# آیا در صورت مبتلا شدن به کووید۱۹ می‌توانم کودک خود را در آغوش بگیرم
# من به کرونامبتلا هستم حال عمومی مساعدی ندارم که بتوانم به کودک خود مستقیما شیر بدهم چه باید بکنم
# آیا خشک­ کن­های دست در نابودی ویروس جدید کرونا موثر هستند
# آیا گندزداییضدعفونی با لامپ ماورای بنفش ویروس جدید کرونا را از بین می­برد
# آیا سنجش حرارت بدن اندازه گیری تب در شنسایی افراد مبتلا به عفونت ویروس جدید کرونا موثر است
# آیا اسپری کردن الکل یا محلول‌های حاوی کلر روی تمام بدن می­تواند ویروس جدید کرونا را نابود کند
# آیا واکسنهای ذات­الریه در برابر ویروس جدید کرونا موثر هستند
# آیا شستشوی منظم بینی با محلول­های نمکی کمک به پیشگیری از ابتلا به عفونت کرونا ویروس جدید می­کند
# آیا خوردن سیر به پیشگیری از ابتلا به ویروس جدید کرونا کمک میکند
# چگونه ماسک بزنیم استفاده کنیم در بیاوریم دور بیندازیم
# علائم کروناچیست
# کروناچگونه منتقل می‌شود
# آیا ویروسی که عامل ابتلا به کرونااست از طریق هوا منتقل می‌شود
# آیا کرونااز فرد فاقد علائم بیماری به دیگران منتقل می‌شود
# آیا ممکن است از طریق مدفوع فرد بیمار به کرونامبتلا بشویم
# برای حفاظت خودم جلوگیری از انتشار بیماری چه کار کنم
# چقدر احتمال دارد به کرونامبتلا شوم
# آیا کرونانگران‌کننده است
# چه کسانی احتمال دارد به نوع شدید بیماری کرونامبتلا شوند
# آیا مصرف آنتی‌بیوتیک در جلوگیری از ابتلا به کرونایا درمان آن مؤثر است
# برای پیشگیری درمان کرونادارو یا درمان خاصی وجود دارد
# آیا کروناواکسن دارو یا درمان خاصی دارد
# آیا کروناهمان بیماری سارس است
# آیا باید برای حفاظت از خودم ماسک بزنم
# دوره ‌نهفتگی کمون بیماری کروناچقدر است
# ممکن است از طریق حیوان خانگی‌ام به کرونامبتلا شوم
# این ویروس تا چه مدت روی سطوح زنده می‌ماند
# دریافت بسته پستی از مناطقی که کرونادر آن‌ها گزارش شده بی‌خطر است
# آیا سازمان جهانی بهداشت توصیه می‌کند که تمام گردهمایی‌های بزرگ بین‌المللی در دوران طغیان ویروس جدید کرونا لغو شود
# اقلیم سرد برف نمی‌تواند ویروس را بکشد
# ویروس جدید کرونا نمی‌تواند از طریق نیش پشه منتقل شود
# آیا کرونا از راه استفاده کردن از سرویس بهداشتی انتقال پیدا می‌کند
# آیا کرونا از طریق پوست انتقال پیدا می‌کند
# ویروس کرونا از راه گوش منتقل می‌شود
# آیا ویروس کرونا دچار جهش شده است
# آیا هر نوع سرفه‌ای نشان از ابتلا به کروناست
# آیا افراد مبتلا به آسم آلرژی در خط ابتلا به کرونا هستند
# چگونه سیستم تنفسی ریه خود را تقویت کنیم تا به بیماری کرونا مبتلا نشویم
# آیا کودکان به کرونا مبتلا می‌شوند
# آیا بین گروه خونی احتمال ابتلا به ویروس کرونا ارتباطی هست
# آیا یکبار ابتلا به کرونا به این معناست که دیگر آن را نمی‌گیریم
# آیا ماسک پارچه‌ای برای جلوگیری از ابتلا به کرونا مناسب است
# چگونه باید لوازم شخصی بیماران مبتلا به کرونارا تمیز کرد

# %% [markdown]
# # Saving all in a pickle

# %%
with open('/content/drive/MyDrive/CoPer paper-Models/Results/sbert-WikiNli.pkl', 'wb') as f:
    pickle.dump(results, f)
